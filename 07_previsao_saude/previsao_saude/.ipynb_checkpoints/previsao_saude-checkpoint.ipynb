# %%
# Importando bibliotecas necessárias
import pandas as pd
import sweetviz as sv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import shap
from pycaret.regression import *
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %%
df = pd.read_csv("pns_tratada.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     V0001      V0015   V0026    V0031  A001  \
# 0           1  Rondônia  Realizada  Urbano  Capital  Casa
# 1           2  Rondônia  Realizada  Urbano  Capital  Casa
# 2           3  Rondônia  Realizada  Urbano  Capital  Casa
# 3           4  Rondônia  Realizada  Urbano  Capital  Casa
# 4           5  Rondônia  Realizada  Urbano  Capital  Casa
#
#                                          A002010                     A003010  \
# 0  Alvenaria com revestimento ou taipa revestida  Telha sem laje de concreto
# 1  Alvenaria com revestimento ou taipa revestida  Telha sem laje de concreto
# 2  Alvenaria com revestimento ou taipa revestida  Telha sem laje de concreto
# 3  Alvenaria com revestimento ou taipa revestida  Telha sem laje de concreto
# 4  Alvenaria com revestimento ou taipa revestida  Telha sem laje de concreto
#
#                                              A004010  A01001  ...  VDC003  \
# 0  Cerâmica, lajota ou pedra (inclusive outros pi...       5  ...       3
# 1  Cerâmica, lajota ou pedra (inclusive outros pi...       4  ...       4
# 2  Cerâmica, lajota ou pedra (inclusive outros pi...       4  ...       4
# 3  Cerâmica, lajota ou pedra (inclusive outros pi...       6  ...       3
# 4  Cerâmica, lajota ou pedra (inclusive outros pi...       6  ...       3
#
#                                  VDD004A                        VDE001  \
# 0  Fundamental incompleto ou equivalente  Pessoas na força de trabalho
# 1  Fundamental incompleto ou equivalente  Pessoas na força de trabalho
# 2        Médio incompleto ou equivalente  Pessoas na força de trabalho
# 3          Médio completo ou equivalente  Pessoas na força de trabalho
# 4  Fundamental incompleto ou equivalente  Pessoas na força de trabalho
#
#              VDE002                              VDE014  VDF002  VDF003  \
# 0  Pessoas Ocupadas           Alojamento e alimentação   2098.0   350.0
# 1  Pessoas Ocupadas           Alojamento e alimentação   1000.0   250.0
# 2  Pessoas Ocupadas           Alojamento e alimentação   1000.0   250.0
# 3  Pessoas Ocupadas  Transporte, armazenagem e correio   2998.0   999.0
# 4  Pessoas Ocupadas  Transporte, armazenagem e correio   2998.0   999.0
#
#                              VDF004 VDL001 VDM001
# 0    Mais de ¼ até ½ salário mínimo    NaN    NaN
# 1    Mais de ¼ até ½ salário mínimo    NaN    NaN
# 2    Mais de ¼ até ½ salário mínimo    NaN    NaN
# 3  Mais de 1 até 2 salários mínimos    NaN    NaN
# 4  Mais de 1 até 2 salários mínimos    NaN    NaN
#
# [5 rows x 187 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39103 entries, 0 to 39102
# Columns: 187 entries, Unnamed: 0 to VDM001
# dtypes: float64(44), int64(11), object(132)
# memory usage: 55.8+ MB
