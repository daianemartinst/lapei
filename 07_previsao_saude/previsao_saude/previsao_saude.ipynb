# %%
# Importando bibliotecas necessárias
import pandas as pd
import sweetviz as sv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import shap
from pycaret.regression import *
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %%
df = pd.read_csv("pns_tratada1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     V0001      V0015   V0026    V0031  A001  \
# 0           1  Rondônia  Realizada  Urbano  Capital  Casa
# 1           2  Rondônia  Realizada  Urbano  Capital  Casa
# 2           3  Rondônia  Realizada  Urbano  Capital  Casa
# 3           4  Rondônia  Realizada  Urbano  Capital  Casa
# 4           5  Rondônia  Realizada  Urbano  Capital  Casa
#
#                           A005010 A005012                  A009010 A01403  \
# 0      Rede geral de distribuição     NaN                 Filtrada    NaN
# 1  Poço raso, freático ou cacimba     Não  Mineral industrializada    NaN
# 2  Poço raso, freático ou cacimba     Não  Mineral industrializada    NaN
# 3      Poço profundo ou artesiano     Não  Mineral industrializada    NaN
# 4      Poço profundo ou artesiano     Não  Mineral industrializada    NaN
#
#    ... U02303 U02403 T003 T004                    Y002  \
# 0  ...    NaN    6.0  Não  Não                     Sim
# 1  ...    NaN    NaN  NaN  NaN                     NaN
# 2  ...    2.0    2.0  Não  Não  Recusou-se a responder
# 3  ...    NaN    NaN  NaN  NaN                     NaN
# 4  ...    NaN    NaN  NaN  NaN                     NaN
#
#                         H001 W001 W00103  W00203      V00281
# 0  Mais de 15 dias até 1 mês  NaN    NaN     NaN  118.311823
# 1                        NaN  NaN    NaN     NaN  118.311823
# 2  Mais de 1 mês até 6 meses  NaN    NaN     NaN  118.311823
# 3                        NaN  NaN    NaN     NaN  118.311823
# 4                        NaN  NaN    NaN     NaN  118.311823
#
# [5 rows x 107 columns]

# %%
my_report = sv.analyze(df)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39103 entries, 0 to 39102
# Columns: 187 entries, Unnamed: 0 to VDM001
# dtypes: float64(44), int64(11), object(132)
# memory usage: 55.8+ MB
