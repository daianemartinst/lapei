# %% [markdown]
# # Instalando o Pycaret

# %%
#!pip install pycaret

# %%
#!pip install scipy

# %%
# Importando bibliotecas necessárias
import pandas as pd
import sweetviz as sv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import shap
from pycaret.regression import *
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from sklearn.cluster import KMeans

# %% [markdown]
# # Tratando a base

# %%
df= pd.read_excel("Base_2022_2023.xlsx")

# %%
df = df[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','taxa_homicidio','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','qtd_cursos_engenharias',
    'qtd_cursos_negocios_direito','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
df.head()
# Out:
#    cod_municipio_ibge  qtd_abertas_Empresario_Individual Mecanismos_incentivo  \
# 0              110001                                194                  Não
# 1              110002                               1275                  Sim
# 2              110003                                 49                  Sim
# 3              110004                               1258                  Sim
# 4              110005                                257                  Sim
#
#   Reducao_IPTU Isencao_IPTU Reducao_ISSQN Isencao_ISSQN Isencao_Tx  \
# 0          NaN          NaN           NaN           NaN        NaN
# 1          Sim          Sim           Não           Não        Sim
# 2          Não          Não           Não           Sim        Não
# 3          Não          Sim           Sim           Não        Sim
# 4          Não          Sim           Não           Não        Não
#
#   Cessao_terrenos Doacao_terrenos  ... media_notas_CH  media_NU_NOTA_LC  \
# 0             NaN             NaN  ...     504.034091        491.079545
# 1             Não             Sim  ...     495.727950        484.710248
# 2             Não             Não  ...     486.071429        447.628571
# 3             Sim             Sim  ...     505.006061        490.991919
# 4             Não             Não  ...     477.045714        454.722857
#
#    media_NU_NOTA_MT media_NU_NOTA_REDACAO  valor_medio_recebido_familia  \
# 0        543.558537            621.363636                         18495
# 1        518.811149            584.534161                         17615
# 2        522.883333            471.428571                         18956
# 3        533.458933            611.717172                         19376
# 4        480.696875            576.571429                         17752
#
#    pib_per_capita_preco_corrente  perc_20_59_anos  pop_total  \
# 0                       25091.18         0.587227      22516
# 1                       25730.20         0.591797     111148
# 2                       32226.25         0.584567       5067
# 3                       29331.29         0.595584      86416
# 4                       37069.25         0.598272      16088
#
#    total_sim_tecnologia  porte_municipio
# 0                  18.0                2
# 1                  12.0                4
# 2                   8.0                1
# 3                  17.0                3
# 4                   8.0                2
#
# [5 rows x 29 columns]

# %%
df['qtd_cursos_engenharias'] = df['qtd_cursos_engenharias'].fillna(0)

df['qtd_cursos_negocios_direito'] = df['qtd_cursos_negocios_direito'].fillna(0)

df['total_sim_tecnologia'] = df['total_sim_tecnologia'].fillna(0)

df['taxa_homicidio'] = df['taxa_homicidio'].fillna(0)

df['RH_adm_dir'] = df['RH_adm_dir'].fillna(0)

# %%
df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df = pd.get_dummies(df, columns = ['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','ISH'], drop_first=True)

# %%
df = df[np.isfinite(df).all(1)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   cod_municipio_ibge                 5570 non-null   int64
#  1   qtd_abertas_Empresario_Individual  5570 non-null   int64
#  2   taxa_homicidio                     5570 non-null   float64
#  3   RH_adm_dir                         5570 non-null   float64
#  4   densidade_banda_larga              5570 non-null   float64
#  5   densidade_telefonia_movel          5570 non-null   float64
#  6   qtd_cursos_engenharias             5570 non-null   float64
#  7   qtd_cursos_negocios_direito        5570 non-null   float64
#  8   media_notas_CN                     5570 non-null   float64
#  9   media_notas_CH                     5570 non-null   float64
#  10  media_NU_NOTA_LC                   5570 non-null   float64
#  11  media_NU_NOTA_MT                   5570 non-null   float64
#  12  media_NU_NOTA_REDACAO              5570 non-null   float64
#  13  valor_medio_recebido_familia       5570 non-null   int64
#  14  pib_per_capita_preco_corrente      5570 non-null   float64
#  15  perc_20_59_anos                    5570 non-null   float64
#  16  pop_total                          5570 non-null   int64
#  17  total_sim_tecnologia               5570 non-null   float64
#  18  porte_municipio                    5570 non-null   int64
#  19  Mecanismos_incentivo_Sim           5570 non-null   uint8
#  20  Reducao_IPTU_Sim                   5570 non-null   uint8
#  21  Isencao_IPTU_Sim                   5570 non-null   uint8
#  22  Reducao_ISSQN_Sim                  5570 non-null   uint8
#  23  Isencao_ISSQN_Sim                  5570 non-null   uint8
#  24  Isencao_Tx_Sim                     5570 non-null   uint8
#  25  Cessao_terrenos_Sim                5570 non-null   uint8
#  26  Doacao_terrenos_Sim                5570 non-null   uint8
#  27  Outros_mecanismos_Sim              5570 non-null   uint8
#  28  ISH_Baixa                          5570 non-null   uint8
#  29  ISH_Máxima                         5570 non-null   uint8
#  30  ISH_Média                          5570 non-null   uint8
#  31  ISH_Mínima                         5570 non-null   uint8
# dtypes: float64(14), int64(5), uint8(13)
# memory usage: 941.0 KB

# %%
df = df.set_index('cod_municipio_ibge')

# %%
df
# Out:
#                     qtd_abertas_Empresario_Individual  taxa_homicidio  \
# cod_municipio_ibge
# 110001                                            194             8.0
# 110002                                           1275            38.0
# 110003                                             49             0.0
# 110004                                           1258            21.0
# 110005                                            257             3.0
# ...                                               ...             ...
# 522200                                            222             1.0
# 522205                                             66             0.0
# 522220                                             23             0.0
# 522230                                             47             0.0
# 530010                                          54325           480.0
#
#                     RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                   926.0               8.958074
# 110002                  2563.0              21.363407
# 110003                   344.0               5.407539
# 110004                  1971.0              19.480189
# 110005                   591.0               8.540527
# ...                        ...                    ...
# 522200                   528.0               6.423907
# 522205                   394.0               8.442568
# 522220                   403.0               1.240118
# 522230                   344.0               7.187342
# 530010                122197.0              25.834035
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              70.647540                     2.0
# 110002                              93.858639                    99.0
# 110003                              78.369844                     0.0
# 110004                             105.350861                   184.0
# 110005                             108.074341                     4.0
# ...                                       ...                     ...
# 522200                             106.821408                     4.0
# 522205                             104.276827                     0.0
# 522220                              66.485816                     0.0
# 522230                              39.892274                     0.0
# 530010                             109.381529                  2210.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     30.0      497.721951
# 110002                                    342.0      474.773986
# 110003                                      0.0      477.266667
# 110004                                    422.0      489.744000
# 110005                                     35.0      479.268750
# ...                                         ...             ...
# 522200                                     12.0      449.954054
# 522205                                      0.0      450.285714
# 522220                                      0.0      431.645455
# 522230                                      0.0      432.055556
# 530010                                  13097.0      505.707532
#
#                     media_notas_CH  media_NU_NOTA_LC  ...  Reducao_ISSQN_Sim  \
# cod_municipio_ibge                                    ...
# 110001                  504.034091        491.079545  ...                  0
# 110002                  495.727950        484.710248  ...                  0
# 110003                  486.071429        447.628571  ...                  0
# 110004                  505.006061        490.991919  ...                  1
# 110005                  477.045714        454.722857  ...                  0
# ...                            ...               ...  ...                ...
# 522200                  479.917073        473.014634  ...                  0
# 522205                  464.383333        457.593333  ...                  0
# 522220                  443.025000        426.491667  ...                  0
# 522230                  417.394737        428.821053  ...                  0
# 530010                  534.044622        522.095562  ...                  0
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
# ...                               ...             ...                  ...
# 522200                              0               0                    0
# 522205                              0               1                    0
# 522220                              0               0                    1
# 522230                              0               0                    1
# 530010                              0               0                    1
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
# ...                                 ...                    ...        ...
# 522200                                0                      0          0
# 522205                                1                      0          0
# 522220                                1                      0          0
# 522230                                0                      0          0
# 530010                                0                      1          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima
# cod_municipio_ibge
# 110001                       0          0           0
# 110002                       0          1           0
# 110003                       0          0           0
# 110004                       0          0           0
# 110005                       0          0           0
# ...                        ...        ...         ...
# 522200                       1          0           0
# 522205                       0          1           0
# 522220                       0          0           0
# 522230                       0          0           0
# 530010                       0          0           0
#
# [5570 rows x 31 columns]

# %% [markdown]
# ## Nova base teste

# %%
df_2 = pd.read_excel("Base_novos_dados_2018_2019.xlsx")

# %%
df_2 = df_2[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','taxa_homicidio','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','qtd_cursos_engenharias',
    'qtd_cursos_negocios_direito','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
df_2['qtd_cursos_engenharias'] = df_2['qtd_cursos_engenharias'].fillna(0)

df_2['qtd_cursos_negocios_direito'] = df_2['qtd_cursos_negocios_direito'].fillna(0)

df_2['total_sim_tecnologia'] = df_2['total_sim_tecnologia'].fillna(0)

df_2['taxa_homicidio'] = df_2['taxa_homicidio'].fillna(0)

df_2['RH_adm_dir'] = df_2['RH_adm_dir'].fillna(0)

# %%
df_2[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df_2[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df_2[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df_2[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df_2 = df_2[np.isfinite(df_2).all(1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[322], line 1
# ----> 1 df_2 = df_2[np.isfinite(df_2).all(1)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:410, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     405 if method == "__call__" and not kwargs:
#     406     # for np.<ufunc>(..) calls
#     407     # kwargs cannot necessarily be handled block-by-block, so only
#     408     # take this path if there are no kwargs
#     409     mgr = inputs[0]._mgr
# --> 410     result = mgr.apply(getattr(ufunc, method))
#     411 else:
#     412     # otherwise specific ufunc methods (eg np.<ufunc>.accumulate(..))
#     413     # Those can have an axis keyword and thus can't be called block-by-block
#     414     result = default_array_ufunc(inputs[0], ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:350, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     348 try:
#     349     if callable(f):
# --> 350         applied = b.apply(f, **kwargs)
#     351     else:
#     352         applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351, in Block.apply(self, func, **kwargs)
#     345 @final
#     346 def apply(self, func, **kwargs) -> list[Block]:
#     347     """
#     348     apply the function to my values; return a block if we are not
#     349     one
#     350     """
# --> 351     result = func(self.values, **kwargs)
#     353     return self._split_op_result(result)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df_2 = df_2.set_index('cod_municipio_ibge')

# %% [markdown]
# # Dividindo em treino e test

# %% [markdown]
# Adaleny, fiz a divisão de treino e teste baseado na estratificação

# %%
treino = df.groupby('porte_municipio', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste = df.drop(treino.index)

print(treino.shape, teste.shape)

# %% [markdown]
# treino = treino.drop('porte_municipio', axis = 1)
# teste= teste.drop('porte_municipio', axis = 1)

# %%
#teste= teste.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %% [markdown]
# treino.info()

# %% [markdown]
# # Pycaret

# %% [markdown]
# ## Setup

# %%
regression_setup = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)

# %% [markdown]
# ## Comparando Modelos

# %% [markdown]
# ### Usando RMSE

# %%
best_model = compare_models(sort = 'RMSE', fold=5)

# %%
# verificando os hiperparâmetros do modelo 

print(best_model)

# %%
best_model = create_model('huber', fold = 5)

# %% [markdown]
# ### Plotando alguns graficos

# %%
evaluate_model(best_model)

# %%
plot_model(best_model, plot = 'learning')

# %%
plot_model(best_model, plot='vc')

# %%
plot_model(best_model, plot='error')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[287], line 1
# ----> 1 plot_model(best_model, plot='error')
#
# File ~\anaconda3\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pycaret\regression\functional.py:1660, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1554 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1555 def plot_model(
#    1556     estimator,
#    (...)
#    1566     display_format: Optional[str] = None,
#    1567 ) -> Optional[str]:
#    1568     """
#    1569     This function analyzes the performance of a trained model on holdout set.
#    1570     It may require re-training the model in certain cases.
#    (...)
#    1657
#    1658     """
# -> 1660     return _CURRENT_EXPERIMENT.plot_model(
#    1661         estimator=estimator,
#    1662         plot=plot,
#    1663         scale=scale,
#    1664         save=save,
#    1665         fold=fold,
#    1666         fit_kwargs=fit_kwargs,
#    1667         plot_kwargs=plot_kwargs,
#    1668         groups=groups,
#    1669         verbose=verbose,
#    1670         use_train_data=use_train_data,
#    1671         display_format=display_format,
#    1672     )
#
# File ~\anaconda3\lib\site-packages\pycaret\regression\oop.py:1960, in RegressionExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1854 def plot_model(
#    1855     self,
#    1856     estimator,
#    (...)
#    1866     display_format: Optional[str] = None,
#    1867 ) -> Optional[str]:
#    1868     """
#    1869     This function analyzes the performance of a trained model on holdout set.
#    1870     It may require re-training the model in certain cases.
#    (...)
#    1957
#    1958     """
# -> 1960     return super().plot_model(
#    1961         estimator=estimator,
#    1962         plot=plot,
#    1963         scale=scale,
#    1964         save=save,
#    1965         fold=fold,
#    1966         fit_kwargs=fit_kwargs,
#    1967         plot_kwargs=plot_kwargs,
#    1968         groups=groups,
#    1969         verbose=verbose,
#    1970         use_train_data=use_train_data,
#    1971         display_format=display_format,
#    1972     )
#
# File ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2052, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#    1939 def plot_model(
#    1940     self,
#    1941     estimator,
#    (...)
#    1953     display_format: Optional[str] = None,
#    1954 ) -> Optional[str]:
#    1955     """
#    1956     This function takes a trained model object and returns a plot based on the
#    1957     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2050
#    2051     """
# -> 2052     return self._plot_model(
#    2053         estimator=estimator,
#    2054         plot=plot,
#    2055         scale=scale,
#    2056         save=save,
#    2057         fold=fold,
#    2058         fit_kwargs=fit_kwargs,
#    2059         plot_kwargs=plot_kwargs,
#    2060         groups=groups,
#    2061         feature_name=feature_name,
#    2062         label=label,
#    2063         use_train_data=use_train_data,
#    2064         verbose=verbose,
#    2065         display_format=display_format,
#    2066     )
#
# File ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:1919, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format)
#    1917 # execute the plot method
#    1918 with redirect_output(self.logger):
# -> 1919     ret = locals()[plot]()
#    1920 if ret:
#    1921     plot_filename = ret
#
# File ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:1233, in _TabularExperiment._plot_model.<locals>.error()
#    1227     from yellowbrick.regressor import PredictionError
#    1229     visualizer = PredictionError(
#    1230         estimator, random_state=self.seed, **plot_kwargs
#    1231     )
# -> 1233 return show_yellowbrick_plot(
#    1234     visualizer=visualizer,  # type: ignore
#    1235     X_train=self.X_train_transformed,
#    1236     y_train=self.y_train_transformed,
#    1237     X_test=self.X_test_transformed,
#    1238     y_test=self.y_test_transformed,
#    1239     name=plot_name,
#    1240     scale=scale,
#    1241     save=save,
#    1242     fit_kwargs=fit_kwargs,
#    1243     display_format=display_format,
#    1244 )
#
# File ~\anaconda3\lib\site-packages\pycaret\internal\plots\yellowbrick.py:103, in show_yellowbrick_plot(visualizer, X_train, y_train, X_test, y_test, name, handle_train, handle_test, scale, save, fit_kwargs, display_format, **kwargs)
#     101 elif handle_test == "score":
#     102     logger.info("Scoring test/hold-out set")
# --> 103     visualizer.score(X_test, y_test)
#     105 plot_filename = f"{name}.png"
#     106 if save:
#
# File ~\anaconda3\lib\site-packages\yellowbrick\regressor\prediction_error.py:165, in PredictionError.score(self, X, y, **kwargs)
#     145 """
#     146 The score function is the hook for visual interaction. Pass in test
#     147 data and the visualizer will create predictions on the data and
#    (...)
#     162 score : float
#     163 """
#     164 # super will set score_ on the visualizer
# --> 165 super(PredictionError, self).score(X, y, **kwargs)
#     167 y_pred = self.predict(X)
#     168 self.draw(y, y_pred)
#
# File ~\anaconda3\lib\site-packages\yellowbrick\regressor\base.py:110, in RegressionScoreVisualizer.score(self, X, y, **kwargs)
#      89 def score(self, X, y, **kwargs):
#      90     """
#      91     The score function is the hook for visual interaction. Pass in test
#      92     data and the visualizer will create predictions on the data and
#    (...)
#     108         The R^2 score of the underlying regressor
#     109     """
# --> 110     self.score_ = self.estimator.score(X, y)
#     111     return self.score_
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:703, in RegressorMixin.score(self, X, y, sample_weight)
#     661 """Return the coefficient of determination of the prediction.
#     662
#     663 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     698 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     699 """
#     701 from .metrics import r2_score
# --> 703 y_pred = self.predict(X)
#     704 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
#     335     check_is_fitted(self)
# --> 337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:529, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     464 def _validate_data(
#     465     self,
#     466     X="no_validation",
#    (...)
#     470     **check_params,
#     471 ):
#     472     """Validate input data and set or check the `n_features_in_` attribute.
#     473
#     474     Parameters
#    (...)
#     527         validated.
#     528     """
# --> 529     self._check_feature_names(X, reset=reset)
#     531     if y is None and self._get_tags()["requires_y"]:
#     532         raise ValueError(
#     533             f"This {self.__class__.__name__} estimator "
#     534             "requires y to be passed, but the target y is None."
#     535         )
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:462, in BaseEstimator._check_feature_names(self, X, reset)
#     457 if not missing_names and not unexpected_names:
#     458     message += (
#     459         "Feature names must be in the same order as they were in fit.\n"
#     460     )
# --> 462 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - cluster_1
# - cluster_2

# %%
plot_model(best_model, plot='feature')

# %%
plot_model(best_model, plot='residuals',  scale = 3)

# %% [markdown]
# ### Tunando o modelo

# %%
# em alguns tutoriais vi que não fizeram nenhuma modificação manual dos parametros, e eles já modificavam. 
#Esse parece que não conteceu do mesmo jeito. 

tuned = tune_model(best_model, fold = 5)

# %%
#estranho, era para monstrar o que foi testado de diferente com o tuned, parece que esta igual.
#Sem falar que os resultados parecem piores depois de tunar 

print(tuned)

# %%
plot_model(tuned, plot = 'learning')  #use_train_data = True

# %%
# Validation Curve
plot_model(tuned, plot='vc')

# %%
plot_model(tuned, plot='error')

# O R² esta bem baixo

# %%
plot_model(tuned, plot='feature' )

# %%
plot_model(tuned, plot='feature', save = True )

# %%
plot_model(tuned, plot='residuals',  scale = 3)

#os resultados parecem muito distantes uns dos outros

# %%
final_model_baseline = finalize_model(tuned)

# %% [markdown]
# ### Previsão

# %%
pred_treino = predict_model(final_model_baseline, data = treino)

# %%
pred_treino

# %%
plt.scatter(pred_treino['qtd_abertas_Empresario_Individual'],pred_treino['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')

# %% [markdown]
# Previsão de dados não vistos

# %%
pred_unseen = predict_model(final_model_baseline, data = teste)

# %%
pred_unseen

# %%
plt.scatter(pred_unseen['qtd_abertas_Empresario_Individual'],pred_unseen['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')

# %% [markdown]
# ## Previsão - Novos dados (VIs = 2018 e VD = 2019)

# %%
pred_treino_2 = predict_model(final_model_baseline, data = df_2)

# %%
pred_treino_2

# %%
plt.scatter(pred_treino_2['qtd_abertas_Empresario_Individual'],pred_treino_2['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')

# %%
df.to_excel('dados_previsao.xlsx')

# %% [markdown]
# ## Testando Radom Forest

# %% [markdown]
# ### MAPE

# %%
regression_setup_mape = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_b2019_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b2019">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2019_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b2019_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b2019_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b2019_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b2019_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b2019_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b2019_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b2019_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b2019_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b2019_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b2019_row3_col1" class="data row3 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b2019_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b2019_row4_col1" class="data row4 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b2019_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b2019_row5_col1" class="data row5 col1" >(2924, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b2019_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b2019_row6_col1" class="data row6 col1" >(1254, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b2019_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b2019_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b2019_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b2019_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b2019_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b2019_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b2019_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b2019_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b2019_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b2019_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b2019_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b2019_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b2019_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b2019_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b2019_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b2019_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b2019_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b2019_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b2019_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b2019_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b2019_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b2019_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b2019_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b2019_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b2019_row18_col1" class="data row18 col1" >3fbc</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_mape = compare_models(sort = 'MAPE', fold=5)
# Out:
# <style type="text/css">
# #T_4b7cb th {
#   text-align: left;
# }
# #T_4b7cb_row0_col0, #T_4b7cb_row0_col1, #T_4b7cb_row0_col2, #T_4b7cb_row0_col3, #T_4b7cb_row0_col4, #T_4b7cb_row1_col0, #T_4b7cb_row1_col1, #T_4b7cb_row1_col2, #T_4b7cb_row1_col3, #T_4b7cb_row1_col4, #T_4b7cb_row1_col5, #T_4b7cb_row1_col6, #T_4b7cb_row2_col0, #T_4b7cb_row2_col1
#   text-align: left;
# }
# #T_4b7cb_row0_col5, #T_4b7cb_row0_col6, #T_4b7cb_row6_col1, #T_4b7cb_row6_col2, #T_4b7cb_row6_col3, #T_4b7cb_row6_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4b7cb_row0_col7, #T_4b7cb_row1_col7, #T_4b7cb_row2_col7, #T_4b7cb_row3_col7, #T_4b7cb_row4_col7, #T_4b7cb_row5_col7, #T_4b7cb_row6_col7, #T_4b7cb_row7_col7, #T_4b7cb_row8_col7, #T_4b7cb_row9_col7, #T_4b7cb_row10_col7, #T_4b7cb_row11_col7, #T_4b7cb_row13_col7, #T_4b7cb_row14_col7, #T_4b7cb_row15_col7, #T_4b7cb_row16_col7, #T_4b7cb_row17_col7, #T_4b7cb_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4b7cb_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4b7cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b7cb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4b7cb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4b7cb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4b7cb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4b7cb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4b7cb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4b7cb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4b7cb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b7cb_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_4b7cb_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_4b7cb_row0_col1" class="data row0 col1" >194.7635</td>
#       <td id="T_4b7cb_row0_col2" class="data row0 col2" >13973713.5514</td>
#       <td id="T_4b7cb_row0_col3" class="data row0 col3" >2468.4513</td>
#       <td id="T_4b7cb_row0_col4" class="data row0 col4" >0.7519</td>
#       <td id="T_4b7cb_row0_col5" class="data row0 col5" >0.4226</td>
#       <td id="T_4b7cb_row0_col6" class="data row0 col6" >0.4050</td>
#       <td id="T_4b7cb_row0_col7" class="data row0 col7" >0.3080</td>
#     </tr>
#     <tr>
#       <th id="T_4b7cb_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_4b7cb_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_4b7cb_row1_col1" class="data row1 col1" >164.7040</td>
#       <td id="T_4b7cb_row1_col2" class="data row1 col2" >8843174.1987</td>
#       <td id="T_4b7cb_row1_col3" class="data row1 col3" >1798.7295</td>
#       <td id="T_4b7cb_row1_col4" class="data row1 col4" >0.8626</td>
#       <td id="T_4b7cb_row1_col5" class="data row1 col5" >0.4348</td>
#       <td id="T_4b7cb_row1_col6" class="data row1 col6" >0.4314</td>
#       <td id="T_4b7cb_row1_col7" class="data row1 col7" >0.3280</td>
#     </tr>
#     <tr>
#       <th id="T_4b7cb_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_4b7cb_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_4b7cb_row2_col1" class="data row2 col1" >219.8897</td>
#       <td id="T_4b7cb_row2_col2" class="data row2 col2" >12499803.0887</td>
#       <td id="T_4b7cb_row2_col3" class="data row2 col3" >2477.6845</td>
#       <td id="T_4b7cb_row2_col4" class="data row2 col4" >0.7576</td>
#       <td id="T_4b7cb_row2_col5" class="data row2 col5" >0.5161</td>
#       <td id="T_4b7cb_row2_col6" class="data row2 col6" >0.4630</td>
#       <td id="T_4b7cb_row2_col7" class="data row2 col7" >0.3080</td>
#     </tr>
#     <tr>
#       <th id="T_4b7cb_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_4b7cb_row3_col0" class="data row3 col0" >K Neighbors Regressor</td>
#       <td id="T_4b7cb_row3_col1" class="data row3 col1" >232.8533</td>
#       <td id="T_4b7cb_row3_col2" class="data row3 col2" >16585764.7820</td>
#       <td id="T_4b7cb_row3_col3" class="data row3 col3" >2662.1187</td>
#       <td id="T_4b7cb_row3_col4" class="data row3 col4" >0.7470</td>
#       <td id="T_4b7cb_row3_col5" class="data row3 col5" >0.5084</td>
#       <td id="T_4b7cb_row3_col6" class="data row3 col6" >0.5136</td>
#       <td id="T_4b7cb_row3_col7" class="data row3 col7" >0.2940</td>
#     </tr>
#     <tr>
#       <th id="T
td>
#     </tr>
#     <tr>
#       <th id="T_d0063_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d0063_row5_col0" class="data row5 col0" >194.7635</td>
#       <td id="T_d0063_row5_col1" class="data row5 col1" >13973713.5514</td>
#       <td id="T_d0063_row5_col2" class="data row5 col2" >2468.4513</td>
#       <td id="T_d0063_row5_col3" class="data row5 col3" >0.7519</td>
#       <td id="T_d0063_row5_col4" class="data row5 col4" >0.4226</td>
#       <td id="T_d0063_row5_col5" class="data row5 col5" >0.4050</td>
#     </tr>
#     <tr>
#       <th id="T_d0063_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d0063_row6_col0" class="data row6 col0" >133.0637</td>
#       <td id="T_d0063_row6_col1" class="data row6 col1" >24561254.2446</td>
#       <td id="T_d0063_row6_col2" class="data row6 col2" >2807.2160</td>
#       <td id="T_d0063_row6_col3" class="data row6 col3" >0.1828</td>
#       <td id="T_d0063_row6_col4" class="data row6 col4" >0.0062</td>
#       <td id="T_d0063_row6_col5" class="data row6 col5" >0.0108</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_mape = tune_model(best_model_mape, fold = 5)
# Out:
# <style type="text/css">
# #T_21f7f_row5_col0, #T_21f7f_row5_col1, #T_21f7f_row5_col2, #T_21f7f_row5_col3, #T_21f7f_row5_col4, #T_21f7f_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_21f7f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21f7f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_21f7f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_21f7f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_21f7f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_21f7f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_21f7f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21f7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21f7f_row0_col0" class="data row0 col0" >172.5487</td>
#       <td id="T_21f7f_row0_col1" class="data row0 col1" >744158.4627</td>
#       <td id="T_21f7f_row0_col2" class="data row0 col2" >862.6462</td>
#       <td id="T_21f7f_row0_col3" class="data row0 col3" >0.9685</td>
#       <td id="T_21f7f_row0_col4" class="data row0 col4" >0.7898</td>
#       <td id="T_21f7f_row0_col5" class="data row0 col5" >1.1382</td>
#     </tr>
#     <tr>
#       <th id="T_21f7f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21f7f_row1_col0" class="data row1 col0" >193.0442</td>
#       <td id="T_21f7f_row1_col1" class="data row1 col1" >1029151.3126</td>
#       <td id="T_21f7f_row1_col2" class="data row1 col2" >1014.4710</td>
#       <td id="T_21f7f_row1_col3" class="data row1 col3" >0.6762</td>
#       <td id="T_21f7f_row1_col4" class="data row1 col4" >0.8262</td>
#       <td id="T_21f7f_row1_col5" class="data row1 col5" >1.2232</td>
#     </tr>
#     <tr>
#       <th id="T_21f7f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21f7f_row2_col0" class="data row2 col0" >163.4294</td>
#       <td id="T_21f7f_row2_col1" class="data row2 col1" >430379.3961</td>
#       <td id="T_21f7f_row2_col2" class="data row2 col2" >656.0331</td>
#       <td id="T_21f7f_row2_col3" class="data row2 col3" >0.9521</td>
#       <td id="T_21f7f_row2_col4" class="data row2 col4" >0.8663</td>
#       <td id="T_21f7f_row2_col5" class="data row2 col5" >1.3677</td>
#     </tr>
#     <tr>
#       <th id="T_21f7f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21f7f_row3_col0" class="data row3 col0" >96.6468</td>
#       <td id="T_21f7f_row3_col1" class="data row3 col1" >35133.3831</td>
#       <td id="T_21f7f_row3_col2" class="data row3 col2" >187.4390</td>
#       <td id="T_21f7f_row3_col3" class="data row3 col3" >0.9596</td>
#       <td id="T_21f7f_row3_col4" class="data row3 col4" >0.8674</td>
#       <td id="T_21f7f_row3_col5" class="data row3 col5" >1.3259</td>
#     </tr>
#     <tr>
#       <th id="T_21f7f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21f7f_row4_col0" class="data row4 col0" >491.7311</td>
#       <td id="T_21f7f_row4_col1" class="data row4 col1" >68978277.4357</td>
#       <td id="T_21f7f_row4_col2" class="data row4 col2" >8305.3162</td>
#       <td id="T_21f7f_row4_col3" class="data row4 col3" >0.4197</td>
#       <td id="T_21f7f_row4_col4" class="data row4 col4" >0.8379</td>
#       <td id="T_21f7f_row4_col5" class="data row4 col5" >1.2779</td>
#     </tr>
#     <tr>
#       <th id="T_21f7f_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_21f7f_row5_col0" class="data row5 col0" >223.4801</td>
#       <td id="T_21f7f_row5_col1" class="data row5 col1" >14243419.9980</td>
#       <td id="T_21f7f_row5_col2" class="data row5 col2" >2205.1811</td>
#       <td id="T_21f7f_row5_col3" class="data row5 col3" >0.7952</td>
#       <td id="T_21f7f_row5_col4" class="data row5 col4" >0.8375</td>
#       <td id="T_21f7f_row5_col5" class="data row5 col5" >1.2666</td>
#     </tr>
#     <tr>
#       <th id="T_21f7f_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_21f7f_row6_col0" class="data row6 col0" >137.9650</td>
#       <td id="T_21f7f_row6_col1" class="data row6 col1" >27369424.8270</td>
#       <td id="T_21f7f_row6_col2" class="data row6 col2" >3062.7759</td>
#       <td id="T_21f7f_row6_col3" class="data row6 col3" >0.2176</td>
#       <td id="T_21f7f_row6_col4" class="data row6 col4" >0.0287</td>
#       <td id="T_21f7f_row6_col5" class="data row6 col5" >0.0803</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
plot_model(best_model_mape, plot='feature' )

# %%
final_model_baseline_mape = finalize_model(best_model_mape)

# %%
pred_teste_mape= predict_model(final_model_baseline_mape, data = teste)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b2a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b2a4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5b2a4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5b2a4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5b2a4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5b2a4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5b2a4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5b2a4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b2a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b2a4_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_5b2a4_row0_col1" class="data row0 col1" >84.6395</td>
#       <td id="T_5b2a4_row0_col2" class="data row0 col2" >175013.8789</td>
#       <td id="T_5b2a4_row0_col3" class="data row0 col3" >418.3466</td>
#       <td id="T_5b2a4_row0_col4" class="data row0 col4" >0.9507</td>
#       <td id="T_5b2a4_row0_col5" class="data row0 col5" >0.3986</td>
#       <td id="T_5b2a4_row0_col6" class="data row0 col6" >0.3724</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_teste_mape
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110005                         3.0       591.0               8.540527
# 110007                         1.0       382.0               3.261486
# 110008                         3.0       573.0               4.388471
# 110011                        10.0      1484.0              20.346228
# 110013                         6.0      1214.0               7.779695
# ...                            ...         ...                    ...
# 522100                         5.0       195.0               2.852253
# 522119                         4.0       271.0              10.329089
# 522190                         0.0       184.0               9.433472
# 522200                         1.0       528.0               6.423907
# 522230                         0.0       344.0               7.187342
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110005                             108.074341                     4.0
# 110007                              51.545662                     0.0
# 110008                              35.367435                     5.0
# 110011                             101.132721                     8.0
# 110013                              56.914486                     3.0
# ...                                       ...                     ...
# 522100                             103.565315                     0.0
# 522119                             116.298340                     0.0
# 522190                              78.092514                     0.0
# 522200                             106.821411                     4.0
# 522230                              39.892273                     0.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110005                                     35.0      479.268738
# 110007                                      0.0      439.184601
# 110008                                     12.0      438.418182
# 110011                                    114.0      472.343292
# 110013                                     26.0      460.839630
# ...                                         ...             ...
# 522100                                      0.0      464.779999
# 522119                                      0.0      435.885712
# 522190                                      0.0      426.950012
# 522200                                     12.0      449.954041
# 522230                                      0.0      432.055542
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110005                  477.045715        454.722870        480.696869  ...
# 110007                  466.414276        432.535706        445.276917  ...
# 110008                  465.692108        451.828949        478.290924  ...
# 110011                  501.169189        481.437683        507.111206  ...
# 110013                  482.138611        470.749115        485.543396  ...
# ...                            ...               ...               ...  ...
# 522100                  487.066681        474.000000        520.359985  ...
# 522119                  480.299988        450.257141        503.938110  ...
# 522190                  483.766663        451.266663        422.950012  ...
# 522200                  479.917084        473.014648        516.186462  ...
# 522230                  417.394745        428.821045        460.816681  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110005                           0                    0                    0
# 110007                           0                    1                    0
# 110008                           1                    1                    0
# 110011                           0                    0                    0
# 110013                           0                    0                    0
# ...                            ...                  ...                  ...
# 522100                           0                    0                    0
# 522119                           0                    1                    0
# 522190                           0                    0                    0
# 522200                           0                    0                    0
# 522230                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110005                                  0          1           0          0
# 110007                                  1          0           0          0
# 110008                                  0          1           0          0
# 110011                                  0          0           0          1
# 110013                                  1          1           0          0
# ...                                   ...        ...         ...        ...
# 522100                                  0          0           0          0
# 522119                                  0          0           1          0
# 522190                                  0          0           1          0
# 522200                                  0          0           1          0
# 522230                                  0          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110005                       0                                257
# 110007                       0                                 86
# 110008                       0                                106
# 110011                       0                                617
# 110013                       0                                279
# ...                        ...                                ...
# 522100                       0                                 41
# 522119                       0                                108
# 522190                       0                                 30
# 522200                       0                                222
# 522230                       0                                 47
#
#                     prediction_label
# cod_municipio_ibge
# 110005                        226.97
# 110007                         53.20
# 110008                        104.85
# 110011                        793.21
# 110013                        264.34
# ...                              ...
# 522100                         45.48
# 522119                        108.44
# 522190                         43.71
# 522200                        178.58
# 522230                         47.30
#
# [1392 rows x 31 columns]

# %%
plt.scatter(pred_teste_mape['qtd_abertas_Empresario_Individual'],pred_teste_mape['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %%
pred_teste_mape.to_excel('previsao_mape.xlsx')

# %% [markdown]
# ### Previsão - Mape 2019

# %%
pred_2018_2019 = predict_model(final_model_baseline_mape, data = df_2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35bf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35bf9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35bf9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_35bf9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_35bf9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_35bf9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_35bf9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_35bf9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35bf9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35bf9_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_35bf9_row0_col1" class="data row0 col1" >116.0603</td>
#       <td id="T_35bf9_row0_col2" class="data row0 col2" >988416.7487</td>
#       <td id="T_35bf9_row0_col3" class="data row0 col3" >994.1915</td>
#       <td id="T_35bf9_row0_col4" class="data row0 col4" >0.9408</td>
#       <td id="T_35bf9_row0_col5" class="data row0 col5" >0.4431</td>
#       <td id="T_35bf9_row0_col6" class="data row0 col6" >0.4471</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_2018_2019
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382995
# 110005                         2.0       591.0               7.847822
# ...                            ...         ...                    ...
# 522200                         2.0       528.0               7.191805
# 522205                         4.0       394.0               8.601167
# 522220                         3.0       403.0               5.055907
# 522230                         2.0       344.0               2.817385
# 530010                       530.0    122197.0              23.930012
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342995                     6.0
# 110002                              86.588539                    42.0
# 110003                              79.838104                     0.0
# 110004                              89.462151                   202.0
# 110005                              89.952827                     0.0
# ...                                       ...                     ...
# 522200                              33.744499                     0.0
# 522205                              78.874527                     0.0
# 522220                               5.833738                     0.0
# 522230                              26.473114                     0.0
# 530010                             117.493172                  3082.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664276
# 110002                                    299.0      481.314240
# 110003                                      0.0      442.604156
# 110004                                    469.0      484.990723
# 110005                                     38.0      466.433807
# ...                                         ...             ...
# 522200                                      0.0      474.571777
# 522205                                      0.0      439.651611
# 522220                                      0.0      440.164276
# 522230                                      0.0      451.296661
# 530010                                  15811.0      510.176941
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  543.020264        495.929718        502.991425  ...
# 110002                  549.247253        513.304749        512.975891  ...
# 110003                  506.685181        466.007416        484.924988  ...
# 110004                  549.739380        513.924805        524.946716  ...
# 110005                  551.494751        498.394745        493.949310  ...
# ...                            ...               ...               ...  ...
# 522200                  522.414612        493.386505        503.091766  ...
# 522205                  498.125641        463.625641        479.803223  ...
# 522220                  513.099976        450.394440        504.899994  ...
# 522230                  498.101593        463.396820        471.051666  ...
# 530010                  580.567993        546.609680        552.578613  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                           0                    0                    0
# 110002                           1                    0                    1
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110005                           0                    0                    0
# ...                            ...                  ...                  ...
# 522200                           0                    0                    0
# 522205                           1                    0                    1
# 522220                           0                    1                    1
# 522230                           0                    1                    0
# 530010                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
# ...                                   ...        ...         ...        ...
# 522200                                  0          0           1          0
# 522205                                  0          0           0          1
# 522220                                  0          0           0          0
# 522230                                  0          0           0          0
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110001                       0                                167
# 110002                       0                               1058
# 110003                       0                                 50
# 110004                       0                                987
# 110005                       0                                181
# ...                        ...                                ...
# 522200                       0                                150
# 522205                       0                                 47
# 522220                       0                                 22
# 522230                       0                                 25
# 530010                       0                              47504
#
#                     prediction_label
# cod_municipio_ibge
# 110001                        230.73
# 110002                       1443.61
# 110003                         55.36
# 110004                       1304.79
# 110005                        212.12
# ...                              ...
# 522200                        113.18
# 522205                         82.81
# 522220                         40.39
# 522230                         50.98
# 530010                      63716.54
#
# [5570 rows x 32 columns]

# %%
plt.scatter(pred_2018_2019['qtd_abertas_Empresario_Individual'],pred_2018_2019['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %%
pred_2018_2019.to_excel('previsao_mape_2018_2019.xlsx')

# %% [markdown]
# ## Clusterização

# %% [markdown]
# ###  K-means 2022

# %%
df_c_22 = df

# %%
df_c_22 = df.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         8.0       926.0               8.958074
# 110002                        38.0      2563.0              21.363407
# 110003                         0.0       344.0               5.407539
# 110004                        21.0      1971.0              19.480189
# 110005                         3.0       591.0               8.540527
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              70.647540                     2.0
# 110002                              93.858639                    99.0
# 110003                              78.369844                     0.0
# 110004                             105.350861                   184.0
# 110005                             108.074341                     4.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     30.0      497.721951
# 110002                                    342.0      474.773986
# 110003                                      0.0      477.266667
# 110004                                    422.0      489.744000
# 110005                                     35.0      479.268750
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  504.034091        491.079545        543.558537  ...
# 110002                  495.727950        484.710248        518.811149  ...
# 110003                  486.071429        447.628571        522.883333  ...
# 110004                  505.006061        490.991919        533.458933  ...
# 110005                  477.045714        454.722857        480.696875  ...
#
#                     Reducao_ISSQN_Sim  Isencao_ISSQN_Sim  Isencao_Tx_Sim  \
# cod_municipio_ibge
# 110001                              0                  0               0
# 110002                              0                  0               1
# 110003                              0                  1               0
# 110004                              1                  0               1
# 110005                              0                  0               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima
# cod_municipio_ibge
# 110001                       0
# 110002                       0
# 110003                       0
# 110004                       0
# 110005                       0
#
# [5 rows x 30 columns]

# %%
df_c_22 = df_c_22.astype('int64')

# %%
df_c_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   taxa_homicidio                 5570 non-null   int64
#  1   RH_adm_dir                     5570 non-null   int64
#  2   densidade_banda_larga          5570 non-null   int64
#  3   densidade_telefonia_movel      5570 non-null   int64
#  4   qtd_cursos_engenharias         5570 non-null   int64
#  5   qtd_cursos_negocios_direito    5570 non-null   int64
#  6   media_notas_CN                 5570 non-null   int64
#  7   media_notas_CH                 5570 non-null   int64
#  8   media_NU_NOTA_LC               5570 non-null   int64
#  9   media_NU_NOTA_MT               5570 non-null   int64
#  10  media_NU_NOTA_REDACAO          5570 non-null   int64
#  11  valor_medio_recebido_familia   5570 non-null   int64
#  12  pib_per_capita_preco_corrente  5570 non-null   int64
#  13  perc_20_59_anos                5570 non-null   int64
#  14  pop_total                      5570 non-null   int64
#  15  total_sim_tecnologia           5570 non-null   int64
#  16  porte_municipio                5570 non-null   int64
#  17  Mecanismos_incentivo_Sim       5570 non-null   int64
#  18  Reducao_IPTU_Sim               5570 non-null   int64
#  19  Isencao_IPTU_Sim               5570 non-null   int64
#  20  Reducao_ISSQN_Sim              5570 non-null   int64
#  21  Isencao_ISSQN_Sim              5570 non-null   int64
#  22  Isencao_Tx_Sim                 5570 non-null   int64
#  23  Cessao_terrenos_Sim            5570 non-null   int64
#  24  Doacao_terrenos_Sim            5570 non-null   int64
#  25  Outros_mecanismos_Sim          5570 non-null   int64
#  26  ISH_Baixa                      5570 non-null   int64
#  27  ISH_Máxima                     5570 non-null   int64
#  28  ISH_Média                      5570 non-null   int64
#  29  ISH_Mínima                     5570 non-null   int64
# dtypes: int64(30)
# memory usage: 1.4 MB

# %%
valores_k =[]
inercias =[]

for i in range(1,15):
    cluster_empr = KMeans(n_clusters=i, random_state=42).fit(df_c_22)
    valores_k.append(i)
    inercias.append(cluster_empr.inertia_)

# %%
fig, ax = plt.subplots()

ax.plot(valores_k,inercias)

plt.show()

# %%
cluster_empr_22 = KMeans(n_clusters=3, random_state=42).fit(df_c_22)

# %%
cluster_empr_22.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
fig, ax = plt.subplots(figsize= (15,10))

ax.scatter(df_c_22.iloc[:,1], df_c_22.iloc[:,0], c = cluster_empr_22.labels_)

plt.show()

# %%
df_c_22['cluster'] = cluster_empr_22.labels_

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster
# cod_municipio_ibge
# 110001                       0          0           0        0
# 110002                       0          1           0        0
# 110003                       0          0           0        0
# 110004                       0          0           0        0
# 110005                       0          0           0        0
#
# [5 rows x 31 columns]

# %%
df_c_22= df_c_22.drop('porte_municipio', axis = 1)

# %%
col_empr = df['qtd_abertas_Empresario_Individual']
display(col_empr)
  
df_c_22 = df_c_22.join(col_empr )
# Out:
# cod_municipio_ibge
# 110001      194
# 110002     1275
# 110003       49
# 110004     1258
# 110005      257
#           ...
# 522200      222
# 522205       66
# 522220       23
# 522230       47
# 530010    54325
# Name: qtd_abertas_Empresario_Individual, Length: 5570, dtype: int64

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                           0                    0                    0
# 110002                           1                    0                    1
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110005                           0                    0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima  cluster  qtd_abertas_Empresario_Individual
# cod_municipio_ibge
# 110001                       0        0                                194
# 110002                       0        0                               1275
# 110003                       0        0                                 49
# 110004                       0        0                               1258
# 110005                       0        0                                257
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Kmeans - 2019

# %%
df_c_19 = df_2

# %%
df_c_19 = df_c_19.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %%
df_c_19.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382994
# 110005                         2.0       591.0               7.847822
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342994                     6.0
# 110002                              86.588543                    42.0
# 110003                              79.838102                     0.0
# 110004                              89.462154                   202.0
# 110005                              89.952827                     0.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664286
# 110002                                    299.0      481.314239
# 110003                                      0.0      442.604167
# 110004                                    469.0      484.990720
# 110005                                     38.0      466.433803
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  543.020270        495.929730        502.991429  ...
# 110002                  549.247267        513.304727        512.975890  ...
# 110003                  506.685185        466.007407        484.925000  ...
# 110004                  549.739357        513.924809        524.946720  ...
# 110005                  551.494737        498.394737        493.949296  ...
#
#                     Reducao_ISSQN_Sim  Isencao_ISSQN_Sim  Isencao_Tx_Sim  \
# cod_municipio_ibge
# 110001                              0                  0               0
# 110002                              0                  0               1
# 110003                              0                  1               0
# 110004                              1                  0               1
# 110005                              0                  0               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima
# cod_municipio_ibge
# 110001                       0
# 110002                       0
# 110003                       0
# 110004                       0
# 110005                       0
#
# [5 rows x 30 columns]

# %%
df_c_19 = df_c_19.astype('int64')

# %%
df_c_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   taxa_homicidio                 5570 non-null   int64
#  1   RH_adm_dir                     5570 non-null   int64
#  2   densidade_banda_larga          5570 non-null   int64
#  3   densidade_telefonia_movel      5570 non-null   int64
#  4   qtd_cursos_engenharias         5570 non-null   int64
#  5   qtd_cursos_negocios_direito    5570 non-null   int64
#  6   media_notas_CN                 5570 non-null   int64
#  7   media_notas_CH                 5570 non-null   int64
#  8   media_NU_NOTA_LC               5570 non-null   int64
#  9   media_NU_NOTA_MT               5570 non-null   int64
#  10  media_NU_NOTA_REDACAO          5570 non-null   int64
#  11  valor_medio_recebido_familia   5570 non-null   int64
#  12  pib_per_capita_preco_corrente  5570 non-null   int64
#  13  perc_20_59_anos                5570 non-null   int64
#  14  pop_total                      5570 non-null   int64
#  15  total_sim_tecnologia           5570 non-null   int64
#  16  porte_municipio                5570 non-null   int64
#  17  Mecanismos_incentivo_Sim       5570 non-null   int64
#  18  Reducao_IPTU_Sim               5570 non-null   int64
#  19  Isencao_IPTU_Sim               5570 non-null   int64
#  20  Reducao_ISSQN_Sim              5570 non-null   int64
#  21  Isencao_ISSQN_Sim              5570 non-null   int64
#  22  Isencao_Tx_Sim                 5570 non-null   int64
#  23  Cessao_terrenos_Sim            5570 non-null   int64
#  24  Doacao_terrenos_Sim            5570 non-null   int64
#  25  Outros_mecanismos_Sim          5570 non-null   int64
#  26  ISH_Baixa                      5570 non-null   int64
#  27  ISH_Máxima                     5570 non-null   int64
#  28  ISH_Média                      5570 non-null   int64
#  29  ISH_Mínima                     5570 non-null   int64
# dtypes: int64(30)
# memory usage: 1.4 MB

# %%
valores_k =[]
inercias =[]

for i in range(1,15):
    cluster_empr = KMeans(n_clusters=i, random_state=42).fit(df_c_19)
    valores_k.append(i)
    inercias.append(cluster_empr.inertia_)

# %%
fig, ax = plt.subplots()

ax.plot(valores_k,inercias)

plt.show()

# %%
cluster_empr_19 = KMeans(n_clusters=3, random_state=42).fit(df_c_19)

# %%
cluster_empr_19.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
#verificar se eu dividi as posições de x e y corretamente

fig, ax = plt.subplots(figsize= (15,10))

ax.scatter(df_c_19.iloc[:,1], df_c_19.iloc[:,0], c = cluster_empr_19.labels_)

plt.show()

# %%
df_c_19['cluster'] = cluster_empr_19.labels_

# %%
df_c_19.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           7         926                      5
# 110002                          41        2563                     11
# 110003                           0         344                      3
# 110004                          17        1971                     12
# 110005                           2         591                      7
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     34                       6
# 110002                                     86                      42
# 110003                                     79                       0
# 110004                                     89                     202
# 110005                                     89                       0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       23             480
# 110002                                      299             481
# 110003                                        0             442
# 110004                                      469             484
# 110005                                       38             466
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         543               495               502  ...
# 110002                         549               513               512  ...
# 110003                         506               466               484  ...
# 110004                         549               513               524  ...
# 110005                         551               498               493  ...
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster
# cod_municipio_ibge
# 110001                       0          0           0        0
# 110002                       0          1           0        0
# 110003                       0          0           0        0
# 110004                       0          0           0        0
# 110005                       0          0           0        0
#
# [5 rows x 31 columns]

# %%
df_c_19= df_c_19.drop('porte_municipio', axis = 1)

# %%
col_empr = df_2['qtd_abertas_Empresario_Individual']
display(col_empr)
  
df_c_19 = df_c_19.join(col_empr )
# Out:
# cod_municipio_ibge
# 110001      167
# 110002     1058
# 110003       50
# 110004      987
# 110005      181
#           ...
# 522200      150
# 522205       47
# 522220       22
# 522230       25
# 530010    47504
# Name: qtd_abertas_Empresario_Individual, Length: 5570, dtype: int64

# %% [markdown]
# ## Treinando o modelo com Cluster

# %% [markdown]
# ### 2022

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  cluster_1  \
# cod_municipio_ibge
# 110001                       0                                194          0
# 110002                       0                               1275          0
# 110003                       0                                 49          0
# 110004                       0                               1258          0
# 110005                       0                                257          0
#
#                     cluster_2
# cod_municipio_ibge
# 110001                      0
# 110002                      0
# 110003                      0
# 110004                      0
# 110005                      0
#
# [5 rows x 32 columns]

# %%
df_c_22 = pd.get_dummies(df_c_22, columns = ['cluster_1'], drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 df_c_22 = pd.get_dummies(df_c_22, columns = ['cluster'], drop_first=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\encoding.py:146, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     144     raise TypeError("Input must be a list-like for parameter `columns`")
#     145 else:
# --> 146     data_to_encode = data[columns]
#     148 # validate prefixes and separator to avoid silently dropping cols
#     149 def check_len(item, name):
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['cluster'], dtype='object')] are in the [columns]"

# %%
df_c_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     5570 non-null   int64
#  1   RH_adm_dir                         5570 non-null   int64
#  2   densidade_banda_larga              5570 non-null   int64
#  3   densidade_telefonia_movel          5570 non-null   int64
#  4   qtd_cursos_engenharias             5570 non-null   int64
#  5   qtd_cursos_negocios_direito        5570 non-null   int64
#  6   media_notas_CN                     5570 non-null   int64
#  7   media_notas_CH                     5570 non-null   int64
#  8   media_NU_NOTA_LC                   5570 non-null   int64
#  9   media_NU_NOTA_MT                   5570 non-null   int64
#  10  media_NU_NOTA_REDACAO              5570 non-null   int64
#  11  valor_medio_recebido_familia       5570 non-null   int64
#  12  pib_per_capita_preco_corrente      5570 non-null   int64
#  13  perc_20_59_anos                    5570 non-null   int64
#  14  pop_total                          5570 non-null   int64
#  15  total_sim_tecnologia               5570 non-null   int64
#  16  Mecanismos_incentivo_Sim           5570 non-null   int64
#  17  Reducao_IPTU_Sim                   5570 non-null   int64
#  18  Isencao_IPTU_Sim                   5570 non-null   int64
#  19  Reducao_ISSQN_Sim                  5570 non-null   int64
#  20  Isencao_ISSQN_Sim                  5570 non-null   int64
#  21  Isencao_Tx_Sim                     5570 non-null   int64
#  22  Cessao_terrenos_Sim                5570 non-null   int64
#  23  Doacao_terrenos_Sim                5570 non-null   int64
#  24  Outros_mecanismos_Sim              5570 non-null   int64
#  25  ISH_Baixa                          5570 non-null   int64
#  26  ISH_Máxima                         5570 non-null   int64
#  27  ISH_Média                          5570 non-null   int64
#  28  ISH_Mínima                         5570 non-null   int64
#  29  qtd_abertas_Empresario_Individual  5570 non-null   int64
#  30  cluster_1                          5570 non-null   uint8
#  31  cluster_2                          5570 non-null   uint8
# dtypes: int64(30), uint8(2)
# memory usage: 1.5 MB

# %%
treino_clus = df_c_22.groupby('cluster_1', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste_clus = df_c_22.drop(treino_clus.index)

print(treino_clus.shape, teste_clus.shape)
# Out:
# (4178, 32) (1392, 32)

# %%
#treino_clus = pd.get_dummies(treino_clus, columns = ['cluster'], drop_first=True)
#teste_clus = pd.get_dummies(teste_clus, columns = ['cluster'], drop_first=True)

# %%
teste_clus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1392 entries, 110003 to 522220
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     1392 non-null   int64
#  1   RH_adm_dir                         1392 non-null   int64
#  2   densidade_banda_larga              1392 non-null   int64
#  3   densidade_telefonia_movel          1392 non-null   int64
#  4   qtd_cursos_engenharias             1392 non-null   int64
#  5   qtd_cursos_negocios_direito        1392 non-null   int64
#  6   media_notas_CN                     1392 non-null   int64
#  7   media_notas_CH                     1392 non-null   int64
#  8   media_NU_NOTA_LC                   1392 non-null   int64
#  9   media_NU_NOTA_MT                   1392 non-null   int64
#  10  media_NU_NOTA_REDACAO              1392 non-null   int64
#  11  valor_medio_recebido_familia       1392 non-null   int64
#  12  pib_per_capita_preco_corrente      1392 non-null   int64
#  13  perc_20_59_anos                    1392 non-null   int64
#  14  pop_total                          1392 non-null   int64
#  15  total_sim_tecnologia               1392 non-null   int64
#  16  Mecanismos_incentivo_Sim           1392 non-null   int64
#  17  Reducao_IPTU_Sim                   1392 non-null   int64
#  18  Isencao_IPTU_Sim                   1392 non-null   int64
#  19  Reducao_ISSQN_Sim                  1392 non-null   int64
#  20  Isencao_ISSQN_Sim                  1392 non-null   int64
#  21  Isencao_Tx_Sim                     1392 non-null   int64
#  22  Cessao_terrenos_Sim                1392 non-null   int64
#  23  Doacao_terrenos_Sim                1392 non-null   int64
#  24  Outros_mecanismos_Sim              1392 non-null   int64
#  25  ISH_Baixa                          1392 non-null   int64
#  26  ISH_Máxima                         1392 non-null   int64
#  27  ISH_Média                          1392 non-null   int64
#  28  ISH_Mínima                         1392 non-null   int64
#  29  qtd_abertas_Empresario_Individual  1392 non-null   int64
#  30  cluster_1                          1392 non-null   uint8
#  31  cluster_2                          1392 non-null   uint8
# dtypes: int64(30), uint8(2)
# memory usage: 339.8 KB

# %%
treino_clus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4178 entries, 316447 to 330455
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     4178 non-null   int64
#  1   RH_adm_dir                         4178 non-null   int64
#  2   densidade_banda_larga              4178 non-null   int64
#  3   densidade_telefonia_movel          4178 non-null   int64
#  4   qtd_cursos_engenharias             4178 non-null   int64
#  5   qtd_cursos_negocios_direito        4178 non-null   int64
#  6   media_notas_CN                     4178 non-null   int64
#  7   media_notas_CH                     4178 non-null   int64
#  8   media_NU_NOTA_LC                   4178 non-null   int64
#  9   media_NU_NOTA_MT                   4178 non-null   int64
#  10  media_NU_NOTA_REDACAO              4178 non-null   int64
#  11  valor_medio_recebido_familia       4178 non-null   int64
#  12  pib_per_capita_preco_corrente      4178 non-null   int64
#  13  perc_20_59_anos                    4178 non-null   int64
#  14  pop_total                          4178 non-null   int64
#  15  total_sim_tecnologia               4178 non-null   int64
#  16  Mecanismos_incentivo_Sim           4178 non-null   int64
#  17  Reducao_IPTU_Sim                   4178 non-null   int64
#  18  Isencao_IPTU_Sim                   4178 non-null   int64
#  19  Reducao_ISSQN_Sim                  4178 non-null   int64
#  20  Isencao_ISSQN_Sim                  4178 non-null   int64
#  21  Isencao_Tx_Sim                     4178 non-null   int64
#  22  Cessao_terrenos_Sim                4178 non-null   int64
#  23  Doacao_terrenos_Sim                4178 non-null   int64
#  24  Outros_mecanismos_Sim              4178 non-null   int64
#  25  ISH_Baixa                          4178 non-null   int64
#  26  ISH_Máxima                         4178 non-null   int64
#  27  ISH_Média                          4178 non-null   int64
#  28  ISH_Mínima                         4178 non-null   int64
#  29  qtd_abertas_Empresario_Individual  4178 non-null   int64
#  30  cluster_1                          4178 non-null   uint8
#  31  cluster_2                          4178 non-null   uint8
# dtypes: int64(30), uint8(2)
# memory usage: 1020.0 KB

# %% [markdown]
# ### Pycaret

# %% [markdown]
# #### RMSE

# %%
regression_setup = setup(data = treino_clus, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T
td>
#     </tr>
#     <tr>
#       <th id="T_35f42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35f42_row3_col0" class="data row3 col0" >112.3043</td>
#       <td id="T_35f42_row3_col1" class="data row3 col1" >125849.3498</td>
#       <td id="T_35f42_row3_col2" class="data row3 col2" >354.7525</td>
#       <td id="T_35f42_row3_col3" class="data row3 col3" >0.9742</td>
#       <td id="T_35f42_row3_col4" class="data row3 col4" >0.7664</td>
#       <td id="T_35f42_row3_col5" class="data row3 col5" >0.8016</td>
#     </tr>
#     <tr>
#       <th id="T_35f42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35f42_row4_col0" class="data row4 col0" >124.9786</td>
#       <td id="T_35f42_row4_col1" class="data row4 col1" >117847.2313</td>
#       <td id="T_35f42_row4_col2" class="data row4 col2" >343.2888</td>
#       <td id="T_35f42_row4_col3" class="data row4 col3" >0.9851</td>
#       <td id="T_35f42_row4_col4" class="data row4 col4" >0.7205</td>
#       <td id="T_35f42_row4_col5" class="data row4 col5" >0.7044</td>
#     </tr>
#     <tr>
#       <th id="T_35f42_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_35f42_row5_col0" class="data row5 col0" >125.8326</td>
#       <td id="T_35f42_row5_col1" class="data row5 col1" >165715.5630</td>
#       <td id="T_35f42_row5_col2" class="data row5 col2" >403.6358</td>
#       <td id="T_35f42_row5_col3" class="data row5 col3" >0.9699</td>
#       <td id="T_35f42_row5_col4" class="data row5 col4" >0.7368</td>
#       <td id="T_35f42_row5_col5" class="data row5 col5" >0.7505</td>
#     </tr>
#     <tr>
#       <th id="T_35f42_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_35f42_row6_col0" class="data row6 col0" >10.1890</td>
#       <td id="T_35f42_row6_col1" class="data row6 col1" >44033.4134</td>
#       <td id="T_35f42_row6_col2" class="data row6 col2" >52.8554</td>
#       <td id="T_35f42_row6_col3" class="data row6 col3" >0.0213</td>
#       <td id="T_35f42_row6_col4" class="data row6 col4" >0.0351</td>
#       <td id="T_35f42_row6_col5" class="data row6 col5" >0.0518</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
print(tuned_clus)
# Out:
# HuberRegressor(alpha=0.7, epsilon=1.5)

# %%
plot_model(tuned_clus, plot='feature')

# %%
final_model_baseline_rmse_clus = finalize_model(tuned_clus)

# %% [markdown]
# ### Previsão - RMSE 2022

# %%
pred_teste_clus = predict_model(final_model_baseline_rmse_clus, data = teste_clus)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4170a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4170a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4170a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4170a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4170a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4170a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4170a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4170a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4170a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4170a_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_4170a_row0_col1" class="data row0 col1" >142.8904</td>
#       <td id="T_4170a_row0_col2" class="data row0 col2" >259517.1425</td>
#       <td id="T_4170a_row0_col3" class="data row0 col3" >509.4283</td>
#       <td id="T_4170a_row0_col4" class="data row0 col4" >0.9166</td>
#       <td id="T_4170a_row0_col5" class="data row0 col5" >0.6831</td>
#       <td id="T_4170a_row0_col6" class="data row0 col6" >0.7324</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_teste_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110009                           7         893                     10
# 110015                           6        1425                     12
# 110020                         145       12963                     23
# ...                            ...         ...                    ...
# 522040                           3        1064                     17
# 522150                           3         296                      1
# 522157                           0         209                      3
# 522160                          15        1180                     12
# 522220                           0         403                      1
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110003                                     78                       0
# 110004                                    105                     184
# 110009                                     60                       0
# 110015                                    111                      18
# 110020                                    106                     424
# ...                                       ...                     ...
# 522040                                     84                       0
# 522150                                     87                       0
# 522157                                     81                       0
# 522160                                    112                      50
# 522220                                     66                       0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110003                                        0             477
# 110004                                      422             489
# 110009                                       22             461
# 110015                                       60             458
# 110020                                     1595             473
# ...                                         ...             ...
# 522040                                       13             454
# 522150                                        0             418
# 522157                                        0             430
# 522160                                      146             477
# 522220                                        0             431
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110009                         469               466               502  ...
# 110015                         476               470               507  ...
# 110020                         496               482               511  ...
# ...                            ...               ...               ...  ...
# 522040                         472               466               498  ...
# 522150                         419               414               436  ...
# 522157                         435               486               514  ...
# 522160                         502               493               523  ...
# 522220                         443               426               445  ...
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110009                                0                      0          0
# 110015                                0                      0          0
# 110020                                0                      0          1
# ...                                 ...                    ...        ...
# 522040                                1                      0          0
# 522150                                1                      0          0
# 522157                                0                      0          0
# 522160                                0                      0          0
# 522220                                1                      0          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster_1  cluster_2  \
# cod_municipio_ibge
# 110003                       0          0           0          0          0
# 110004                       0          0           0          0          0
# 110009                       0          1           0          0          0
# 110015                       0          0           0          0          0
# 110020                       0          0           0          0          0
# ...                        ...        ...         ...        ...        ...
# 522040                       0          0           0          0          0
# 522150                       0          0           0          0          0
# 522157                       0          1           0          0          0
# 522160                       0          0           0          0          0
# 522220                       0          0           0          0          0
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110003                                             49         61.908737
# 110004                                           1258       1872.515735
# 110009                                            319        350.396314
# 110015                                            461        449.792046
# 110020                                           7893       8911.937677
# ...                                               ...               ...
# 522040                                            231        214.793712
# 522150                                             25         62.069422
# 522157                                             14         31.470971
# 522160                                            587        754.049971
# 522220                                             23         58.778298
#
# [1392 rows x 33 columns]

# %%
plt.scatter(pred_teste_clus['qtd_abertas_Empresario_Individual'],pred_teste_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ### Previsão - RMSE 2019

# %%
pred_2018_2019 = predict_model(final_model_baseline_rmse_clus, data = df_c_19)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[267], line 1
# ----> 1 pred_2018_2019 = predict_model(final_model_baseline_rmse_clus, data = df_c_19)
#
# File ~\anaconda3\lib\site-packages\pycaret\regression\functional.py:1917, in predict_model(estimator, data, round, verbose)
#    1914 if experiment is None:
#    1915     experiment = _EXPERIMENT_CLASS()
# -> 1917 return experiment.predict_model(
#    1918     estimator=estimator,
#    1919     data=data,
#    1920     round=round,
#    1921     verbose=verbose,
#    1922 )
#
# File ~\anaconda3\lib\site-packages\pycaret\regression\oop.py:2210, in RegressionExperiment.predict_model(self, estimator, data, round, verbose)
#    2156 def predict_model(
#    2157     self,
#    2158     estimator,
#    (...)
#    2161     verbose: bool = True,
#    2162 ) -> pd.DataFrame:
#    2163     """
#    2164     This function predicts ``Label`` using a trained model. When ``data`` is
#    2165     None, it predicts label on the holdout set.
#    (...)
#    2207
#    2208     """
# -> 2210     return super().predict_model(
#    2211         estimator=estimator,
#    2212         data=data,
#    2213         probability_threshold=None,
#    2214         encoded_labels=False,
#    2215         round=round,
#    2216         verbose=verbose,
#    2217     )
#
# File ~\anaconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4930, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4928 X_test_untransformed = data
#    4929 y_test_untransformed = target
# -> 4930 data = data[X_columns]  # Ignore all columns but the originals
#    4931 if preprocess:
#    4932     X_test_ = pipeline.transform(
#    4933         X=data,
#    4934         y=(target if preprocess != "features" else None),
#    4935     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['cluster_1', 'cluster_2'] not in index"

# %%
pred_2018_2019

# %%
plt.scatter(pred_2018_2019_clus['qtd_abertas_Empresario_Individual'],pred_2018_2019_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')

# %% [markdown]
# ### MAPE

# %%
regression_setup = setup(data = treino_clus, target = 'qtd_abertas_Empresario_Individual', session_id = 42)

# %%
best_model_clus = compare_models(sort = 'MAPE', fold=5)

# %%
print(best_model_clus)

# %%
best_model_clus = create_model('rf', fold = 5)

# %%
tuned_clus = tune_model(best_model_clus, fold = 5)

# %%
print(tuned_clus)

# %%
plot_model(best_model_clus, plot='feature')

# %%
final_model_baseline_mape_clus = finalize_model(best_model_clus)

# %% [markdown]
# ### Previsão - Mape 2022

# %%
pred_teste_clus = predict_model(final_model_baseline_mape_clus, data = teste_clus)

# %%
pred_teste_clus

# %%
plt.scatter(pred_teste_clus['qtd_abertas_Empresario_Individual'],pred_teste_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')

# %% [markdown]
# ### Previsão - Mape 2019

# %%
pred_2018_2019_clus = predict_model(final_model_baseline_mape_clus, data = df_c_19)

# %%
pred_2018_2019_clus

# %%
plt.scatter(pred_2018_2019_clus['qtd_abertas_Empresario_Individual'],pred_2018_2019_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
