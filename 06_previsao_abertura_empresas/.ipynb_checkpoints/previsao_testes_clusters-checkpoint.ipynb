# %% [markdown]
# # Instalando o Pycaret

# %%
#!pip install pycaret

# %%
#!pip install scipy

# %%
# Importando bibliotecas necessárias
import pandas as pd
import sweetviz as sv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import shap
from pycaret.regression import *
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from sklearn.cluster import KMeans 
from sklearn.feature_extraction import FeatureHasher

# %% [markdown]
# # Tratando a base

# %%
df= pd.read_excel("Base_2022_2023.xlsx")

# %%
df = df[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','taxa_homicidio','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','qtd_cursos_engenharias',
    'qtd_cursos_negocios_direito','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
df.head()
# Out:
#    cod_municipio_ibge  qtd_abertas_Empresario_Individual Mecanismos_incentivo  \
# 0              110001                                194                  Não
# 1              110002                               1275                  Sim
# 2              110003                                 49                  Sim
# 3              110004                               1258                  Sim
# 4              110005                                257                  Sim
#
#   Reducao_IPTU Isencao_IPTU Reducao_ISSQN Isencao_ISSQN Isencao_Tx  \
# 0          NaN          NaN           NaN           NaN        NaN
# 1          Sim          Sim           Não           Não        Sim
# 2          Não          Não           Não           Sim        Não
# 3          Não          Sim           Sim           Não        Sim
# 4          Não          Sim           Não           Não        Não
#
#   Cessao_terrenos Doacao_terrenos  ... media_notas_CH  media_NU_NOTA_LC  \
# 0             NaN             NaN  ...     504.034091        491.079545
# 1             Não             Sim  ...     495.727950        484.710248
# 2             Não             Não  ...     486.071429        447.628571
# 3             Sim             Sim  ...     505.006061        490.991919
# 4             Não             Não  ...     477.045714        454.722857
#
#    media_NU_NOTA_MT media_NU_NOTA_REDACAO  valor_medio_recebido_familia  \
# 0        543.558537            621.363636                         18495
# 1        518.811149            584.534161                         17615
# 2        522.883333            471.428571                         18956
# 3        533.458933            611.717172                         19376
# 4        480.696875            576.571429                         17752
#
#    pib_per_capita_preco_corrente  perc_20_59_anos  pop_total  \
# 0                       25091.18         0.587227      22516
# 1                       25730.20         0.591797     111148
# 2                       32226.25         0.584567       5067
# 3                       29331.29         0.595584      86416
# 4                       37069.25         0.598272      16088
#
#    total_sim_tecnologia  porte_municipio
# 0                  18.0                2
# 1                  12.0                4
# 2                   8.0                1
# 3                  17.0                3
# 4                   8.0                2
#
# [5 rows x 29 columns]

# %%
df['qtd_cursos_engenharias'] = df['qtd_cursos_engenharias'].fillna(0)

df['qtd_cursos_negocios_direito'] = df['qtd_cursos_negocios_direito'].fillna(0)

df['total_sim_tecnologia'] = df['total_sim_tecnologia'].fillna(0)

df['taxa_homicidio'] = df['taxa_homicidio'].fillna(0)

df['RH_adm_dir'] = df['RH_adm_dir'].fillna(0)

# %%
df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df = pd.get_dummies(df, columns = ['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','ISH'], drop_first=True)

# %%
df = df[np.isfinite(df).all(1)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   cod_municipio_ibge                 5570 non-null   int64
#  1   qtd_abertas_Empresario_Individual  5570 non-null   int64
#  2   taxa_homicidio                     5570 non-null   float64
#  3   RH_adm_dir                         5570 non-null   float64
#  4   densidade_banda_larga              5570 non-null   float64
#  5   densidade_telefonia_movel          5570 non-null   float64
#  6   qtd_cursos_engenharias             5570 non-null   float64
#  7   qtd_cursos_negocios_direito        5570 non-null   float64
#  8   media_notas_CN                     5570 non-null   float64
#  9   media_notas_CH                     5570 non-null   float64
#  10  media_NU_NOTA_LC                   5570 non-null   float64
#  11  media_NU_NOTA_MT                   5570 non-null   float64
#  12  media_NU_NOTA_REDACAO              5570 non-null   float64
#  13  valor_medio_recebido_familia       5570 non-null   int64
#  14  pib_per_capita_preco_corrente      5570 non-null   float64
#  15  perc_20_59_anos                    5570 non-null   float64
#  16  pop_total                          5570 non-null   int64
#  17  total_sim_tecnologia               5570 non-null   float64
#  18  porte_municipio                    5570 non-null   int64
#  19  Mecanismos_incentivo_Sim           5570 non-null   uint8
#  20  Reducao_IPTU_Sim                   5570 non-null   uint8
#  21  Isencao_IPTU_Sim                   5570 non-null   uint8
#  22  Reducao_ISSQN_Sim                  5570 non-null   uint8
#  23  Isencao_ISSQN_Sim                  5570 non-null   uint8
#  24  Isencao_Tx_Sim                     5570 non-null   uint8
#  25  Cessao_terrenos_Sim                5570 non-null   uint8
#  26  Doacao_terrenos_Sim                5570 non-null   uint8
#  27  Outros_mecanismos_Sim              5570 non-null   uint8
#  28  ISH_Baixa                          5570 non-null   uint8
#  29  ISH_Máxima                         5570 non-null   uint8
#  30  ISH_Média                          5570 non-null   uint8
#  31  ISH_Mínima                         5570 non-null   uint8
# dtypes: float64(14), int64(5), uint8(13)
# memory usage: 941.0 KB

# %%
df = df.set_index('cod_municipio_ibge')

# %%
df
# Out:
#                     qtd_abertas_Empresario_Individual  taxa_homicidio  \
# cod_municipio_ibge
# 110001                                            194             8.0
# 110002                                           1275            38.0
# 110003                                             49             0.0
# 110004                                           1258            21.0
# 110005                                            257             3.0
# ...                                               ...             ...
# 522200                                            222             1.0
# 522205                                             66             0.0
# 522220                                             23             0.0
# 522230                                             47             0.0
# 530010                                          54325           480.0
#
#                     RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                   926.0               8.958074
# 110002                  2563.0              21.363407
# 110003                   344.0               5.407539
# 110004                  1971.0              19.480189
# 110005                   591.0               8.540527
# ...                        ...                    ...
# 522200                   528.0               6.423907
# 522205                   394.0               8.442568
# 522220                   403.0               1.240118
# 522230                   344.0               7.187342
# 530010                122197.0              25.834035
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              70.647540                     2.0
# 110002                              93.858639                    99.0
# 110003                              78.369844                     0.0
# 110004                             105.350861                   184.0
# 110005                             108.074341                     4.0
# ...                                       ...                     ...
# 522200                             106.821408                     4.0
# 522205                             104.276827                     0.0
# 522220                              66.485816                     0.0
# 522230                              39.892274                     0.0
# 530010                             109.381529                  2210.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     30.0      497.721951
# 110002                                    342.0      474.773986
# 110003                                      0.0      477.266667
# 110004                                    422.0      489.744000
# 110005                                     35.0      479.268750
# ...                                         ...             ...
# 522200                                     12.0      449.954054
# 522205                                      0.0      450.285714
# 522220                                      0.0      431.645455
# 522230                                      0.0      432.055556
# 530010                                  13097.0      505.707532
#
#                     media_notas_CH  media_NU_NOTA_LC  ...  Reducao_ISSQN_Sim  \
# cod_municipio_ibge                                    ...
# 110001                  504.034091        491.079545  ...                  0
# 110002                  495.727950        484.710248  ...                  0
# 110003                  486.071429        447.628571  ...                  0
# 110004                  505.006061        490.991919  ...                  1
# 110005                  477.045714        454.722857  ...                  0
# ...                            ...               ...  ...                ...
# 522200                  479.917073        473.014634  ...                  0
# 522205                  464.383333        457.593333  ...                  0
# 522220                  443.025000        426.491667  ...                  0
# 522230                  417.394737        428.821053  ...                  0
# 530010                  534.044622        522.095562  ...                  0
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
# ...                               ...             ...                  ...
# 522200                              0               0                    0
# 522205                              0               1                    0
# 522220                              0               0                    1
# 522230                              0               0                    1
# 530010                              0               0                    1
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
# ...                                 ...                    ...        ...
# 522200                                0                      0          0
# 522205                                1                      0          0
# 522220                                1                      0          0
# 522230                                0                      0          0
# 530010                                0                      1          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima
# cod_municipio_ibge
# 110001                       0          0           0
# 110002                       0          1           0
# 110003                       0          0           0
# 110004                       0          0           0
# 110005                       0          0           0
# ...                        ...        ...         ...
# 522200                       1          0           0
# 522205                       0          1           0
# 522220                       0          0           0
# 522230                       0          0           0
# 530010                       0          0           0
#
# [5570 rows x 31 columns]

# %% [markdown]
# ## Nova base teste

# %%
df_2 = pd.read_excel("Base_novos_dados_2018_2019.xlsx")

# %%
df_2 = df_2[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','taxa_homicidio','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','qtd_cursos_engenharias',
    'qtd_cursos_negocios_direito','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
df_2['qtd_cursos_engenharias'] = df_2['qtd_cursos_engenharias'].fillna(0)

df_2['qtd_cursos_negocios_direito'] = df_2['qtd_cursos_negocios_direito'].fillna(0)

df_2['total_sim_tecnologia'] = df_2['total_sim_tecnologia'].fillna(0)

df_2['taxa_homicidio'] = df_2['taxa_homicidio'].fillna(0)

df_2['RH_adm_dir'] = df_2['RH_adm_dir'].fillna(0)

# %%
df_2[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df_2[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df_2[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df_2[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df_2 = pd.get_dummies(df_2, columns = ['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','ISH'], drop_first=True)

# %%
df_2 = df_2[np.isfinite(df_2).all(1)]

# %%
df_2 = df_2.set_index('cod_municipio_ibge')

# %% [markdown]
# # Dividindo em treino e test

# %% [markdown]
# Adaleny, fiz a divisão de treino e teste baseado na estratificação

# %%
treino = df.groupby('porte_municipio', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste = df.drop(treino.index)

print(treino.shape, teste.shape)
# Out:
# (4178, 31) (1392, 31)

# %%
treino = treino.drop('porte_municipio', axis = 1)
teste= teste.drop('porte_municipio', axis = 1)

# %% [markdown]
# treino = treino.drop('porte_municipio', axis = 1)
# teste= teste.drop('porte_municipio', axis = 1)

# %%
#teste= teste.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %% [markdown]
# treino.info()

# %% [markdown]
# # Pycaret

# %% [markdown]
# ## Setup

# %%
regression_setup = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_40144_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_40144">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40144_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_40144_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40144_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40144_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_40144_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40144_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_40144_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40144_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_40144_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40144_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_40144_row3_col1" class="data row3 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40144_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_40144_row4_col1" class="data row4 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40144_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_40144_row5_col1" class="data row5 col1" >(2924, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40144_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_40144_row6_col1" class="data row6 col1" >(1254, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40144_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_40144_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40144_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_40144_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_40144_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_40144_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_40144_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_40144_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_40144_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_40144_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_40144_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_40144_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_40144_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_40144_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_40144_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_40144_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_40144_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_40144_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_40144_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_40144_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_40144_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_40144_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_40144_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_40144_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_40144_row18_col1" class="data row18 col1" >bccc</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Comparando Modelos

# %% [markdown]
# ### Usando RMSE

# %%
best_model = compare_models(sort = 'RMSE', fold=5)
# Out:
# <style type="text/css">
# #T_32e66 th {
#   text-align: left;
# }
# #T_32e66_row0_col0, #T_32e66_row0_col5, #T_32e66_row0_col6, #T_32e66_row1_col0, #T_32e66_row1_col1, #T_32e66_row1_col2, #T_32e66_row1_col3, #T_32e66_row1_col4, #T_32e66_row1_col5, #T_32e66_row1_col6, #T_32e66_row2_col0, #T_32e66_row2_col1, #T_32e66_row2_col2, #T_32e66_row2_col3, #T_32e66_row2_col4, #T_32e66_row2_col5, #T_32e66_row2_col6, #T_32e66_row3_col0, #T_32e66_row3_col1, #T_32e66_row3_col2, #T_32e66_row3_col3, #T_32e66_row3_col4, #T_32e66_row3_col5, #T_32e66_row3_col6, #T_32e66_row4_col0, #T_32e66_row4_col1, #T_32e66_row4_col2, #T_32e66_row4_col3, #T_32e66_row4_col4, #T_32e66_row4_col5, #T_32e66_row4_col6, #T_32e66_row5_col0, #T_32e66_row5_col1, #T_32e66_row5_col2, #T_32e66_row5_col3, #T_32e66_row5_col4, #T_32e66_row5_col5, #T_32e66_row5_col6, #T_32e66_row6_col0, #T_32e66_row6_col1, #T_32e66_row6_col2, #T_32e66_row6_col3, #T_32e66_row6_col4, #T_32e66_row6_col5, #T_32e66_row6_col6, #T_32e66_row7_col0, #T_32e66_row7_col1, #T_32e66_row7_col2, #T_32e66_row7_col3, #T_32e66_row7_col4, #T_32e66_row7_col5, #T_32e66_row7_col6, #T_32e66_row8_col0, #T_32e66_row8_col1, #T_32e66_row8_col2, #T_32e66_row8_col3, #T_32e66_row8_col4, #T_32e66_row8_col5, #T_32e66_row8_col6, #T_32e66_row9_col0
>0.6571</td>
#     </tr>
#     <tr>
#       <th id="T_b5781_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5781_row1_col0" class="data row1 col0" >152.2660</td>
#       <td id="T_b5781_row1_col1" class="data row1 col1" >373452.7730</td>
#       <td id="T_b5781_row1_col2" class="data row1 col2" >611.1078</td>
#       <td id="T_b5781_row1_col3" class="data row1 col3" >0.8825</td>
#       <td id="T_b5781_row1_col4" class="data row1 col4" >0.6260</td>
#       <td id="T_b5781_row1_col5" class="data row1 col5" >0.5953</td>
#     </tr>
#     <tr>
#       <th id="T_b5781_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b5781_row2_col0" class="data row2 col0" >150.8734</td>
#       <td id="T_b5781_row2_col1" class="data row2 col1" >512538.5771</td>
#       <td id="T_b5781_row2_col2" class="data row2 col2" >715.9180</td>
#       <td id="T_b5781_row2_col3" class="data row2 col3" >0.9430</td>
#       <td id="T_b5781_row2_col4" class="data row2 col4" >0.7083</td>
#       <td id="T_b5781_row2_col5" class="data row2 col5" >0.7101</td>
#     </tr>
#     <tr>
#       <th id="T_b5781_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b5781_row3_col0" class="data row3 col0" >89.4697</td>
#       <td id="T_b5781_row3_col1" class="data row3 col1" >55167.1622</td>
#       <td id="T_b5781_row3_col2" class="data row3 col2" >234.8769</td>
#       <td id="T_b5781_row3_col3" class="data row3 col3" >0.9366</td>
#       <td id="T_b5781_row3_col4" class="data row3 col4" >0.6656</td>
#       <td id="T_b5781_row3_col5" class="data row3 col5" >0.6878</td>
#     </tr>
#     <tr>
#       <th id="T_b5781_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b5781_row4_col0" class="data row4 col0" >157.2604</td>
#       <td id="T_b5781_row4_col1" class="data row4 col1" >538828.3469</td>
#       <td id="T_b5781_row4_col2" class="data row4 col2" >734.0493</td>
#       <td id="T_b5781_row4_col3" class="data row4 col3" >0.9955</td>
#       <td id="T_b5781_row4_col4" class="data row4 col4" >0.7731</td>
#       <td id="T_b5781_row4_col5" class="data row4 col5" >0.9538</td>
#     </tr>
#     <tr>
#       <th id="T_b5781_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b5781_row5_col0" class="data row5 col0" >138.3505</td>
#       <td id="T_b5781_row5_col1" class="data row5 col1" >366711.5141</td>
#       <td id="T_b5781_row5_col2" class="data row5 col2" >578.1140</td>
#       <td id="T_b5781_row5_col3" class="data row5 col3" >0.9485</td>
#       <td id="T_b5781_row5_col4" class="data row5 col4" >0.6986</td>
#       <td id="T_b5781_row5_col5" class="data row5 col5" >0.7208</td>
#     </tr>
#     <tr>
#       <th id="T_b5781_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b5781_row6_col0" class="data row6 col0" >24.9394</td>
#       <td id="T_b5781_row6_col1" class="data row6 col1" >172143.9775</td>
#       <td id="T_b5781_row6_col2" class="data row6 col2" >180.2656</td>
#       <td id="T_b5781_row6_col3" class="data row6 col3" >0.0402</td>
#       <td id="T_b5781_row6_col4" class="data row6 col4" >0.0499</td>
#       <td id="T_b5781_row6_col5" class="data row6 col5" >0.1227</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### Plotando alguns graficos

# %%
#evaluate_model(best_model)

# %%
#plot_model(best_model, plot = 'learning')

# %%
#plot_model(best_model, plot='vc')

# %%
#plot_model(best_model, plot='error')

# %%
#plot_model(best_model, plot='feature')

# %%
#plot_model(best_model, plot='residuals',  scale = 3)

# %% [markdown]
# ### Tunando o modelo

# %%
tuned = tune_model(best_model, fold = 5)
# Out:
# <style type="text/css">
# #T_5d512_row5_col0, #T_5d512_row5_col1, #T_5d512_row5_col2, #T_5d512_row5_col3, #T_5d512_row5_col4, #T_5d512_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5d512">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d512_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5d512_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5d512_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5d512_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5d512_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5d512_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d512_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d512_row0_col0" class="data row0 col0" >141.0645</td>
#       <td id="T_5d512_row0_col1" class="data row0 col1" >329320.7964</td>
#       <td id="T_5d512_row0_col2" class="data row0 col2" >573.8648</td>
#       <td id="T_5d512_row0_col3" class="data row0 col3" >0.9861</td>
#       <td id="T_5d512_row0_col4" class="data row0 col4" >0.7124</td>
#       <td id="T_5d512_row0_col5" class="data row0 col5" >0.6766</td>
#     </tr>
#     <tr>
#       <th id="T_5d512_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5d512_row1_col0" class="data row1 col0" >153.0118</td>
#       <td id="T_5d512_row1_col1" class="data row1 col1" >375921.3360</td>
#       <td id="T_5d512_row1_col2" class="data row1 col2" >613.1242</td>
#       <td id="T_5d512_row1_col3" class="data row1 col3" >0.8817</td>
#       <td id="T_5d512_row1_col4" class="data row1 col4" >0.6539</td>
#       <td id="T_5d512_row1_col5" class="data row1 col5" >0.6034</td>
#     </tr>
#     <tr>
#       <th id="T_5d512_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5d512_row2_col0" class="data row2 col0" >150.4280</td>
#       <td id="T_5d512_row2_col1" class="data row2 col1" >497575.6228</td>
#       <td id="T_5d512_row2_col2" class="data row2 col2" >705.3904</td>
#       <td id="T_5d512_row2_col3" class="data row2 col3" >0.9446</td>
#       <td id="T_5d512_row2_col4" class="data row2 col4" >0.6997</td>
#       <td id="T_5d512_row2_col5" class="data row2 col5" >0.7065</td>
#     </tr>
#     <tr>
#       <th id="T_5d512_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5d512_row3_col0" class="data row3 col0" >89.7567</td>
#       <td id="T_5d512_row3_col1" class="data row3 col1" >55087.6462</td>
#       <td id="T_5d512_row3_col2" class="data row3 col2" >234.7076</td>
#       <td id="T_5d512_row3_col3" class="data row3 col3" >0.9367</td>
#       <td id="T_5d512_row3_col4" class="data row3 col4" >0.6430</td>
#       <td id="T_5d512_row3_col5" class="data row3 col5" >0.6916</td>
#     </tr>
#     <tr>
#       <th id="T_5d512_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5d512_row4_col0" class="data row4 col0" >155.8591</td>
#       <td id="T_5d512_row4_col1" class="data row4 col1" >543075.1470</td>
#       <td id="T_5d512_row4_col2" class="data row4 col2" >736.9363</td>
#       <td id="T_5d512_row4_col3" class="data row4 col3" >0.9954</td>
#       <td id="T_5d512_row4_col4" class="data row4 col4" >0.7712</td>
#       <td id="T_5d512_row4_col5" class="data row4 col5" >0.8733</td>
#     </tr>
#     <tr>
#       <th id="T_5d512_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5d512_row5_col0" class="data row5 col0" >138.0240</td>
#       <td id="T_5d512_row5_col1" class="data row5 col1" >360196.1097</td>
#       <td id="T_5d512_row5_col2" class="data row5 col2" >572.8047</td>
#       <td id="T_5d512_row5_col3" class="data row5 col3" >0.9489</td>
#       <td id="T_5d512_row5_col4" class="data row5 col4" >0.6960</td>
#       <td id="T_5d512_row5_col5" class="data row5 col5" >0.7103</td>
#     </tr>
#     <tr>
#       <th id="T_5d512_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5d512_row6_col0" class="data row6 col0" >24.6397</td>
#       <td id="T_5d512_row6_col1" class="data row6 col1" >171236.4535</td>
#       <td id="T_5d512_row6_col2" class="data row6 col2" >179.1394</td>
#       <td id="T_5d512_row6_col3" class="data row6 col3" >0.0406</td>
#       <td id="T_5d512_row6_col4" class="data row6 col4" >0.0459</td>
#       <td id="T_5d512_row6_col5" class="data row6 col5" >0.0889</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
print(tuned)
# Out:
# HuberRegressor(alpha=0.5, epsilon=1.7)

# %%
#plot_model(tuned, plot = 'learning')  #use_train_data = True

# %%
# Validation Curve
#plot_model(tuned, plot='vc')

# %%
#plot_model(tuned, plot='error')

# %%
#plot_model(tuned, plot='feature' )

# %%
#plot_model(tuned, plot='feature', save = True )

# %%
#plot_model(tuned, plot='residuals',  scale = 3)

# %%
final_model_baseline = finalize_model(tuned)

# %% [markdown]
# ### Previsão

# %%
pred_treino = predict_model(final_model_baseline, data = treino)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c0d67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0d67_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c0d67_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c0d67_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c0d67_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c0d67_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c0d67_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c0d67_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0d67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0d67_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_c0d67_row0_col1" class="data row0 col1" >131.7326</td>
#       <td id="T_c0d67_row0_col2" class="data row0 col2" >258644.3471</td>
#       <td id="T_c0d67_row0_col3" class="data row0 col3" >508.5709</td>
#       <td id="T_c0d67_row0_col4" class="data row0 col4" >0.9890</td>
#       <td id="T_c0d67_row0_col5" class="data row0 col5" >0.7048</td>
#       <td id="T_c0d67_row0_col6" class="data row0 col6" >0.7478</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_treino
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 270660                         6.0         0.0               0.463208
# 316730                         0.0       186.0              12.130569
# 251278                         0.0       260.0               8.554277
# 430870                         0.0       226.0              30.952818
# 314920                         0.0       369.0               5.450562
# ...                            ...         ...                    ...
# 355030                       454.0    127721.0              32.097408
# 291080                       264.0      5937.0              11.146967
# 430510                        86.0      7345.0              34.121548
# 330330                       165.0      3689.0              36.960739
# 355220                        63.0     11747.0              37.041367
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 270660                              33.152462                     0.0
# 316730                              67.534187                     0.0
# 251278                              66.133064                     0.0
# 430870                              88.121902                     0.0
# 314920                              94.467270                     0.0
# ...                                       ...                     ...
# 355030                             125.004189                 12809.0
# 291080                             125.226761                   494.0
# 430510                             101.562866                   484.0
# 330330                             125.476761                  1362.0
# 355220                             119.078194                  1831.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 270660                                      0.0      395.628571
# 316730                                      0.0      490.662506
# 251278                                      0.0      444.866669
# 430870                                      0.0      488.318176
# 314920                                      0.0      469.000000
# ...                                         ...             ...
# 355030                                  52259.0      515.010742
# 291080                                   1546.0      497.371368
# 430510                                   1699.0      520.229065
# 330330                                   2503.0      522.259460
# 355220                                   2692.0      514.474243
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 270660                  422.762512        445.825012        436.742859  ...
# 316730                  527.674988        496.262512        539.212524  ...
# 251278                  473.833344        443.799988        451.933319  ...
# 430870                  497.261536        469.307678        565.990906  ...
# 314920                  452.000000        449.950012        554.099976  ...
# ...                            ...               ...               ...  ...
# 355030                  548.616333        534.100159        581.029175  ...
# 291080                  523.909973        509.181915        543.344971  ...
# 430510                  556.289062        535.819946        581.916504  ...
# 330330                  556.662903        536.360840        592.505432  ...
# 355220                  546.214417        531.277527        577.488953  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 270660                           0                    0                    0
# 316730                           0                    0                    0
# 251278                           0                    1                    1
# 430870                           0                    0                    0
# 314920                           0                    0                    0
# ...                            ...                  ...                  ...
# 355030                           0                    0                    0
# 291080                           0                    0                    0
# 430510                           0                    0                    0
# 330330                           1                    0                    0
# 355220                           1                    0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 270660                                  0          1           0          0
# 316730                                  0          0           1          0
# 251278                                  0          1           0          0
# 430870                                  0          0           0          0
# 314920                                  0          0           0          0
# ...                                   ...        ...         ...        ...
# 355030                                  1          0           0          1
# 291080                                  0          0           0          0
# 430510                                  0          0           0          1
# 330330                                  0          1           0          0
# 355220                                  0          0           0          1
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 270660                       0                                 33
# 316730                       0                                 26
# 251278                       0                                 15
# 430870                       0                                 74
# 314920                       0                                 37
# ...                        ...                                ...
# 355030                       0                             253408
# 291080                       0                               9589
# 430510                       0                               9898
# 330330                       0                               9251
# 355220                       0                              17213
#
#                     prediction_label
# cod_municipio_ibge
# 270660                     50.239255
# 316730                     12.849264
# 251278                     -3.476766
# 430870                    102.689113
# 314920                     51.653274
# ...                              ...
# 355030                 253407.766344
# 291080                  10386.017573
# 430510                   9435.673314
# 330330                  12101.806259
# 355220                  14244.951267
#
# [4178 rows x 31 columns]

# %%
plt.scatter(pred_treino['qtd_abertas_Empresario_Individual'],pred_treino['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# Previsão de dados não vistos

# %%
pred_unseen = predict_model(final_model_baseline, data = teste)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bb9ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb9ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bb9ef_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bb9ef_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bb9ef_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bb9ef_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bb9ef_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bb9ef_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb9ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb9ef_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_bb9ef_row0_col1" class="data row0 col1" >122.8559</td>
#       <td id="T_bb9ef_row0_col2" class="data row0 col2" >134040.6877</td>
#       <td id="T_bb9ef_row0_col3" class="data row0 col3" >366.1157</td>
#       <td id="T_bb9ef_row0_col4" class="data row0 col4" >0.9622</td>
#       <td id="T_bb9ef_row0_col5" class="data row0 col5" >0.6865</td>
#       <td id="T_bb9ef_row0_col6" class="data row0 col6" >0.7617</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_unseen
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110005                         3.0       591.0               8.540527
# 110007                         1.0       382.0               3.261486
# 110008                         3.0       573.0               4.388471
# 110011                        10.0      1484.0              20.346228
# 110013                         6.0      1214.0               7.779695
# ...                            ...         ...                    ...
# 522100                         5.0       195.0               2.852253
# 522119                         4.0       271.0              10.329089
# 522190                         0.0       184.0               9.433472
# 522200                         1.0       528.0               6.423907
# 522230                         0.0       344.0               7.187342
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110005                             108.074341                     4.0
# 110007                              51.545662                     0.0
# 110008                              35.367435                     5.0
# 110011                             101.132721                     8.0
# 110013                              56.914486                     3.0
# ...                                       ...                     ...
# 522100                             103.565315                     0.0
# 522119                             116.298340                     0.0
# 522190                              78.092514                     0.0
# 522200                             106.821411                     4.0
# 522230                              39.892273                     0.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110005                                     35.0      479.268738
# 110007                                      0.0      439.184601
# 110008                                     12.0      438.418182
# 110011                                    114.0      472.343292
# 110013                                     26.0      460.839630
# ...                                         ...             ...
# 522100                                      0.0      464.779999
# 522119                                      0.0      435.885712
# 522190                                      0.0      426.950012
# 522200                                     12.0      449.954041
# 522230                                      0.0      432.055542
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110005                  477.045715        454.722870        480.696869  ...
# 110007                  466.414276        432.535706        445.276917  ...
# 110008                  465.692108        451.828949        478.290924  ...
# 110011                  501.169189        481.437683        507.111206  ...
# 110013                  482.138611        470.749115        485.543396  ...
# ...                            ...               ...               ...  ...
# 522100                  487.066681        474.000000        520.359985  ...
# 522119                  480.299988        450.257141        503.938110  ...
# 522190                  483.766663        451.266663        422.950012  ...
# 522200                  479.917084        473.014648        516.186462  ...
# 522230                  417.394745        428.821045        460.816681  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110005                           0                    0                    0
# 110007                           0                    1                    0
# 110008                           1                    1                    0
# 110011                           0                    0                    0
# 110013                           0                    0                    0
# ...                            ...                  ...                  ...
# 522100                           0                    0                    0
# 522119                           0                    1                    0
# 522190                           0                    0                    0
# 522200                           0                    0                    0
# 522230                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110005                                  0          1           0          0
# 110007                                  1          0           0          0
# 110008                                  0          1           0          0
# 110011                                  0          0           0          1
# 110013                                  1          1           0          0
# ...                                   ...        ...         ...        ...
# 522100                                  0          0           0          0
# 522119                                  0          0           1          0
# 522190                                  0          0           1          0
# 522200                                  0          0           1          0
# 522230                                  0          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110005                       0                                257
# 110007                       0                                 86
# 110008                       0                                106
# 110011                       0                                617
# 110013                       0                                279
# ...                        ...                                ...
# 522100                       0                                 41
# 522119                       0                                108
# 522190                       0                                 30
# 522200                       0                                222
# 522230                       0                                 47
#
#                     prediction_label
# cod_municipio_ibge
# 110005                    244.431312
# 110007                     38.251022
# 110008                    184.035830
# 110011                    749.728184
# 110013                    445.707551
# ...                              ...
# 522100                     52.918899
# 522119                    112.937606
# 522190                    114.281526
# 522200                    185.673619
# 522230                     54.298978
#
# [1392 rows x 31 columns]

# %%
plt.scatter(pred_unseen['qtd_abertas_Empresario_Individual'],pred_unseen['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ## Previsão - Novos dados (VIs = 2018 e VD = 2019)

# %%
pred_treino_2 = predict_model(final_model_baseline, data = df_2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_476ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_476ab_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_476ab_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_476ab_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_476ab_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_476ab_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_476ab_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_476ab_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_476ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_476ab_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_476ab_row0_col1" class="data row0 col1" >140.0121</td>
#       <td id="T_476ab_row0_col2" class="data row0 col2" >361851.6957</td>
#       <td id="T_476ab_row0_col3" class="data row0 col3" >601.5411</td>
#       <td id="T_476ab_row0_col4" class="data row0 col4" >0.9783</td>
#       <td id="T_476ab_row0_col5" class="data row0 col5" >0.7536</td>
#       <td id="T_476ab_row0_col6" class="data row0 col6" >1.0564</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_treino_2
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382995
# 110005                         2.0       591.0               7.847822
# ...                            ...         ...                    ...
# 522200                         2.0       528.0               7.191805
# 522205                         4.0       394.0               8.601167
# 522220                         3.0       403.0               5.055907
# 522230                         2.0       344.0               2.817385
# 530010                       530.0    122197.0              23.930012
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342995                     6.0
# 110002                              86.588539                    42.0
# 110003                              79.838104                     0.0
# 110004                              89.462151                   202.0
# 110005                              89.952827                     0.0
# ...                                       ...                     ...
# 522200                              33.744499                     0.0
# 522205                              78.874527                     0.0
# 522220                               5.833738                     0.0
# 522230                              26.473114                     0.0
# 530010                             117.493172                  3082.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664276
# 110002                                    299.0      481.314240
# 110003                                      0.0      442.604156
# 110004                                    469.0      484.990723
# 110005                                     38.0      466.433807
# ...                                         ...             ...
# 522200                                      0.0      474.571777
# 522205                                      0.0      439.651611
# 522220                                      0.0      440.164276
# 522230                                      0.0      451.296661
# 530010                                  15811.0      510.176941
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  543.020264        495.929718        502.991425  ...
# 110002                  549.247253        513.304749        512.975891  ...
# 110003                  506.685181        466.007416        484.924988  ...
# 110004                  549.739380        513.924805        524.946716  ...
# 110005                  551.494751        498.394745        493.949310  ...
# ...                            ...               ...               ...  ...
# 522200                  522.414612        493.386505        503.091766  ...
# 522205                  498.125641        463.625641        479.803223  ...
# 522220                  513.099976        450.394440        504.899994  ...
# 522230                  498.101593        463.396820        471.051666  ...
# 530010                  580.567993        546.609680        552.578613  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                           0                    0                    0
# 110002                           1                    0                    1
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110005                           0                    0                    0
# ...                            ...                  ...                  ...
# 522200                           0                    0                    0
# 522205                           1                    0                    1
# 522220                           0                    1                    1
# 522230                           0                    1                    0
# 530010                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
# ...                                   ...        ...         ...        ...
# 522200                                  0          0           1          0
# 522205                                  0          0           0          1
# 522220                                  0          0           0          0
# 522230                                  0          0           0          0
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110001                       0                                167
# 110002                       0                               1058
# 110003                       0                                 50
# 110004                       0                                987
# 110005                       0                                181
# ...                        ...                                ...
# 522200                       0                                150
# 522205                       0                                 47
# 522220                       0                                 22
# 522230                       0                                 25
# 530010                       0                              47504
#
#                     prediction_label
# cod_municipio_ibge
# 110001                    263.722029
# 110002                   1725.522077
# 110003                     98.784840
# 110004                   2022.436311
# 110005                    286.187252
# ...                              ...
# 522200                    142.910724
# 522205                    138.877294
# 522220                     55.409321
# 522230                     75.254998
# 530010                  59391.787865
#
# [5570 rows x 32 columns]

# %%
plt.scatter(pred_treino_2['qtd_abertas_Empresario_Individual'],pred_treino_2['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %%
#df.to_excel('dados_previsao.xlsx')

# %% [markdown]
# ## Testando Radom Forest

# %% [markdown]
# ### MAPE

# %%
#regression_setup = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)

# %%
#best_model_mape = compare_models(sort = 'MAPE', fold=5)

# %%
#print(best_model_mape)

# %%
#best_model_mape = create_model('rf', fold = 5)

# %%
#tuned_mape = tune_model(best_model_mape, fold = 5)

# %%
#plot_model(best_model_mape, plot='feature' )

# %%
#final_model_baseline_mape = finalize_model(best_model_mape)

# %%
#pred_teste_mape= predict_model(final_model_baseline_mape, data = teste)

# %%
#pred_teste_mape

# %%
#plt.scatter(pred_teste_mape['qtd_abertas_Empresario_Individual'],pred_teste_mape['prediction_label'])
#plt.xlabel('Valores reais')
#plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')

# %%
#pred_teste_mape.to_excel('previsao_mape.xlsx')

# %% [markdown]
# ### Previsão - Mape 2019

# %%
#pred_2018_2019 = predict_model(final_model_baseline_mape, data = df_2)

# %%
#pred_2018_2019

# %%
#plt.scatter(pred_2018_2019['qtd_abertas_Empresario_Individual'],pred_2018_2019['prediction_label'])
#plt.xlabel('Valores reais')
#plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')

# %%
#pred_2018_2019.to_excel('previsao_mape_2018_2019.xlsx')

# %% [markdown]
# ## Clusterização

# %% [markdown]
# ###  K-means 2022

# %%
df_c_22 = df

# %%
df_c_22 = df.drop('qtd_abertas_Empresario_Individual', axis = 1)
df_c_22= df_c_22.drop('porte_municipio', axis = 1)

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         8.0       926.0               8.958074
# 110002                        38.0      2563.0              21.363407
# 110003                         0.0       344.0               5.407539
# 110004                        21.0      1971.0              19.480189
# 110005                         3.0       591.0               8.540527
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              70.647540                     2.0
# 110002                              93.858639                    99.0
# 110003                              78.369844                     0.0
# 110004                             105.350861                   184.0
# 110005                             108.074341                     4.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     30.0      497.721951
# 110002                                    342.0      474.773986
# 110003                                      0.0      477.266667
# 110004                                    422.0      489.744000
# 110005                                     35.0      479.268750
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  504.034091        491.079545        543.558537  ...
# 110002                  495.727950        484.710248        518.811149  ...
# 110003                  486.071429        447.628571        522.883333  ...
# 110004                  505.006061        490.991919        533.458933  ...
# 110005                  477.045714        454.722857        480.696875  ...
#
#                     Reducao_ISSQN_Sim  Isencao_ISSQN_Sim  Isencao_Tx_Sim  \
# cod_municipio_ibge
# 110001                              0                  0               0
# 110002                              0                  0               1
# 110003                              0                  1               0
# 110004                              1                  0               1
# 110005                              0                  0               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima
# cod_municipio_ibge
# 110001                       0
# 110002                       0
# 110003                       0
# 110004                       0
# 110005                       0
#
# [5 rows x 29 columns]

# %%
df_c_22 = df_c_22.astype('int64')

# %%
df_c_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   taxa_homicidio                 5570 non-null   int64
#  1   RH_adm_dir                     5570 non-null   int64
#  2   densidade_banda_larga          5570 non-null   int64
#  3   densidade_telefonia_movel      5570 non-null   int64
#  4   qtd_cursos_engenharias         5570 non-null   int64
#  5   qtd_cursos_negocios_direito    5570 non-null   int64
#  6   media_notas_CN                 5570 non-null   int64
#  7   media_notas_CH                 5570 non-null   int64
#  8   media_NU_NOTA_LC               5570 non-null   int64
#  9   media_NU_NOTA_MT               5570 non-null   int64
#  10  media_NU_NOTA_REDACAO          5570 non-null   int64
#  11  valor_medio_recebido_familia   5570 non-null   int64
#  12  pib_per_capita_preco_corrente  5570 non-null   int64
#  13  perc_20_59_anos                5570 non-null   int64
#  14  pop_total                      5570 non-null   int64
#  15  total_sim_tecnologia           5570 non-null   int64
#  16  Mecanismos_incentivo_Sim       5570 non-null   int64
#  17  Reducao_IPTU_Sim               5570 non-null   int64
#  18  Isencao_IPTU_Sim               5570 non-null   int64
#  19  Reducao_ISSQN_Sim              5570 non-null   int64
#  20  Isencao_ISSQN_Sim              5570 non-null   int64
#  21  Isencao_Tx_Sim                 5570 non-null   int64
#  22  Cessao_terrenos_Sim            5570 non-null   int64
#  23  Doacao_terrenos_Sim            5570 non-null   int64
#  24  Outros_mecanismos_Sim          5570 non-null   int64
#  25  ISH_Baixa                      5570 non-null   int64
#  26  ISH_Máxima                     5570 non-null   int64
#  27  ISH_Média                      5570 non-null   int64
#  28  ISH_Mínima                     5570 non-null   int64
# dtypes: int64(29)
# memory usage: 1.4 MB

# %%
valores_k =[]
inercias =[]

for i in range(1,15):
    cluster_empr = KMeans(n_clusters=i, random_state=42).fit(df_c_22)
    valores_k.append(i)
    inercias.append(cluster_empr.inertia_)

# %%
fig, ax = plt.subplots()

ax.plot(valores_k,inercias)

plt.show()

# %%
cluster_empr_22 = KMeans(n_clusters=5, random_state=42).fit(df_c_22)

# %%
cluster_empr_22.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 3])

# %%
fig, ax = plt.subplots(figsize= (15,10))

ax.scatter(df_c_22.iloc[:,1], df_c_22.iloc[:,0], c = cluster_empr_22.labels_)

plt.show()

# %%
df_c_22['cluster'] = cluster_empr_22.labels_

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster
# cod_municipio_ibge
# 110001                       0          0           0        0
# 110002                       0          1           0        0
# 110003                       0          0           0        0
# 110004                       0          0           0        0
# 110005                       0          0           0        0
#
# [5 rows x 30 columns]

# %%
col_empr = df['qtd_abertas_Empresario_Individual']
display(col_empr)
  
df_c_22 = df_c_22.join(col_empr )
# Out:
# cod_municipio_ibge
# 110001      194
# 110002     1275
# 110003       49
# 110004     1258
# 110005      257
#           ...
# 522200      222
# 522205       66
# 522220       23
# 522230       47
# 530010    54325
# Name: qtd_abertas_Empresario_Individual, Length: 5570, dtype: int64

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                           0                    0                    0
# 110002                           1                    0                    1
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110005                           0                    0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima  cluster  qtd_abertas_Empresario_Individual
# cod_municipio_ibge
# 110001                       0        0                                194
# 110002                       0        0                               1275
# 110003                       0        0                                 49
# 110004                       0        0                               1258
# 110005                       0        0                                257
#
# [5 rows x 31 columns]

# %%
df_c_22['cluster'].value_counts()
# Out:
# 0    5432
# 4     125
# 3      11
# 2       1
# 1       1
# Name: cluster, dtype: int64

# %%
df_c_22.loc[df_c_22['cluster'] == 0,'novos_clusters'] = 0

# %%
df_c_22.loc[df_c_22['cluster'] == 1,'novos_clusters'] = 1

# %%
df_c_22.loc[df_c_22['cluster'] == 2,'novos_clusters'] = 1

# %%
df_c_22.loc[df_c_22['cluster'] == 3,'novos_clusters'] = 1

# %%
df_c_22.loc[df_c_22['cluster'] == 4,'novos_clusters'] = 2

# %%
df_c_22 = df_c_22.astype('int64')

# %%
df_c_22.to_excel('df_c_22.xlsx')

# %% [markdown]
# ### Kmeans - 2019

# %%
df_c_19 = df_2

# %%
df_c_19 = df_c_19.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %%
df_c_19.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382994
# 110005                         2.0       591.0               7.847822
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342994                     6.0
# 110002                              86.588543                    42.0
# 110003                              79.838102                     0.0
# 110004                              89.462154                   202.0
# 110005                              89.952827                     0.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664286
# 110002                                    299.0      481.314239
# 110003                                      0.0      442.604167
# 110004                                    469.0      484.990720
# 110005                                     38.0      466.433803
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  543.020270        495.929730        502.991429  ...
# 110002                  549.247267        513.304727        512.975890  ...
# 110003                  506.685185        466.007407        484.925000  ...
# 110004                  549.739357        513.924809        524.946720  ...
# 110005                  551.494737        498.394737        493.949296  ...
#
#                     Reducao_ISSQN_Sim  Isencao_ISSQN_Sim  Isencao_Tx_Sim  \
# cod_municipio_ibge
# 110001                              0                  0               0
# 110002                              0                  0               1
# 110003                              0                  1               0
# 110004                              1                  0               1
# 110005                              0                  0               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima
# cod_municipio_ibge
# 110001                       0
# 110002                       0
# 110003                       0
# 110004                       0
# 110005                       0
#
# [5 rows x 30 columns]

# %%
df_c_19 = df_c_19.astype('int64')

# %%
df_c_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   taxa_homicidio                 5570 non-null   int64
#  1   RH_adm_dir                     5570 non-null   int64
#  2   densidade_banda_larga          5570 non-null   int64
#  3   densidade_telefonia_movel      5570 non-null   int64
#  4   qtd_cursos_engenharias         5570 non-null   int64
#  5   qtd_cursos_negocios_direito    5570 non-null   int64
#  6   media_notas_CN                 5570 non-null   int64
#  7   media_notas_CH                 5570 non-null   int64
#  8   media_NU_NOTA_LC               5570 non-null   int64
#  9   media_NU_NOTA_MT               5570 non-null   int64
#  10  media_NU_NOTA_REDACAO          5570 non-null   int64
#  11  valor_medio_recebido_familia   5570 non-null   int64
#  12  pib_per_capita_preco_corrente  5570 non-null   int64
#  13  perc_20_59_anos                5570 non-null   int64
#  14  pop_total                      5570 non-null   int64
#  15  total_sim_tecnologia           5570 non-null   int64
#  16  porte_municipio                5570 non-null   int64
#  17  Mecanismos_incentivo_Sim       5570 non-null   int64
#  18  Reducao_IPTU_Sim               5570 non-null   int64
#  19  Isencao_IPTU_Sim               5570 non-null   int64
#  20  Reducao_ISSQN_Sim              5570 non-null   int64
#  21  Isencao_ISSQN_Sim              5570 non-null   int64
#  22  Isencao_Tx_Sim                 5570 non-null   int64
#  23  Cessao_terrenos_Sim            5570 non-null   int64
#  24  Doacao_terrenos_Sim            5570 non-null   int64
#  25  Outros_mecanismos_Sim          5570 non-null   int64
#  26  ISH_Baixa                      5570 non-null   int64
#  27  ISH_Máxima                     5570 non-null   int64
#  28  ISH_Média                      5570 non-null   int64
#  29  ISH_Mínima                     5570 non-null   int64
# dtypes: int64(30)
# memory usage: 1.4 MB

# %%
valores_k =[]
inercias =[]

for i in range(1,15):
    cluster_empr = KMeans(n_clusters=i, random_state=42).fit(df_c_19)
    valores_k.append(i)
    inercias.append(cluster_empr.inertia_)

# %%
fig, ax = plt.subplots()

ax.plot(valores_k,inercias)

plt.show()

# %%
cluster_empr_19 = KMeans(n_clusters=3, random_state=42).fit(df_c_19)

# %%
cluster_empr_19.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
#verificar se eu dividi as posições de x e y corretamente

fig, ax = plt.subplots(figsize= (15,10))

ax.scatter(df_c_19.iloc[:,1], df_c_19.iloc[:,0], c = cluster_empr_19.labels_)

plt.show()

# %%
df_c_19['cluster'] = cluster_empr_19.labels_

# %%
df_c_19.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           7         926                      5
# 110002                          41        2563                     11
# 110003                           0         344                      3
# 110004                          17        1971                     12
# 110005                           2         591                      7
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     34                       6
# 110002                                     86                      42
# 110003                                     79                       0
# 110004                                     89                     202
# 110005                                     89                       0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       23             480
# 110002                                      299             481
# 110003                                        0             442
# 110004                                      469             484
# 110005                                       38             466
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         543               495               502  ...
# 110002                         549               513               512  ...
# 110003                         506               466               484  ...
# 110004                         549               513               524  ...
# 110005                         551               498               493  ...
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster
# cod_municipio_ibge
# 110001                       0          0           0        0
# 110002                       0          1           0        0
# 110003                       0          0           0        0
# 110004                       0          0           0        0
# 110005                       0          0           0        0
#
# [5 rows x 31 columns]

# %%
df_c_19= df_c_19.drop('porte_municipio', axis = 1)

# %%
col_empr = df_2['qtd_abertas_Empresario_Individual']
display(col_empr)
  
df_c_19 = df_c_19.join(col_empr )
# Out:
# cod_municipio_ibge
# 110001      167
# 110002     1058
# 110003       50
# 110004      987
# 110005      181
#           ...
# 522200      150
# 522205       47
# 522220       22
# 522230       25
# 530010    47504
# Name: qtd_abertas_Empresario_Individual, Length: 5570, dtype: int64

# %% [markdown]
# ## Treinando o modelo com Cluster

# %% [markdown]
# ### 2022

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima  cluster  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110001                       0        0                                194
# 110002                       0        0                               1275
# 110003                       0        0                                 49
# 110004                       0        0                               1258
# 110005                       0        0                                257
#
#                     novos_clusters
# cod_municipio_ibge
# 110001                           0
# 110002                           0
# 110003                           0
# 110004                           0
# 110005                           0
#
# [5 rows x 32 columns]

# %%
df_c_22= df_c_22.drop('cluster', axis = 1)

# %%
#df_c_22 = pd.get_dummies(df_c_22, columns = ['cluster']) #drop_first=True

# %%
h = FeatureHasher(n_features=4)
f = h.transform(df_c_22['cluster'])
f.toarray()

# %%
df_c_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     5570 non-null   int64
#  1   RH_adm_dir                         5570 non-null   int64
#  2   densidade_banda_larga              5570 non-null   int64
#  3   densidade_telefonia_movel          5570 non-null   int64
#  4   qtd_cursos_engenharias             5570 non-null   int64
#  5   qtd_cursos_negocios_direito        5570 non-null   int64
#  6   media_notas_CN                     5570 non-null   int64
#  7   media_notas_CH                     5570 non-null   int64
#  8   media_NU_NOTA_LC                   5570 non-null   int64
#  9   media_NU_NOTA_MT                   5570 non-null   int64
#  10  media_NU_NOTA_REDACAO              5570 non-null   int64
#  11  valor_medio_recebido_familia       5570 non-null   int64
#  12  pib_per_capita_preco_corrente      5570 non-null   int64
#  13  perc_20_59_anos                    5570 non-null   int64
#  14  pop_total                          5570 non-null   int64
#  15  total_sim_tecnologia               5570 non-null   int64
#  16  Mecanismos_incentivo_Sim           5570 non-null   int64
#  17  Reducao_IPTU_Sim                   5570 non-null   int64
#  18  Isencao_IPTU_Sim                   5570 non-null   int64
#  19  Reducao_ISSQN_Sim                  5570 non-null   int64
#  20  Isencao_ISSQN_Sim                  5570 non-null   int64
#  21  Isencao_Tx_Sim                     5570 non-null   int64
#  22  Cessao_terrenos_Sim                5570 non-null   int64
#  23  Doacao_terrenos_Sim                5570 non-null   int64
#  24  Outros_mecanismos_Sim              5570 non-null   int64
#  25  ISH_Baixa                          5570 non-null   int64
#  26  ISH_Máxima                         5570 non-null   int64
#  27  ISH_Média                          5570 non-null   int64
#  28  ISH_Mínima                         5570 non-null   int64
#  29  qtd_abertas_Empresario_Individual  5570 non-null   int64
#  30  novos_clusters                     5570 non-null   int64
# dtypes: int64(31)
# memory usage: 1.5 MB

# %%
treino_clus = df_c_22.groupby('novos_clusters', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste_clus = df_c_22.drop(treino_clus.index)

print(treino_clus.shape, teste_clus.shape)
# Out:
# (4178, 31) (1392, 31)

# %%
#treino_clus = pd.get_dummies(treino_clus, columns = ['cluster'], drop_first=True)
#teste_clus = pd.get_dummies(teste_clus, columns = ['cluster'], drop_first=True)

# %%
treino_clus = treino_clus.drop('novos_clusters', axis = 1)
teste_clus = teste_clus.drop('novos_clusters', axis = 1)

# %%
teste_clus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1392 entries, 110003 to 530010
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     1392 non-null   int64
#  1   RH_adm_dir                         1392 non-null   int64
#  2   densidade_banda_larga              1392 non-null   int64
#  3   densidade_telefonia_movel          1392 non-null   int64
#  4   qtd_cursos_engenharias             1392 non-null   int64
#  5   qtd_cursos_negocios_direito        1392 non-null   int64
#  6   media_notas_CN                     1392 non-null   int64
#  7   media_notas_CH                     1392 non-null   int64
#  8   media_NU_NOTA_LC                   1392 non-null   int64
#  9   media_NU_NOTA_MT                   1392 non-null   int64
#  10  media_NU_NOTA_REDACAO              1392 non-null   int64
#  11  valor_medio_recebido_familia       1392 non-null   int64
#  12  pib_per_capita_preco_corrente      1392 non-null   int64
#  13  perc_20_59_anos                    1392 non-null   int64
#  14  pop_total                          1392 non-null   int64
#  15  total_sim_tecnologia               1392 non-null   int64
#  16  Mecanismos_incentivo_Sim           1392 non-null   int64
#  17  Reducao_IPTU_Sim                   1392 non-null   int64
#  18  Isencao_IPTU_Sim                   1392 non-null   int64
#  19  Reducao_ISSQN_Sim                  1392 non-null   int64
#  20  Isencao_ISSQN_Sim                  1392 non-null   int64
#  21  Isencao_Tx_Sim                     1392 non-null   int64
#  22  Cessao_terrenos_Sim                1392 non-null   int64
#  23  Doacao_terrenos_Sim                1392 non-null   int64
#  24  Outros_mecanismos_Sim              1392 non-null   int64
#  25  ISH_Baixa                          1392 non-null   int64
#  26  ISH_Máxima                         1392 non-null   int64
#  27  ISH_Média                          1392 non-null   int64
#  28  ISH_Mínima                         1392 non-null   int64
#  29  qtd_abertas_Empresario_Individual  1392 non-null   int64
# dtypes: int64(30)
# memory usage: 337.1 KB

# %%
treino_clus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4178 entries, 521500 to 420240
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     4178 non-null   int64
#  1   RH_adm_dir                         4178 non-null   int64
#  2   densidade_banda_larga              4178 non-null   int64
#  3   densidade_telefonia_movel          4178 non-null   int64
#  4   qtd_cursos_engenharias             4178 non-null   int64
#  5   qtd_cursos_negocios_direito        4178 non-null   int64
#  6   media_notas_CN                     4178 non-null   int64
#  7   media_notas_CH                     4178 non-null   int64
#  8   media_NU_NOTA_LC                   4178 non-null   int64
#  9   media_NU_NOTA_MT                   4178 non-null   int64
#  10  media_NU_NOTA_REDACAO              4178 non-null   int64
#  11  valor_medio_recebido_familia       4178 non-null   int64
#  12  pib_per_capita_preco_corrente      4178 non-null   int64
#  13  perc_20_59_anos                    4178 non-null   int64
#  14  pop_total                          4178 non-null   int64
#  15  total_sim_tecnologia               4178 non-null   int64
#  16  Mecanismos_incentivo_Sim           4178 non-null   int64
#  17  Reducao_IPTU_Sim                   4178 non-null   int64
#  18  Isencao_IPTU_Sim                   4178 non-null   int64
#  19  Reducao_ISSQN_Sim                  4178 non-null   int64
#  20  Isencao_ISSQN_Sim                  4178 non-null   int64
#  21  Isencao_Tx_Sim                     4178 non-null   int64
#  22  Cessao_terrenos_Sim                4178 non-null   int64
#  23  Doacao_terrenos_Sim                4178 non-null   int64
#  24  Outros_mecanismos_Sim              4178 non-null   int64
#  25  ISH_Baixa                          4178 non-null   int64
#  26  ISH_Máxima                         4178 non-null   int64
#  27  ISH_Média                          4178 non-null   int64
#  28  ISH_Mínima                         4178 non-null   int64
#  29  qtd_abertas_Empresario_Individual  4178 non-null   int64
# dtypes: int64(30)
# memory usage: 1011.9 KB

# %% [markdown]
# ### Pycaret

# %% [markdown]
# #### RMSE

# %%
regression_setup_rmse = setup(data = treino_clus, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_ad3c7_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ad3c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad3c7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ad3c7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad3c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad3c7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ad3c7_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad3c7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ad3c7_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad3c7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ad3c7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad3c7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ad3c7_row3_col1" class="data row3 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad3c7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ad3c7_row4_col1" class="data row4 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad3c7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ad3c7_row5_col1" class="data row5 col1" >(2924, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad3c7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ad3c7_row6_col1" class="data row6 col1" >(1254, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad3c7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ad3c7_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad3c7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ad3c7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ad3c7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ad3c7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ad3c7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ad3c7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ad3c7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ad3c7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ad3c7_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_ad3c7_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ad3c7_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_ad3c7_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ad3c7_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_ad3c7_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ad3c7_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_ad3c7_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ad3c7_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_ad3c7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ad3c7_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_ad3c7_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ad3c7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ad3c7_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_ad3c7_row18_col1" class="data row18 col1" >48b0</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_clus = compare_models(sort = 'RMSE', fold=5)
# Out:
# <style type="text/css">
# #T_9981f th {
#   text-align: left;
# }
# #T_9981f_row0_col0, #T_9981f_row0_col1, #T_9981f_row0_col4, #T_9981f_row0_col5, #T_9981f_row0_col6, #T_9981f_row1_col0, #T_9981f_row1_col1, #T_9981f_row1_col2, #T_9981f_row1_col3, #T_9981f_row1_col5, #T_9981f_row1_col6, #T_9981f_row2_col0, #T_9981f_row2_col1, #T_9981f_row2_col2, #T_9981f_row2_col3, #T_9981f_row2_col4, #T_9981f_row2_col5, #T_9981f_row2_col6, #T_9981f_row3_col0, #T_9981f_row3_col1, #T_9981f_row3_col2, #T_9981f_row3_col3, #T_9981f_row3_col4, #T_9981f_row3_col5, #T_9981f_row3_col6, #T_9981f_row4_col0, #T_9981f_row4_col1, #T_9981f_row4_col2, #T_9981f_row4_col3, #T_9981f_row4_col4, #T_9981f_row4_col5, #T_9981f_row4_col6, #T_9981f_row5_col0, #T_9981f_row5_col1, #T_9981f_row5_col2, #T_9981f_row5_col3, #T_9981f_row5_col4, #T_9981f_row5_col5, #T_9981f_row5_col6, #T_9981f_row6_col0, #T_9981f_row6_col1, #T_9981f_row6_col2, #T_9981f_row6_col3, #T_9981f_row6_col4, #T_9981f_row6_col5, #T_9981f_row6_col6, #T_9981f_row7_col0, #T_9981f_row7_col1, #T_9981f_row7_col2, #T_9981f_row7_col3, #T_9981f_row7_col4, #T_9981f_row7_col5, #T_9981f_row7_col6, #T_9981f_row8_col0, #T_9981f_row8_col1, #T_9981f_row8_col2, #T_9981f_row8_col3, #T_9981f_row8_col4, #T_9981f_row8_col5, #T_9981f_row8_col6, #T_9981f_row9_col0, #T_9981f_row9_col1, #T_9981f_row9_col2, #T_9981f_row9_col3, #T_9981f_row9_col4, #T_9981f_row9_col5, #T_9981f_row9_col6, #T_9981f_row10_col0,
td>
#     </tr>
#     <tr>
#       <th id="T_43f54_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43f54_row1_col0" class="data row1 col0" >147.3555</td>
#       <td id="T_43f54_row1_col1" class="data row1 col1" >139660.2643</td>
#       <td id="T_43f54_row1_col2" class="data row1 col2" >373.7115</td>
#       <td id="T_43f54_row1_col3" class="data row1 col3" >0.9018</td>
#       <td id="T_43f54_row1_col4" class="data row1 col4" >1.1013</td>
#       <td id="T_43f54_row1_col5" class="data row1 col5" >2.2050</td>
#     </tr>
#     <tr>
#       <th id="T_43f54_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43f54_row2_col0" class="data row2 col0" >177.9164</td>
#       <td id="T_43f54_row2_col1" class="data row2 col1" >203746.3365</td>
#       <td id="T_43f54_row2_col2" class="data row2 col2" >451.3827</td>
#       <td id="T_43f54_row2_col3" class="data row2 col3" >0.9759</td>
#       <td id="T_43f54_row2_col4" class="data row2 col4" >1.0672</td>
#       <td id="T_43f54_row2_col5" class="data row2 col5" >2.3260</td>
#     </tr>
#     <tr>
#       <th id="T_43f54_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43f54_row3_col0" class="data row3 col0" >141.7701</td>
#       <td id="T_43f54_row3_col1" class="data row3 col1" >66418.7842</td>
#       <td id="T_43f54_row3_col2" class="data row3 col2" >257.7184</td>
#       <td id="T_43f54_row3_col3" class="data row3 col3" >0.9069</td>
#       <td id="T_43f54_row3_col4" class="data row3 col4" >1.1124</td>
#       <td id="T_43f54_row3_col5" class="data row3 col5" >2.1428</td>
#     </tr>
#     <tr>
#       <th id="T_43f54_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43f54_row4_col0" class="data row4 col0" >183.7222</td>
#       <td id="T_43f54_row4_col1" class="data row4 col1" >471730.5675</td>
#       <td id="T_43f54_row4_col2" class="data row4 col2" >686.8264</td>
#       <td id="T_43f54_row4_col3" class="data row4 col3" >0.9156</td>
#       <td id="T_43f54_row4_col4" class="data row4 col4" >0.9685</td>
#       <td id="T_43f54_row4_col5" class="data row4 col5" >1.9280</td>
#     </tr>
#     <tr>
#       <th id="T_43f54_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_43f54_row5_col0" class="data row5 col0" >164.2606</td>
#       <td id="T_43f54_row5_col1" class="data row5 col1" >345732.6009</td>
#       <td id="T_43f54_row5_col2" class="data row5 col2" >538.0046</td>
#       <td id="T_43f54_row5_col3" class="data row5 col3" >0.9183</td>
#       <td id="T_43f54_row5_col4" class="data row5 col4" >1.0759</td>
#       <td id="T_43f54_row5_col5" class="data row5 col5" >2.1775</td>
#     </tr>
#     <tr>
#       <th id="T_43f54_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_43f54_row6_col0" class="data row6 col0" >16.7108</td>
#       <td id="T_43f54_row6_col1" class="data row6 col1" >285620.0073</td>
#       <td id="T_43f54_row6_col2" class="data row6 col2" >237.2417</td>
#       <td id="T_43f54_row6_col3" class="data row6 col3" >0.0298</td>
#       <td id="T_43f54_row6_col4" class="data row6 col4" >0.0574</td>
#       <td id="T_43f54_row6_col5" class="data row6 col5" >0.1400</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(tuned_clus)
# Out:
# HuberRegressor(alpha=0.7, epsilon=1.5)

# %%
#plot_model(tuned_clus, plot='feature')

# %%
final_model_baseline_rmse_clus = finalize_model(tuned_clus)

# %% [markdown]
# ### Previsão - RMSE 2022

# %%
pred_teste_clus = predict_model(final_model_baseline_rmse_clus, data = teste_clus)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d852">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d852_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5d852_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5d852_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5d852_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5d852_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5d852_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5d852_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d852_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d852_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_5d852_row0_col1" class="data row0 col1" >228.8296</td>
#       <td id="T_5d852_row0_col2" class="data row0 col2" >821723.9022</td>
#       <td id="T_5d852_row0_col3" class="data row0 col3" >906.4899</td>
#       <td id="T_5d852_row0_col4" class="data row0 col4" >0.9384</td>
#       <td id="T_5d852_row0_col5" class="data row0 col5" >1.3266</td>
#       <td id="T_5d852_row0_col6" class="data row0 col6" >3.2597</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_teste_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110009                           7         893                     10
# 110015                           6        1425                     12
# 110025                           2         727                     21
# ...                            ...         ...                    ...
# 522145                           3         264                      3
# 522155                           0         435                     11
# 522157                           0         209                      3
# 522205                           0         394                      8
# 530010                         480      122197                     25
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110003                                     78                       0
# 110004                                    105                     184
# 110009                                     60                       0
# 110015                                    111                      18
# 110025                                     98                       3
# ...                                       ...                     ...
# 522145                                     89                       0
# 522155                                     66                       0
# 522157                                     81                       0
# 522205                                    104                       0
# 530010                                    109                    2210
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110003                                        0             477
# 110004                                      422             489
# 110009                                       22             461
# 110015                                       60             458
# 110025                                       15             461
# ...                                         ...             ...
# 522145                                        0             442
# 522155                                        0             418
# 522157                                        0             430
# 522205                                        0             450
# 530010                                    13097             505
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110009                         469               466               502  ...
# 110015                         476               470               507  ...
# 110025                         446               454               484  ...
# ...                            ...               ...               ...  ...
# 522145                         430               432               444  ...
# 522155                         452               407               454  ...
# 522157                         435               486               514  ...
# 522205                         464               457               504  ...
# 530010                         534               522               552  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110009                           0                    0                    0
# 110015                           0                    1                    0
# 110025                           0                    0                    0
# ...                            ...                  ...                  ...
# 522145                           0                    0                    1
# 522155                           0                    0                    1
# 522157                           0                    1                    0
# 522205                           1                    0                    1
# 530010                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110009                                  0          0           0          1
# 110015                                  0          0           0          0
# 110025                                  1          0           0          0
# ...                                   ...        ...         ...        ...
# 522145                                  0          0           0          0
# 522155                                  0          0           0          1
# 522157                                  0          0           0          1
# 522205                                  0          0           0          1
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110003                       0                                 49
# 110004                       0                               1258
# 110009                       0                                319
# 110015                       0                                461
# 110025                       0                                172
# ...                        ...                                ...
# 522145                       0                                 28
# 522155                       0                                 58
# 522157                       0                                 14
# 522205                       0                                 66
# 530010                       0                              54325
#
#                     prediction_label
# cod_municipio_ibge
# 110003                    -94.274761
# 110004                   1515.188691
# 110009                    435.927291
# 110015                    493.452795
# 110025                    150.764904
# ...                              ...
# 522145                   -157.216265
# 522155                     27.580802
# 522157                   -162.368709
# 522205                     15.024241
# 530010                  61369.081843
#
# [1392 rows x 31 columns]

# %%
plt.scatter(pred_teste_clus['qtd_abertas_Empresario_Individual'],pred_teste_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ### Previsão - RMSE 2019

# %%
df_c_19 = pd.get_dummies(df_c_19, columns = ['cluster'], drop_first=True)

# %%
pred_2018_2019_clus = predict_model(final_model_baseline_rmse_clus, data = df_c_19)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1b630">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b630_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1b630_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1b630_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1b630_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1b630_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1b630_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1b630_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b630_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b630_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_1b630_row0_col1" class="data row0 col1" >138.4405</td>
#       <td id="T_1b630_row0_col2" class="data row0 col2" >356543.8202</td>
#       <td id="T_1b630_row0_col3" class="data row0 col3" >597.1129</td>
#       <td id="T_1b630_row0_col4" class="data row0 col4" >0.9786</td>
#       <td id="T_1b630_row0_col5" class="data row0 col5" >0.7514</td>
#       <td id="T_1b630_row0_col6" class="data row0 col6" >1.0421</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_2018_2019_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           7         926                      5
# 110002                          41        2563                     11
# 110003                           0         344                      3
# 110004                          17        1971                     12
# 110005                           2         591                      7
# ...                            ...         ...                    ...
# 522200                           2         528                      7
# 522205                           4         394                      8
# 522220                           3         403                      5
# 522230                           2         344                      2
# 530010                         530      122197                     23
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     34                       6
# 110002                                     86                      42
# 110003                                     79                       0
# 110004                                     89                     202
# 110005                                     89                       0
# ...                                       ...                     ...
# 522200                                     33                       0
# 522205                                     78                       0
# 522220                                      5                       0
# 522230                                     26                       0
# 530010                                    117                    3082
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       23             480
# 110002                                      299             481
# 110003                                        0             442
# 110004                                      469             484
# 110005                                       38             466
# ...                                         ...             ...
# 522200                                        0             474
# 522205                                        0             439
# 522220                                        0             440
# 522230                                        0             451
# 530010                                    15811             510
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         543               495               502  ...
# 110002                         549               513               512  ...
# 110003                         506               466               484  ...
# 110004                         549               513               524  ...
# 110005                         551               498               493  ...
# ...                            ...               ...               ...  ...
# 522200                         522               493               503  ...
# 522205                         498               463               479  ...
# 522220                         513               450               504  ...
# 522230                         498               463               471  ...
# 530010                         580               546               552  ...
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
# ...                                 ...                    ...        ...
# 522200                                0                      0          0
# 522205                                1                      0          0
# 522220                                1                      0          0
# 522230                                0                      0          0
# 530010                                0                      1          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster_1  cluster_2  \
# cod_municipio_ibge
# 110001                       0          0           0          0          0
# 110002                       0          1           0          0          0
# 110003                       0          0           0          0          0
# 110004                       0          0           0          0          0
# 110005                       0          0           0          0          0
# ...                        ...        ...         ...        ...        ...
# 522200                       1          0           0          0          0
# 522205                       0          1           0          0          0
# 522220                       0          0           0          0          0
# 522230                       0          0           0          0          0
# 530010                       0          0           0          0          1
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110001                                            167        263.981807
# 110002                                           1058       1722.466869
# 110003                                             50         95.096364
# 110004                                            987       1999.143946
# 110005                                            181        282.454704
# ...                                               ...               ...
# 522200                                            150        144.270888
# 522205                                             47        134.799216
# 522220                                             22         55.379545
# 522230                                             25         74.945107
# 530010                                          47504      58408.624395
#
# [5570 rows x 33 columns]

# %%
plt.scatter(pred_2018_2019_clus['qtd_abertas_Empresario_Individual'],pred_2018_2019_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ### MAPE

# %%
regression_setup = setup(data = treino_clus, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_fa203_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fa203">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa203_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fa203_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa203_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa203_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fa203_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa203_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fa203_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa203_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fa203_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa203_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fa203_row3_col1" class="data row3 col1" >(4178, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa203_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fa203_row4_col1" class="data row4 col1" >(4178, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa203_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fa203_row5_col1" class="data row5 col1" >(2924, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa203_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fa203_row6_col1" class="data row6 col1" >(1254, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa203_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fa203_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa203_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_fa203_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa203_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_fa203_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fa203_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_fa203_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fa203_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_fa203_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fa203_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_fa203_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fa203_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_fa203_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fa203_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_fa203_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fa203_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_fa203_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fa203_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_fa203_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fa203_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_fa203_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fa203_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_fa203_row18_col1" class="data row18 col1" >3c31</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_clus = compare_models(sort = 'MAPE', fold=5)
# Out:
# <style type="text/css">
# #T_1dea8 th {
#   text-align: left;
# }
# #T_1dea8_row0_col0, #T_1dea8_row0_col1, #T_1dea8_row0_col2, #T_1dea8_row0_col3, #T_1dea8_row0_col4, #T_1dea8_row1_col0, #T_1dea8_row1_col1, #T_1dea8_row1_col2, #T_1dea8_row1_col3, #T_1dea8_row1_col4, #T_1dea8_row1_col5, #T_1dea8_row1_col6, #T_1dea8_row2_col0, #T_1dea8_row2_col1, #T_1dea8_row2_col2, #T_1dea8_row2_col3, #T_1dea8_row2_col4, #T_1dea8_row2_col5, #T_1dea8_row2_col6, #T_1dea8_row3_col0, #T_1dea8_row3_col1, #T_1dea8_row3_col2, #T_1dea8_row3_col3, #T_1dea8_row3_col4, #T_1dea8_row3_col5, #T_1dea8_row3_col6, #T_1dea8_row4_col0, #T_1dea8_row4_col1, #T_1dea8_row4_col2, #T_1dea8_row4_col3, #T_1dea8_row4_col4, #T_1dea8_row4_col5, #T_1dea8_row4_col6, #T_1dea8_row5_col0, #T_1dea8_row5_col1, #T_1dea8_row5_col2, #T_1dea8_row5_col3, #T_1dea8_row5_col4, #T_1dea8_row5_col5, #T_1dea8_row5_col6, #T_1dea8_row6_col0, #T_1dea8_row6_col4, #T_1dea8_row6_col5, #T_1dea8_row6_col6, #T_1dea8_row7_col0, #T_1dea8_row7_col1, #T_1dea8_row7_col2, #T_1dea8_row7_col3, #T_1dea8_row7_col4, #T_1dea8_row7_col5, #T_1dea8_row7_col6, #T_1dea8_row8_col0, #T_1dea8_row8_col1, #T_1dea8_row8_col2, #T_1dea8_row8_col3, #T_1dea8_row8_col4, #T_1dea8_row8_col5, #T_1dea8_row8_col6, #T_1dea8_row9_col0, #T_1dea8_row9_col1, #T_1dea8_row9_col2, #T_1dea8_row9_col3, #T_1dea8_row9_col4, #T_1dea8_row9_col5, #T_1dea8_row9_col6, #T_1dea8_row10_col0, #T_1dea8_row10_col1, #T_1dea8_row10_col2, #T_1dea8_row10_col3, #T_1dea8_row10_col4, #T_1dea8_row10_col5, #T_1dea8_row10_col6, #T_1dea8_row11_col0, #T_1dea8_row11_col1, #T_1dea8_row11_col2, #T_1dea8_row11_col3, #T_1dea8_row11_col4, #T_1dea8_row11_col5, #T_1dea8_row11_col6, #T_1dea8_row12_col0, #T_1dea8_row12_col1, #T_1dea8_row12_col2, #T_1dea8_row12_col3, #T_1dea8_row12_col5, #T_1dea8_row12_col6, #T_1dea8_row13_col0, #T_1dea8_row13_col1, #T_1dea8_row13_col2, #T_1dea8_row13_col3, #T_1dea8_row13_col4, #T_1dea8_row13_col5, #T_1dea8_row13_col6, #T_1dea8_row14_col0, #T_1dea8_row14_col1, #T_1dea8_row14_col2, #T_1dea8_row14_col3, #T_1dea8_row14_col4, #T_1dea8_row14_col5, #T_1dea8_row14_col6, #T_1dea8_row15_col0, #T_1dea8_row15_col1, #T_1dea8_row15_col2, #T_1dea8_row15_col3, #T_1dea8_row15_col4, #T_1dea8_row15_col5, #T_1dea8_row15_col6, #T_1dea8_row16_col0, #T_1dea8_row16_col1, #T_1dea8_row16_col2, #T_1dea8_row16_col3, #T_1dea8_row16_col4, #T_1dea8_row16_col5, #T_1dea8_row16_col6, #T_1dea8_row17_col0, #T_1dea8_row17_col1, #T_1dea8_row17_col2, #T_1dea8_row17_col3, #T_1dea8_row17_col4, #T_1dea8_row17_col5, #T_1dea8_row17_col6, #T_1dea8_row18_col0, #T_1dea8_row18_col1, #T_1dea8_row18_col2, #T_1dea8_row18_col3, #T_1dea8_row18_col4, #T_1dea8_row18_col5, #T_1dea8_row18_col6 {
#   text-align: left;
# }
# #T_1dea8_row0_col5, #T_1dea8_row0_col6, #T_1dea8_row6_col1, #T_1dea8_row6_col2, #T_1dea8_row6_col3, #T_1dea8_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1dea8_row0_col7, #T_1dea8_row1_col7, #T_1dea8_row3_col7, #T_1dea8_row4_col7, #T_1dea8_row5_col7, #T_1dea8_row6_col7, #T_1dea8_row7_col7, #T_1dea8_row8_col7, #T_1dea8_row9_col7, #T_1dea8_row10_col7, #T_1dea8_row11_col7, #T_1dea8_row12_col7, #T_1dea8_row13_col7, #T_1dea8_row14_col7, #T_1dea8_row15_col7, #T_1dea8_row16_col7, #T_1dea8_row17_col7, #T_1dea8_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_
level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_89877_row6_col0" class="data row6 col0" >151.0337</td>
#       <td id="T_89877_row6_col1" class="data row6 col1" >35697742.1904</td>
#       <td id="T_89877_row6_col2" class="data row6 col2" >3517.1560</td>
#       <td id="T_89877_row6_col3" class="data row6 col3" >0.2857</td>
#       <td id="T_89877_row6_col4" class="data row6 col4" >0.0501</td>
#       <td id="T_89877_row6_col5" class="data row6 col5" >0.2017</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(tuned_clus)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
plot_model(best_model_clus, plot='feature')

# %%
final_model_baseline_mape_clus = finalize_model(best_model_clus)

# %% [markdown]
# ### Previsão - Mape 2022

# %%
pred_teste_clus = predict_model(final_model_baseline_mape_clus, data = teste_clus)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5fe0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5fe0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e5fe0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e5fe0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e5fe0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e5fe0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e5fe0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e5fe0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5fe0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5fe0_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_e5fe0_row0_col1" class="data row0 col1" >93.8469</td>
#       <td id="T_e5fe0_row0_col2" class="data row0 col2" >119848.8287</td>
#       <td id="T_e5fe0_row0_col3" class="data row0 col3" >346.1919</td>
#       <td id="T_e5fe0_row0_col4" class="data row0 col4" >0.9615</td>
#       <td id="T_e5fe0_row0_col5" class="data row0 col5" >0.4130</td>
#       <td id="T_e5fe0_row0_col6" class="data row0 col6" >0.3824</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_teste_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110009                           7         893                     10
# 110015                           6        1425                     12
# 110020                         145       12963                     23
# ...                            ...         ...                    ...
# 522040                           3        1064                     17
# 522150                           3         296                      1
# 522157                           0         209                      3
# 522160                          15        1180                     12
# 522220                           0         403                      1
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110003                                     78                       0
# 110004                                    105                     184
# 110009                                     60                       0
# 110015                                    111                      18
# 110020                                    106                     424
# ...                                       ...                     ...
# 522040                                     84                       0
# 522150                                     87                       0
# 522157                                     81                       0
# 522160                                    112                      50
# 522220                                     66                       0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110003                                        0             477
# 110004                                      422             489
# 110009                                       22             461
# 110015                                       60             458
# 110020                                     1595             473
# ...                                         ...             ...
# 522040                                       13             454
# 522150                                        0             418
# 522157                                        0             430
# 522160                                      146             477
# 522220                                        0             431
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110009                         469               466               502  ...
# 110015                         476               470               507  ...
# 110020                         496               482               511  ...
# ...                            ...               ...               ...  ...
# 522040                         472               466               498  ...
# 522150                         419               414               436  ...
# 522157                         435               486               514  ...
# 522160                         502               493               523  ...
# 522220                         443               426               445  ...
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110009                                0                      0          0
# 110015                                0                      0          0
# 110020                                0                      0          1
# ...                                 ...                    ...        ...
# 522040                                1                      0          0
# 522150                                1                      0          0
# 522157                                0                      0          0
# 522160                                0                      0          0
# 522220                                1                      0          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster_1  cluster_2  \
# cod_municipio_ibge
# 110003                       0          0           0          0          0
# 110004                       0          0           0          0          0
# 110009                       0          1           0          0          0
# 110015                       0          0           0          0          0
# 110020                       0          0           0          0          0
# ...                        ...        ...         ...        ...        ...
# 522040                       0          0           0          0          0
# 522150                       0          0           0          0          0
# 522157                       0          1           0          0          0
# 522160                       0          0           0          0          0
# 522220                       0          0           0          0          0
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110003                                             49             52.54
# 110004                                           1258           1375.89
# 110009                                            319            233.55
# 110015                                            461            578.26
# 110020                                           7893           9242.11
# ...                                               ...               ...
# 522040                                            231            248.67
# 522150                                             25             46.96
# 522157                                             14             23.10
# 522160                                            587            787.79
# 522220                                             23             44.72
#
# [1392 rows x 33 columns]

# %%
plt.scatter(pred_teste_clus['qtd_abertas_Empresario_Individual'],pred_teste_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ### Previsão - Mape 2019

# %%
pred_2018_2019_clus = predict_model(final_model_baseline_mape_clus, data = df_c_19)
# Out:
# <style type="text/css">
# </style>
# <table id="T_17622">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17622_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17622_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_17622_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_17622_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_17622_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_17622_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_17622_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17622_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17622_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_17622_row0_col1" class="data row0 col1" >116.1945</td>
#       <td id="T_17622_row0_col2" class="data row0 col2" >786575.1478</td>
#       <td id="T_17622_row0_col3" class="data row0 col3" >886.8907</td>
#       <td id="T_17622_row0_col4" class="data row0 col4" >0.9529</td>
#       <td id="T_17622_row0_col5" class="data row0 col5" >0.4530</td>
#       <td id="T_17622_row0_col6" class="data row0 col6" >0.4667</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_2018_2019_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           7         926                      5
# 110002                          41        2563                     11
# 110003                           0         344                      3
# 110004                          17        1971                     12
# 110005                           2         591                      7
# ...                            ...         ...                    ...
# 522200                           2         528                      7
# 522205                           4         394                      8
# 522220                           3         403                      5
# 522230                           2         344                      2
# 530010                         530      122197                     23
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     34                       6
# 110002                                     86                      42
# 110003                                     79                       0
# 110004                                     89                     202
# 110005                                     89                       0
# ...                                       ...                     ...
# 522200                                     33                       0
# 522205                                     78                       0
# 522220                                      5                       0
# 522230                                     26                       0
# 530010                                    117                    3082
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       23             480
# 110002                                      299             481
# 110003                                        0             442
# 110004                                      469             484
# 110005                                       38             466
# ...                                         ...             ...
# 522200                                        0             474
# 522205                                        0             439
# 522220                                        0             440
# 522230                                        0             451
# 530010                                    15811             510
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         543               495               502  ...
# 110002                         549               513               512  ...
# 110003                         506               466               484  ...
# 110004                         549               513               524  ...
# 110005                         551               498               493  ...
# ...                            ...               ...               ...  ...
# 522200                         522               493               503  ...
# 522205                         498               463               479  ...
# 522220                         513               450               504  ...
# 522230                         498               463               471  ...
# 530010                         580               546               552  ...
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
# ...                                 ...                    ...        ...
# 522200                                0                      0          0
# 522205                                1                      0          0
# 522220                                1                      0          0
# 522230                                0                      0          0
# 530010                                0                      1          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster_1  cluster_2  \
# cod_municipio_ibge
# 110001                       0          0           0          0          0
# 110002                       0          1           0          0          0
# 110003                       0          0           0          0          0
# 110004                       0          0           0          0          0
# 110005                       0          0           0          0          0
# ...                        ...        ...         ...        ...        ...
# 522200                       1          0           0          0          0
# 522205                       0          1           0          0          0
# 522220                       0          0           0          0          0
# 522230                       0          0           0          0          0
# 530010                       0          0           0          0          1
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110001                                            167            205.29
# 110002                                           1058           1264.52
# 110003                                             50             50.18
# 110004                                            987           1240.49
# 110005                                            181            215.65
# ...                                               ...               ...
# 522200                                            150            105.64
# 522205                                             47             88.38
# 522220                                             22             45.58
# 522230                                             25             44.75
# 530010                                          47504          61857.92
#
# [5570 rows x 33 columns]

# %%
plt.scatter(pred_2018_2019_clus['qtd_abertas_Empresario_Individual'],pred_2018_2019_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')
