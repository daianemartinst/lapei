# %% [markdown]
# # Instalando o Pycaret

# %%
#!pip install pycaret

# %%
#!pip install scipy

# %%
# Importando bibliotecas necessárias
import pandas as pd
import sweetviz as sv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import shap
from pycaret.regression import *
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform
from sklearn.cluster import KMeans 
from sklearn.feature_extraction import FeatureHasher

# %% [markdown]
# # Tratando a base

# %%
df= pd.read_excel("Base_2022_2023.xlsx")

# %%
df = df[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
#'taxa_homicidio',

# %%
df.head()
# Out:
#    cod_municipio_ibge  qtd_abertas_Empresario_Individual Mecanismos_incentivo  \
# 0              110001                                194                  Não
# 1              110002                               1275                  Sim
# 2              110003                                 49                  Sim
# 3              110004                               1258                  Sim
# 4              110005                                257                  Sim
#
#   Reducao_IPTU Isencao_IPTU Reducao_ISSQN Isencao_ISSQN Isencao_Tx  \
# 0          NaN          NaN           NaN           NaN        NaN
# 1          Sim          Sim           Não           Não        Sim
# 2          Não          Não           Não           Sim        Não
# 3          Não          Sim           Sim           Não        Sim
# 4          Não          Sim           Não           Não        Não
#
#   Cessao_terrenos Doacao_terrenos  ... media_notas_CH  media_NU_NOTA_LC  \
# 0             NaN             NaN  ...     504.034091        491.079545
# 1             Não             Sim  ...     495.727950        484.710248
# 2             Não             Não  ...     486.071429        447.628571
# 3             Sim             Sim  ...     505.006061        490.991919
# 4             Não             Não  ...     477.045714        454.722857
#
#   media_NU_NOTA_MT  media_NU_NOTA_REDACAO  valor_medio_recebido_familia  \
# 0       543.558537             621.363636                         18495
# 1       518.811149             584.534161                         17615
# 2       522.883333             471.428571                         18956
# 3       533.458933             611.717172                         19376
# 4       480.696875             576.571429                         17752
#
#    pib_per_capita_preco_corrente  perc_20_59_anos  pop_total  \
# 0                       25091.18         0.587227      22516
# 1                       25730.20         0.591797     111148
# 2                       32226.25         0.584567       5067
# 3                       29331.29         0.595584      86416
# 4                       37069.25         0.598272      16088
#
#    total_sim_tecnologia  porte_municipio
# 0                  18.0                2
# 1                  12.0                4
# 2                   8.0                1
# 3                  17.0                3
# 4                   8.0                2
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# cod_municipio_ibge                      0
# qtd_abertas_Empresario_Individual       0
# Mecanismos_incentivo                    2
# Reducao_IPTU                         2086
# Isencao_IPTU                         2086
# Reducao_ISSQN                        2086
# Isencao_ISSQN                        2086
# Isencao_Tx                           2086
# Cessao_terrenos                      2086
# Doacao_terrenos                      2086
# Outros_mecanismos                    2086
# RH_adm_dir                             23
# ISH                                     0
# densidade_banda_larga                   0
# densidade_telefonia_movel               0
# media_notas_CN                         91
# media_notas_CH                         84
# media_NU_NOTA_LC                       84
# media_NU_NOTA_MT                       91
# media_NU_NOTA_REDACAO                  94
# valor_medio_recebido_familia            0
# pib_per_capita_preco_corrente           0
# perc_20_59_anos                         0
# pop_total                               0
# total_sim_tecnologia                  129
# porte_municipio                         0
# dtype: int64

# %%
df['qtd_cursos_engenharias'] = df['qtd_cursos_engenharias'].fillna(0)

df['qtd_cursos_negocios_direito'] = df['qtd_cursos_negocios_direito'].fillna(0)

df['total_sim_tecnologia'] = df['total_sim_tecnologia'].fillna(0)

#df['taxa_homicidio'] = df['taxa_homicidio'].fillna(0)

df['RH_adm_dir'] = df['RH_adm_dir'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qtd_cursos_engenharias'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df['qtd_cursos_engenharias'] = df['qtd_cursos_engenharias'].fillna(0)
#       3 df['qtd_cursos_negocios_direito'] = df['qtd_cursos_negocios_direito'].fillna(0)
#       5 df['total_sim_tecnologia'] = df['total_sim_tecnologia'].fillna(0)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'qtd_cursos_engenharias'

# %%
df.isnull().sum()

# %%
df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df = pd.get_dummies(df, columns = ['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','ISH'], drop_first=True)

# %%
df.isnull().sum()

# %%
df = df[np.isfinite(df).all(1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df = df[np.isfinite(df).all(1)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2113, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2109 @final
#    2110 def __array_ufunc__(
#    2111     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2112 ):
# -> 2113     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:410, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     405 if method == "__call__" and not kwargs:
#     406     # for np.<ufunc>(..) calls
#     407     # kwargs cannot necessarily be handled block-by-block, so only
#     408     # take this path if there are no kwargs
#     409     mgr = inputs[0]._mgr
# --> 410     result = mgr.apply(getattr(ufunc, method))
#     411 else:
#     412     # otherwise specific ufunc methods (eg np.<ufunc>.accumulate(..))
#     413     # Those can have an axis keyword and thus can't be called block-by-block
#     414     result = default_array_ufunc(inputs[0], ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:350, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     348 try:
#     349     if callable(f):
# --> 350         applied = b.apply(f, **kwargs)
#     351     else:
#     352         applied = getattr(b, f)(**kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:351, in Block.apply(self, func, **kwargs)
#     345 @final
#     346 def apply(self, func, **kwargs) -> list[Block]:
#     347     """
#     348     apply the function to my values; return a block if we are not
#     349     one
#     350     """
# --> 351     result = func(self.values, **kwargs)
#     353     return self._split_op_result(result)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df.info()

# %%
df = df.set_index('cod_municipio_ibge')

# %%
df
# Out:
#                     qtd_abertas_Empresario_Individual Mecanismos_incentivo  \
# cod_municipio_ibge
# 110001                                            194                  Não
# 110002                                           1275                  Sim
# 110003                                             49                  Sim
# 110004                                           1258                  Sim
# 110005                                            257                  Sim
# ...                                               ...                  ...
# 522200                                            222                  Não
# 522205                                             66                  Sim
# 522220                                             23                  Sim
# 522230                                             47                  Sim
# 530010                                          54325                  Sim
#
#                    Reducao_IPTU Isencao_IPTU Reducao_ISSQN Isencao_ISSQN  \
# cod_municipio_ibge
# 110001                      NaN          NaN           NaN           NaN
# 110002                      Sim          Sim           Não           Não
# 110003                      Não          Não           Não           Sim
# 110004                      Não          Sim           Sim           Não
# 110005                      Não          Sim           Não           Não
# ...                         ...          ...           ...           ...
# 522200                      NaN          NaN           NaN           NaN
# 522205                      Sim          Não           Não           Não
# 522220                      Sim          Não           Não           Não
# 522230                      Não          Não           Não           Não
# 530010                      Sim          Não           Não           Não
#
#                    Isencao_Tx Cessao_terrenos Doacao_terrenos  \
# cod_municipio_ibge
# 110001                    NaN             NaN             NaN
# 110002                    Sim             Não             Sim
# 110003                    Não             Não             Não
# 110004                    Sim             Sim             Sim
# 110005                    Não             Não             Não
# ...                       ...             ...             ...
# 522200                    NaN             NaN             NaN
# 522205                    Sim             Não             Sim
# 522220                    Não             Sim             Sim
# 522230                    Não             Sim             Não
# 530010                    Não             Sim             Não
#
#                    Outros_mecanismos  ...  media_notas_CH media_NU_NOTA_LC  \
# cod_municipio_ibge                    ...
# 110001                           NaN  ...      504.034091       491.079545
# 110002                           Sim  ...      495.727950       484.710248
# 110003                           Sim  ...      486.071429       447.628571
# 110004                           Não  ...      505.006061       490.991919
# 110005                           Não  ...      477.045714       454.722857
# ...                              ...  ...             ...              ...
# 522200                           NaN  ...      479.917073       473.014634
# 522205                           Não  ...      464.383333       457.593333
# 522220                           Não  ...      443.025000       426.491667
# 522230                           Não  ...      417.394737       428.821053
# 530010                           Sim  ...      534.044622       522.095562
#
#                     media_NU_NOTA_MT  media_NU_NOTA_REDACAO  \
# cod_municipio_ibge
# 110001                    543.558537             621.363636
# 110002                    518.811149             584.534161
# 110003                    522.883333             471.428571
# 110004                    533.458933             611.717172
# 110005                    480.696875             576.571429
# ...                              ...                    ...
# 522200                    516.186486             553.658537
# 522205                    504.085714             552.000000
# 522220                    445.027273             420.000000
# 522230                    460.816667             444.210526
# 530010                    552.273557             627.378382
#
#                     valor_medio_recebido_familia  \
# cod_municipio_ibge
# 110001                                     18495
# 110002                                     17615
# 110003                                     18956
# 110004                                     19376
# 110005                                     17752
# ...                                          ...
# 522200                                     19058
# 522205                                     17265
# 522220                                     17859
# 522230                                     16764
# 530010                                     21675
#
#                     pib_per_capita_preco_corrente  perc_20_59_anos  pop_total  \
# cod_municipio_ibge
# 110001                                   25091.18         0.587227      22516
# 110002                                   25730.20         0.591797     111148
# 110003                                   32226.25         0.584567       5067
# 110004                                   29331.29         0.595584      86416
# 110005                                   37069.25         0.598272      16088
# ...                                           ...              ...        ...
# 522200                                   42019.96         0.596607      14088
# 522205                                   47171.97         0.600089       9002
# 522220                                   19310.39         0.612618       6451
# 522230                                   37142.72         0.585255       5941
# 530010                                   87016.16         0.611824    3094325
#
#                     total_sim_tecnologia  porte_municipio
# cod_municipio_ibge
# 110001                              18.0                2
# 110002                              12.0                4
# 110003                               8.0                1
# 110004                              17.0                3
# 110005                               8.0                2
# ...                                  ...              ...
# 522200                               7.0                2
# 522205                              16.0                1
# 522220                              11.0                1
# 522230                               3.0                1
# 530010                              11.0                5
#
# [5570 rows x 25 columns]

# %% [markdown]
# ## Nova base teste

# %%
df_2 = pd.read_excel("Base_novos_dados_2018_2019.xlsx")

# %%
df_2 = df_2[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','taxa_homicidio','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
#'qtd_cursos_engenharias',
#    'qtd_cursos_negocios_direito',

# %%
#df_2['qtd_cursos_engenharias'] = df_2['qtd_cursos_engenharias'].fillna(0)

#df_2['qtd_cursos_negocios_direito'] = df_2['qtd_cursos_negocios_direito'].fillna(0)

df_2['total_sim_tecnologia'] = df_2['total_sim_tecnologia'].fillna(0)

df_2['taxa_homicidio'] = df_2['taxa_homicidio'].fillna(0)

df_2['RH_adm_dir'] = df_2['RH_adm_dir'].fillna(0)

# %%
df_2[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df_2[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df_2[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df_2[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df_2 = pd.get_dummies(df_2, columns = ['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','ISH'], drop_first=True)

# %%
df_2 = df_2[np.isfinite(df_2).all(1)]

# %%
df_2 = df_2.set_index('cod_municipio_ibge')

# %% [markdown]
# # Dividindo em treino e test

# %% [markdown]
# Adaleny, fiz a divisão de treino e teste baseado na estratificação

# %%
treino = df.groupby('porte_municipio', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste = df.drop(treino.index)

print(treino.shape, teste.shape)
# Out:
# (4178, 29) (1392, 29)

# %%
treino = treino.drop('porte_municipio', axis = 1)
teste= teste.drop('porte_municipio', axis = 1)

# %% [markdown]
# treino = treino.drop('porte_municipio', axis = 1)
# teste= teste.drop('porte_municipio', axis = 1)

# %%
#teste= teste.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %% [markdown]
# treino.info()

# %% [markdown]
# # Pycaret

# %% [markdown]
# ## Setup

# %%
regression_setup = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_e1899_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1899">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1899_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1899_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1899_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1899_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1899_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1899_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e1899_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1899_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e1899_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1899_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e1899_row3_col1" class="data row3 col1" >(4178, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1899_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e1899_row4_col1" class="data row4 col1" >(4178, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1899_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e1899_row5_col1" class="data row5 col1" >(2924, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1899_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e1899_row6_col1" class="data row6 col1" >(1254, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1899_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e1899_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1899_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e1899_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1899_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e1899_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1899_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e1899_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1899_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e1899_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1899_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e1899_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e1899_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e1899_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e1899_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e1899_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e1899_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e1899_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e1899_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e1899_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e1899_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e1899_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e1899_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e1899_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e1899_row18_col1" class="data row18 col1" >bed1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Comparando Modelos

# %% [markdown]
# ### Usando RMSE

# %%
best_model = compare_models(sort = 'RMSE', fold=5)
# Out:
# <style type="text/css">
# #T_1fdf8 th {
#   text-align: left;
# }
# #T_1fdf8_row0_col0, #T_1fdf8_row0_col1, #T_1fdf8_row0_col4, #T_1fdf8_row0_col5, #T_1fdf8_row0_col6, #T_1fdf8_row1_col0, #T_1fdf8_row1_col1, #T_1fdf8_row1_col2, #T_1fdf8_row1_col3, #T_1fdf8_row1_col5, #T_1fdf8_row1_col6, #T_1fdf8_row2_col0, #T_1fdf8_row2_col1, #T_1fdf8_row2_col2, #T_1fdf8_row2_col3, #T_1fdf8_row2
#   text-align: left;
# }
# #T_1fdf8_row0_col2, #T_1fdf8_row0_col3, #T_1fdf8_row1_col4, #T_1fdf8_row10_col1, #T_1fdf8_row12_col5, #T_1fdf8_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1fdf8_row0_col7, #T_1fdf8_row1_col7, #T_1fdf8_row2_col7, #T_1fdf8_row3_col7, #T_1fdf8_row4_col7, #T_1fdf8_row5_col7, #T_1fdf8_row6_col7, #T_1fdf8_row7_col7, #T_1fdf8_row8_col7, #T_1fdf8_row10_col7, #T_1fdf8_row11_col7, #T_1fdf8_row12_col7, #T_1fdf8_row13_col7, #T_1fdf8_row14_col7, #T_1fdf8_row15_col7, #T_1fdf8_row16_col7, #T_1fdf8_row17_col7, #T_1fdf8_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1fdf8_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1fdf8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fdf8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1fdf8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1fdf8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1fdf8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1fdf8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1fdf8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1fdf8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1fdf8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fdf8_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_1fdf8_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_1fdf8_row0_col1" class="data row0 col1" >176.4552</td>
#       <td id="T_1fdf8_row0_col2" class="data row0 col2" >1253011.0742</td>
#       <td id="T_1fdf8_row0_col3" class="data row0 col3" >930.1752</td>
#       <td id="T_1fdf8_row0_col4" class="data row0 col4" >0.9235</td>
#       <td id="T_1fdf8_row0_col5" class="data row0 col5" >0.8336</td>
#       <td id="T_1fdf8_row0_col6" class="data row0 col6" >1.0239</td>
#       <td id="T_1fdf8_row0_col7" class="data row0 col7" >0.6660</td>
#     </tr>
#     <tr>
#       <th id="T_1fdf8_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_1fdf8_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_1fdf8_row1_col1" class="data row1 col1" >222.3184</td>
#       <td id="T_1fdf8_row1_col2" class="data row1 col2" >1304406.5691</td>
#       <td id="T_1fdf8_row1_col3" class="data row1 col3" >947.6668</td>
#       <td id="T_1fdf8_row1_col4" class="data row1 col4" >0.9245</td>
#       <td id="T_1fdf8_row1_col5" class="data row1 col5" >1.1778</td>
#       <td id="T_1fdf8_row1_col6" class="data row1 col6" >2.6551</td>
#       <td id="T_1fdf8_row1_col7" class="data row1 col7" >0.6680</td>
#     </tr>
#     <tr>
#       <th id="T_1fdf8_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_1fdf8_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_1fdf8_row2_col1" class="data row2 col1" >209.8144</td>
#       <td id="T_1fdf8_row2_col2" class="data row2 col2" >1706523.8331</td>
#       <td id="T_1fdf8_row2_col3" class="data row2 col3" >1099.8355</td>
#       <td id="T_1fdf8_row2_col4" class="data row2 col4" >0.9123</td>
#       <td id="T_1fdf8_row2_col5" class="data row2 col5" >1.1287</td>
#       <td id="T_1fdf8_row2_col6" class="data row2 col6" >2.5236</td>
#       <td id="T_1fdf8_row2_col7" class="data row2 col7" >0.6720</td>
#     </tr>
#     <tr>
#       <th id="T_1fdf8_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_1fdf8_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_1fdf8_row3_col1" class="data row3 col1" >211.3799</td>
#       <td id="T_1fdf8_row3_col2" class="data row3 col2" >1725149.5271</td>
#       <td id="T_1fdf8_row3_col3" class="data row3 col3" >1104.2386</td>
#       <td id="T_1fdf8_row3_col4" class="data row3 col4" >0.9119</td>
#       <td id="T_1fdf8_row3_col5" class="data row3 col5" >1.1463</td>
#       <td id="T_1fdf8_row3_col6" class="data row3 col6" >2.5638</td>
#       <td id="T_1fdf8_row3_col7" class="data row3 col7" >0.6800</td>
#     </tr>
#     <tr>
#       <th id="T_1fdf8_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_1fdf8_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_1fdf8_row4_col1" class="data row4 col1" >215.3272</td>
#       <td id="T_1fdf8_row4_col2" class="data row4 col2" >1739075.3243</td>
#       <td id="T_1fdf8_row4_col3" class="data row4 col3" >1109.1636</td>
#       <td id="T_1fdf8_row4_col4" class="data row4 col4" >0.9109</td>
#       <td id="T_1fdf8_row4_col5" class="data row4 col5" >1.1391</td>
#       <td id="T_1fdf8_row4_col6" class="data row4 col6" >2.6301</td>
#       <td id="T_1fdf8_row4_col7" class="data row4 col7" >0.6820</td>
#     </tr>
#     <tr>
#       <th id="T_1fdf8_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_1fdf8_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_1fdf8_row5_col1" class="data row5 col1" >215.3273</td>
#       <td id="T_1fdf8_row5_col2" class="data row5 col2" >1739078.1256</td>
#       <td id="T_1fdf8_row5_col3" class="data row5 col3" >1109.1645</td>
#       <td id="T_1fdf8_row5_col4" class="data row5 col4" >0.9109</td>
#       <td id="T_1fdf8_row5_col5" class="data row5 col5"
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
# verificando os hiperparâmetros do modelo 

print(best_model)
# Out:
# HuberRegressor()

# %%
best_model = create_model('omp', fold = 5)
# Out:
# <style type="text/css">
# #T_7d6ce_row5_col0, #T_7d6ce_row5_col1, #T_7d6ce_row5_col2, #T_7d6ce_row5_col3, #T_7d6ce_row5_col4, #T_7d6ce_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7d6ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d6ce_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7d6ce_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7d6ce_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7d6ce_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7d6ce_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7d6ce_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d6ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d6ce_row0_col0" class="data row0 col0" >251.3536</td>
#       <td id="T_7d6ce_row0_col1" class="data row0 col1" >1547477.6272</td>
#       <td id="T_7d6ce_row0_col2" class="data row0 col2" >1243.9765</td>
#       <td id="T_7d6ce_row0_col3" class="data row0 col3" >0.9345</td>
#       <td id="T_7d6ce_row0_col4" class="data row0 col4" >1.1895</td>
#       <td id="T_7d6ce_row0_col5" class="data row0 col5" >2.9093</td>
#     </tr>
#     <tr>
#       <th id="T_7d6ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d6ce_row1_col0" class="data row1 col0" >242.1398</td>
#       <td id="T_7d6ce_row1_col1" class="data row1 col1" >560711.2004</td>
#       <td id="T_7d6ce_row1_col2" class="data row1 col2" >748.8065</td>
#       <td id="T_7d6ce_row1_col3" class="data row1 col3" >0.8236</td>
#       <td id="T_7d6ce_row1_col4" class="data row1 col4" >1.1870</td>
#       <td id="T_7d6ce_row1_col5" class="data row1 col5" >2.5391</td>
#     </tr>
#     <tr>
#       <th id="T_7d6ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d6ce_row2_col0" class="data row2 col0" >196.9644</td>
#       <td id="T_7d6ce_row2_col1" class="data row2 col1" >201650.2234</td>
#       <td id="T_7d6ce_row2_col2" class="data row2 col2" >449.0548</td>
#       <td id="T_7d6ce_row2_col3" class="data row2 col3" >0.9776</td>
#       <td id="T_7d6ce_row2_col4" class="data row2 col4" >1.2807</td>
#       <td id="T_7d6ce_row2_col5" class="data row2 col5" >3.1197</td>
#     </tr>
#     <tr>
#       <th id="T_7d6ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d6ce_row3_col0" class="data row3 col0" >157.6298</td>
#       <td id="T_7d6ce_row3_col1" class="data row3 col1" >67999.2438</td>
#       <td id="T_7d6ce_row3_col2" class="data row3 col2" >260.7666</td>
#       <td id="T_7d6ce_row3_col3" class="data row3 col3" >0.9219</td>
#       <td id="T_7d6ce_row3_col4" class="data row3 col4" >1.1999</td>
#       <td id="T_7d6ce_row3_col5" class="data row3 col5" >2.8298</td>
#     </tr>
#     <tr>
#       <th id="T_7d6ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d6ce_row4_col0" class="data row4 col0" >263.5046</td>
#       <td id="T_7d6ce_row4_col1" class="data row4 col1" >4144194.5509</td>
#       <td id="T_7d6ce_row4_col2" class="data row4 col2" >2035.7295</td>
#       <td id="T_7d6ce_row4_col3" class="data row4 col3" >0.9651</td>
#       <td id="T_7d6ce_row4_col4" class="data row4 col4" >1.0320</td>
#       <td id="T_7d6ce_row4_col5" class="data row4 col5" >1.8779</td>
#     </tr>
#     <tr>
#       <th id="T_7d6ce_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_7d6ce_row5_col0" class="data row5 col0" >222.3184</td>
#       <td id="T_7d6ce_row5_col1" class="data row5 col1" >1304406.5691</td>
#       <td id="T_7d6ce_row5_col2" class="data row5 col2" >947.6668</td>
#       <td id="T_7d6ce_row5_col3" class="data row5 col3" >0.9245</td>
#       <td id="T_7d6ce_row5_col4" class="data row5 col4" >1.1778</td>
#       <td id="T_7d6ce_row5_col5" class="data row5 col5" >2.6551</td>
#     </tr>
#     <tr>
#       <th id="T_7d6ce_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_7d6ce_row6_col0" class="data row6 col0" >39.3946</td>
#       <td id="T_7d6ce_row6_col1" class="data row6 col1" >1511379.2875</td>
#       <td id="T_7d6ce_row6_col2" class="data row6 col2" >637.4435</td>
#       <td id="T_7d6ce_row6_col3" class="data row6 col3" >0.0543</td>
#       <td id="T_7d6ce_row6_col4" class="data row6 col4" >0.0807</td>
#       <td id="T_7d6ce_row6_col5" class="data row6 col5" >0.4309</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### Plotando alguns graficos

# %%
#evaluate_model(best_model)

# %%
#plot_model(best_model, plot = 'learning')

# %%
#plot_model(best_model, plot='vc')

# %%
#plot_model(best_model, plot='error')

# %%
#plot_model(best_model, plot='feature')

# %%
#plot_model(best_model, plot='residuals',  scale = 3)

# %% [markdown]
# ### Tunando o modelo

# %%
tuned = tune_model(best_model, fold = 5)
# Out:
# <style type="text/css">
# #T_00856_row5_col0, #T_00856_row5_col1, #T_00856_row5_col2, #T_00856_row5_col3, #T_00856_row5_col4, #T_00856_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_00856">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00856_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_00856_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_00856_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_00856_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_00856_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_00856_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00856_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00856_row0_col0" class="data row0 col0" >249.5658</td>
#       <td id="T_00856_row0_col1" class="data row0 col1" >1547953.2063</td>
#       <td id="T_00856_row0_col2" class="data row0 col2" >1244.1677</td>
#       <td id="T_00856_row0_col3" class="data row0 col3" >0.9345</td>
#       <td id="T_00856_row0_col4" class="data row0 col4" >1.1419</td>
#       <td id="T_00856_row0_col5" class="data row0 col5" >2.7302</td>
#     </tr>
#     <tr>
#       <th id="T_00856_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00856_row1_col0" class="data row1 col0" >242.1747</td>
#       <td id="T_00856_row1_col1" class="data row1 col1" >567335.1601</td>
#       <td id="T_00856_row1_col2" class="data row1 col2" >753.2165</td>
#       <td id="T_00856_row1_col3" class="data row1 col3" >0.8215</td>
#       <td id="T_00856_row1_col4" class="data row1 col4" >1.1726</td>
#       <td id="T_00856_row1_col5" class="data row1 col5" >2.4145</td>
#     </tr>
#     <tr>
#       <th id="T_00856_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00856_row2_col0" class="data row2 col0" >196.4185</td>
#       <td id="T_00856_row2_col1" class="data row2 col1" >202539.6401</td>
#       <td id="T_00856_row2_col2" class="data row2 col2" >450.0440</td>
#       <td id="T_00856_row2_col3" class="data row2 col3" >0.9775</td>
#       <td id="T_00856_row2_col4" class="data row2 col4" >1.1926</td>
#       <td id="T_00856_row2_col5" class="data row2 col5" >2.9743</td>
#     </tr>
#     <tr>
#       <th id="T_00856_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00856_row3_col0" class="data row3 col0" >157.3257</td>
#       <td id="T_00856_row3_col1" class="data row3 col1" >70017.4080</td>
#       <td id="T_00856_row3_col2" class="data row3 col2" >264.6080</td>
#       <td id="T_00856_row3_col3" class="data row3 col3" >0.9196</td>
#       <td id="T_00856_row3_col4" class="data row3 col4" >1.1821</td>
#       <td id="T_00856_row3_col5" class="data row3 col5" >2.7102</td>
#     </tr>
#     <tr>
#       <th id="T_00856_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00856_row4_col0" class="data row4 col0" >266.0835</td>
#       <td id="T_00856_row4_col1" class="data row4 col1" >4124153.0767</td>
#       <td id="T_00856_row4_col2" class="data row4 col2" >2030.8011</td>
#       <td id="T_00856_row4_col3" class="data row4 col3" >0.9653</td>
#       <td id="T_00856_row4_col4" class="data row4 col4" >0.9990</td>
#       <td id="T_00856_row4_col5" class="data row4 col5" >1.7384</td>
#     </tr>
#     <tr>
#       <th id="T_00856_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_00856_row5_col0" class="data row5 col0" >222.3136</td>
#       <td id="T_00856_row5_col1" class="data row5 col1" >1302399.6982</td>
#       <td id="T_00856_row5_col2" class="data row5 col2" >948.5675</td>
#       <td id="T_00856_row5_col3" class="data row5 col3" >0.9237</td>
#       <td id="T_00856_row5_col4" class="data row5 col4" >1.1376</td>
#       <td id="T_00856_row5_col5" class="data row5 col5" >2.5135</td>
#     </tr>
#     <tr>
#       <th id="T_00856_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_00856_row6_col0" class="data row6 col0" >39.8671</td>
#       <td id="T_00856_row6_col1" class="data row6 col1" >1502755.2553</td>
#       <td id="T_00856_row6_col2" class="data row6 col2" >634.5230</td>
#       <td id="T_00856_row6_col3" class="data row6 col3" >0.0551</td>
#       <td id="T_00856_row6_col4" class="data row6 col4" >0.0714</td>
#       <td id="T_00856_row6_col5" class="data row6 col5" >0.4263</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(tuned)
# Out:
# HuberRegressor(alpha=0.5, epsilon=1.7)

# %%
#plot_model(tuned, plot = 'learning')  #use_train_data = True

# %%
# Validation Curve
#plot_model(tuned, plot='vc')

# %%
#plot_model(tuned, plot='error')

# %%
#plot_model(tuned, plot='feature' )

# %%
#plot_model(tuned, plot='feature', save = True )

# %%
#plot_model(tuned, plot='residuals',  scale = 3)

# %%
final_model_baseline = finalize_model(tuned)

# %% [markdown]
# ### Previsão

# %%
pred_treino = predict_model(final_model_baseline, data = treino)
# Out:
# <style type="text/css">
# </style>
# <table id="T_491e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_491e1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_491e1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_491e1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_491e1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_491e1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_491e1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_491e1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_491e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_491e1_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_491e1_row0_col1" class="data row0 col1" >208.6579</td>
#       <td id="T_491e1_row0_col2" class="data row0 col2" >464149.6933</td>
#       <td id="T_491e1_row0_col3" class="data row0 col3" >681.2853</td>
#       <td id="T_491e1_row0_col4" class="data row0 col4" >0.9802</td>
#       <td id="T_491e1_row0_col5" class="data row0 col5" >1.2169</td>
#       <td id="T_491e1_row0_col6" class="data row0 col6" >2.7134</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_treino
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 270660                         6.0         0.0               0.463208
# 316730                         0.0       186.0              12.130569
# 251278                         0.0       260.0               8.554277
# 430870                         0.0       226.0              30.952818
# 314920                         0.0       369.0               5.450562
# ...                            ...         ...                    ...
# 355030                       454.0    127721.0              32.097408
# 291080                       264.0      5937.0              11.146967
# 430510                        86.0      7345.0              34.121548
# 330330                       165.0      3689.0              36.960739
# 355220                        63.0     11747.0              37.041367
#
#                     densidade_telefonia_movel  media_notas_CN  media_notas_CH  \
# cod_municipio_ibge
# 270660                              33.152462      395.628571      422.762512
# 316730                              67.534187      490.662506      527.674988
# 251278                              66.133064      444.866669      473.833344
# 430870                              88.121902      488.318176      497.261536
# 314920                              94.467270      469.000000      452.000000
# ...                                       ...             ...             ...
# 355030                             125.004189      515.010742      548.616333
# 291080                             125.226761      497.371368      523.909973
# 430510                             101.562866      520.229065      556.289062
# 330330                             125.476761      522.259460      556.662903
# 355220                             119.078194      514.474243      546.214417
#
#                     media_NU_NOTA_LC  media_NU_NOTA_MT  media_NU_NOTA_REDACAO  \
# cod_municipio_ibge
# 270660                    445.825012        436.742859             477.500000
# 316730                    496.262512        539.212524             625.000000
# 251278                    443.799988        451.933319             426.666656
# 430870                    469.307678        565.990906             523.076904
# 314920                    449.950012        554.099976             385.000000
# ...                              ...               ...                    ...
# 355030                    534.100159        581.029175             642.395203
# 291080                    509.181915        543.344971             647.652283
# 430510                    535.819946        581.916504             657.943054
# 330330                    536.360840        592.505432             711.747864
# 355220                    531.277527        577.488953             639.773743
#
#                     valor_medio_recebido_familia  ...  Isencao_Tx_Sim  \
# cod_municipio_ibge                                ...
# 270660                                     22696  ...               0
# 316730                                     16927  ...               0
# 251278                                     24526  ...               0
# 430870                                     16597  ...               0
# 314920                                     26848  ...               0
# ...                                          ...  ...             ...
# 355030                                     18959  ...               0
# 291080                                     15754  ...               0
# 430510                                     19763  ...               0
# 330330                                     19694  ...               1
# 355220                                     18931  ...               1
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 270660                                0                    0
# 316730                                0                    0
# 251278                                1                    1
# 430870                                0                    0
# 314920                                0                    0
# ...                                 ...                  ...
# 355030                                0                    0
# 291080                                0                    0
# 430510                                0                    0
# 330330                                0                    0
# 355220                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 270660                                  0          1           0          0
# 316730                                  0          0           1          0
# 251278                                  0          1           0          0
# 430870                                  0          0           0          0
# 314920                                  0          0           0          0
# ...                                   ...        ...         ...        ...
# 355030                                  1          0           0          1
# 291080                                  0          0           0          0
# 430510                                  0          0           0          1
# 330330                                  0          1           0          0
# 355220                                  0          0           0          1
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 270660                       0                                 33
# 316730                       0                                 26
# 251278                       0                                 15
# 430870                       0                                 74
# 314920                       0                                 37
# ...                        ...                                ...
# 355030                       0                             253408
# 291080                       0                               9589
# 430510                       0                               9898
# 330330                       0                               9251
# 355220                       0                              17213
#
#                     prediction_label
# cod_municipio_ibge
# 270660                    -66.270135
# 316730                   -160.388043
# 251278                   -166.903976
# 430870                    -39.108656
# 314920                    -75.548575
# ...                              ...
# 355030                 234559.721186
# 291080                  11632.273214
# 430510                   9785.077541
# 330330                   9718.190138
# 355220                  13040.464633
#
# [4178 rows x 29 columns]

# %%
plt.scatter(pred_treino['qtd_abertas_Empresario_Individual'],pred_treino['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# Previsão de dados não vistos

# %%
pred_unseen = predict_model(final_model_baseline, data = teste)
# Out:
# <style type="text/css">
# </style>
# <table id="T_53137">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53137_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_53137_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_53137_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_53137_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_53137_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_53137_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_53137_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53137_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53137_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_53137_row0_col1" class="data row0 col1" >195.8194</td>
#       <td id="T_53137_row0_col2" class="data row0 col2" >214832.2376</td>
#       <td id="T_53137_row0_col3" class="data row0 col3" >463.5000</td>
#       <td id="T_53137_row0_col4" class="data row0 col4" >0.9395</td>
#       <td id="T_53137_row0_col5" class="data row0 col5" >1.2283</td>
#       <td id="T_53137_row0_col6" class="data row0 col6" >2.6779</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_unseen
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110005                         3.0       591.0               8.540527
# 110007                         1.0       382.0               3.261486
# 110008                         3.0       573.0               4.388471
# 110011                        10.0      1484.0              20.346228
# 110013                         6.0      1214.0               7.779695
# ...                            ...         ...                    ...
# 522100                         5.0       195.0               2.852253
# 522119                         4.0       271.0              10.329089
# 522190                         0.0       184.0               9.433472
# 522200                         1.0       528.0               6.423907
# 522230                         0.0       344.0               7.187342
#
#                     densidade_telefonia_movel  media_notas_CN  media_notas_CH  \
# cod_municipio_ibge
# 110005                             108.074341      479.268738      477.045715
# 110007                              51.545662      439.184601      466.414276
# 110008                              35.367435      438.418182      465.692108
# 110011                             101.132721      472.343292      501.169189
# 110013                              56.914486      460.839630      482.138611
# ...                                       ...             ...             ...
# 522100                             103.565315      464.779999      487.066681
# 522119                             116.298340      435.885712      480.299988
# 522190                              78.092514      426.950012      483.766663
# 522200                             106.821411      449.954041      479.917084
# 522230                              39.892273      432.055542      417.394745
#
#                     media_NU_NOTA_LC  media_NU_NOTA_MT  media_NU_NOTA_REDACAO  \
# cod_municipio_ibge
# 110005                    454.722870        480.696869             576.571411
# 110007                    432.535706        445.276917             577.142883
# 110008                    451.828949        478.290924             492.105255
# 110011                    481.437683        507.111206             590.000000
# 110013                    470.749115        485.543396             503.508759
# ...                              ...               ...                    ...
# 522100                    474.000000        520.359985             576.666687
# 522119                    450.257141        503.938110             485.714294
# 522190                    451.266663        422.950012             213.333328
# 522200                    473.014648        516.186462             553.658508
# 522230                    428.821045        460.816681             444.210541
#
#                     valor_medio_recebido_familia  ...  Isencao_Tx_Sim  \
# cod_municipio_ibge                                ...
# 110005                                     17752  ...               0
# 110007                                     17512  ...               0
# 110008                                     20099  ...               1
# 110011                                     16120  ...               0
# 110013                                     16738  ...               0
# ...                                          ...  ...             ...
# 522100                                     17311  ...               0
# 522119                                     20453  ...               0
# 522190                                     16663  ...               0
# 522200                                     19058  ...               0
# 522230                                     16764  ...               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110005                                0                    0
# 110007                                1                    0
# 110008                                1                    0
# 110011                                0                    0
# 110013                                0                    0
# ...                                 ...                  ...
# 522100                                0                    0
# 522119                                1                    0
# 522190                                0                    0
# 522200                                0                    0
# 522230                                1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110005                                  0          1           0          0
# 110007                                  1          0           0          0
# 110008                                  0          1           0          0
# 110011                                  0          0           0          1
# 110013                                  1          1           0          0
# ...                                   ...        ...         ...        ...
# 522100                                  0          0           0          0
# 522119                                  0          0           1          0
# 522190                                  0          0           1          0
# 522200                                  0          0           1          0
# 522230                                  0          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110005                       0                                257
# 110007                       0                                 86
# 110008                       0                                106
# 110011                       0                                617
# 110013                       0                                279
# ...                        ...                                ...
# 522100                       0                                 41
# 522119                       0                                108
# 522190                       0                                 30
# 522200                       0                                222
# 522230                       0                                 47
#
#                     prediction_label
# cod_municipio_ibge
# 110005                    239.784934
# 110007                     40.176678
# 110008                    212.981765
# 110011                    791.458921
# 110013                    582.664886
# ...                              ...
# 522100                     41.790639
# 522119                    135.813482
# 522190                     37.799159
# 522200                    215.667610
# 522230                     23.433030
#
# [1392 rows x 29 columns]

# %%
plt.scatter(pred_unseen['qtd_abertas_Empresario_Individual'],pred_unseen['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ## Previsão - Novos dados (VIs = 2018 e VD = 2019)

# %%
pred_treino_2 = predict_model(final_model_baseline, data = df_2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bbf54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbf54_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bbf54_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bbf54_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bbf54_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bbf54_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bbf54_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bbf54_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbf54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bbf54_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_bbf54_row0_col1" class="data row0 col1" >213.4012</td>
#       <td id="T_bbf54_row0_col2" class="data row0 col2" >441374.4084</td>
#       <td id="T_bbf54_row0_col3" class="data row0 col3" >664.3601</td>
#       <td id="T_bbf54_row0_col4" class="data row0 col4" >0.9735</td>
#       <td id="T_bbf54_row0_col5" class="data row0 col5" >1.3087</td>
#       <td id="T_bbf54_row0_col6" class="data row0 col6" >3.3123</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_treino_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     5570 non-null   float32
#  1   RH_adm_dir                         5570 non-null   float32
#  2   densidade_banda_larga              5570 non-null   float32
#  3   densidade_telefonia_movel          5570 non-null   float32
#  4   media_notas_CN                     5570 non-null   float32
#  5   media_notas_CH                     5570 non-null   float32
#  6   media_NU_NOTA_LC                   5570 non-null   float32
#  7   media_NU_NOTA_MT                   5570 non-null   float32
#  8   media_NU_NOTA_REDACAO              5570 non-null   float32
#  9   valor_medio_recebido_familia       5570 non-null   int32
#  10  pib_per_capita_preco_corrente      5570 non-null   float32
#  11  perc_20_59_anos                    5570 non-null   float32
#  12  pop_total                          5570 non-null   int32
#  13  total_sim_tecnologia               5570 non-null   float32
#  14  porte_municipio                    5570 non-null   int8
#  15  Mecanismos_incentivo_Sim           5570 non-null   uint8
#  16  Reducao_IPTU_Sim                   5570 non-null   uint8
#  17  Isencao_IPTU_Sim                   5570 non-null   uint8
#  18  Reducao_ISSQN_Sim                  5570 non-null   uint8
#  19  Isencao_ISSQN_Sim                  5570 non-null   uint8
#  20  Isencao_Tx_Sim                     5570 non-null   uint8
#  21  Cessao_terrenos_Sim                5570 non-null   uint8
#  22  Doacao_terrenos_Sim                5570 non-null   uint8
#  23  Outros_mecanismos_Sim              5570 non-null   uint8
#  24  ISH_Baixa                          5570 non-null   uint8
#  25  ISH_Máxima                         5570 non-null   uint8
#  26  ISH_Média                          5570 non-null   uint8
#  27  ISH_Mínima                         5570 non-null   uint8
#  28  qtd_abertas_Empresario_Individual  5570 non-null   int32
#  29  prediction_label                   5570 non-null   float64
# dtypes: float32(12), float64(1), int32(3), int8(1), uint8(13)
# memory usage: 618.6 KB

# %%
pred_treino_2
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382995
# 110005                         2.0       591.0               7.847822
# ...                            ...         ...                    ...
# 522200                         2.0       528.0               7.191805
# 522205                         4.0       394.0               8.601167
# 522220                         3.0       403.0               5.055907
# 522230                         2.0       344.0               2.817385
# 530010                       530.0    122197.0              23.930012
#
#                     densidade_telefonia_movel  media_notas_CN  media_notas_CH  \
# cod_municipio_ibge
# 110001                              34.342995      480.664276      543.020264
# 110002                              86.588539      481.314240      549.247253
# 110003                              79.838104      442.604156      506.685181
# 110004                              89.462151      484.990723      549.739380
# 110005                              89.952827      466.433807      551.494751
# ...                                       ...             ...             ...
# 522200                              33.744499      474.571777      522.414612
# 522205                              78.874527      439.651611      498.125641
# 522220                               5.833738      440.164276      513.099976
# 522230                              26.473114      451.296661      498.101593
# 530010                             117.493172      510.176941      580.567993
#
#                     media_NU_NOTA_LC  media_NU_NOTA_MT  media_NU_NOTA_REDACAO  \
# cod_municipio_ibge
# 110001                    495.929718        502.991425             453.783783
# 110002                    513.304749        512.975891             461.418030
# 110003                    466.007416        484.924988             391.111115
# 110004                    513.924805        524.946716             482.419617
# 110005                    498.394745        493.949310             440.789459
# ...                              ...               ...                    ...
# 522200                    493.386505        503.091766             446.516846
# 522205                    463.625641        479.803223             362.051270
# 522220                    450.394440        504.899994             346.666656
# 522230                    463.396820        471.051666             369.206360
# 530010                    546.609680        552.578613             546.970764
#
#                     valor_medio_recebido_familia  ...  Isencao_Tx_Sim  \
# cod_municipio_ibge                                ...
# 110001                                     15747  ...               0
# 110002                                     14890  ...               1
# 110003                                     14451  ...               0
# 110004                                     15214  ...               1
# 110005                                     15255  ...               0
# ...                                          ...  ...             ...
# 522200                                     16064  ...               0
# 522205                                     15749  ...               1
# 522220                                     15874  ...               0
# 522230                                     14436  ...               0
# 530010                                     17438  ...               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
# ...                                 ...                  ...
# 522200                                0                    0
# 522205                                0                    1
# 522220                                1                    1
# 522230                                1                    0
# 530010                                1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
# ...                                   ...        ...         ...        ...
# 522200                                  0          0           1          0
# 522205                                  0          0           0          1
# 522220                                  0          0           0          0
# 522230                                  0          0           0          0
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110001                       0                                167
# 110002                       0                               1058
# 110003                       0                                 50
# 110004                       0                                987
# 110005                       0                                181
# ...                        ...                                ...
# 522200                       0                                150
# 522205                       0                                 47
# 522220                       0                                 22
# 522230                       0                                 25
# 530010                       0                              47504
#
#                     prediction_label
# cod_municipio_ibge
# 110001                    250.269144
# 110002                   1824.971830
# 110003                    -76.449116
# 110004                   1425.764097
# 110005                    137.659054
# ...                              ...
# 522200                     95.098506
# 522205                     11.678748
# 522220                    -81.537281
# 522230                    -59.197835
# 530010                  56256.393364
#
# [5570 rows x 30 columns]

# %%
plt.scatter(pred_treino_2['qtd_abertas_Empresario_Individual'],pred_treino_2['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %%
pred_treino_2.to_excel('dados_previsao_teste_omp.xlsx')

# %% [markdown]
# ## Testando Radom Forest

# %% [markdown]
# ### MAPE

# %%
#regression_setup = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)

# %%
#best_model_mape = compare_models(sort = 'MAPE', fold=5)

# %%
#print(best_model_mape)

# %%
#best_model_mape = create_model('rf', fold = 5)

# %%
#tuned_mape = tune_model(best_model_mape, fold = 5)

# %%
#plot_model(best_model_mape, plot='feature' )

# %%
#final_model_baseline_mape = finalize_model(best_model_mape)

# %%
#pred_teste_mape= predict_model(final_model_baseline_mape, data = teste)

# %%
#pred_teste_mape

# %%
#plt.scatter(pred_teste_mape['qtd_abertas_Empresario_Individual'],pred_teste_mape['prediction_label'])
#plt.xlabel('Valores reais')
#plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')

# %%
#pred_teste_mape.to_excel('previsao_mape.xlsx')

# %% [markdown]
# ### Previsão - Mape 2019

# %%
#pred_2018_2019 = predict_model(final_model_baseline_mape, data = df_2)

# %%
#pred_2018_2019

# %%
#plt.scatter(pred_2018_2019['qtd_abertas_Empresario_Individual'],pred_2018_2019['prediction_label'])
#plt.xlabel('Valores reais')
#plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')

# %%
#pred_2018_2019.to_excel('previsao_mape_2018_2019.xlsx')

# %% [markdown]
# ## Clusterização

# %% [markdown]
# ###  K-means 2022

# %%
df_c_22 = df

# %%
df_c_22 = df.drop('qtd_abertas_Empresario_Individual', axis = 1)
df_c_22= df_c_22.drop('porte_municipio', axis = 1)

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         8.0       926.0               8.958074
# 110002                        38.0      2563.0              21.363407
# 110003                         0.0       344.0               5.407539
# 110004                        21.0      1971.0              19.480189
# 110005                         3.0       591.0               8.540527
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              70.647540                     2.0
# 110002                              93.858639                    99.0
# 110003                              78.369844                     0.0
# 110004                             105.350861                   184.0
# 110005                             108.074341                     4.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     30.0      497.721951
# 110002                                    342.0      474.773986
# 110003                                      0.0      477.266667
# 110004                                    422.0      489.744000
# 110005                                     35.0      479.268750
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  504.034091        491.079545        543.558537  ...
# 110002                  495.727950        484.710248        518.811149  ...
# 110003                  486.071429        447.628571        522.883333  ...
# 110004                  505.006061        490.991919        533.458933  ...
# 110005                  477.045714        454.722857        480.696875  ...
#
#                     Reducao_ISSQN_Sim  Isencao_ISSQN_Sim  Isencao_Tx_Sim  \
# cod_municipio_ibge
# 110001                              0                  0               0
# 110002                              0                  0               1
# 110003                              0                  1               0
# 110004                              1                  0               1
# 110005                              0                  0               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima
# cod_municipio_ibge
# 110001                       0
# 110002                       0
# 110003                       0
# 110004                       0
# 110005                       0
#
# [5 rows x 29 columns]

# %%
df_c_22 = df_c_22.astype('int64')

# %%
df_c_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   taxa_homicidio                 5570 non-null   int64
#  1   RH_adm_dir                     5570 non-null   int64
#  2   densidade_banda_larga          5570 non-null   int64
#  3   densidade_telefonia_movel      5570 non-null   int64
#  4   qtd_cursos_engenharias         5570 non-null   int64
#  5   qtd_cursos_negocios_direito    5570 non-null   int64
#  6   media_notas_CN                 5570 non-null   int64
#  7   media_notas_CH                 5570 non-null   int64
#  8   media_NU_NOTA_LC               5570 non-null   int64
#  9   media_NU_NOTA_MT               5570 non-null   int64
#  10  media_NU_NOTA_REDACAO          5570 non-null   int64
#  11  valor_medio_recebido_familia   5570 non-null   int64
#  12  pib_per_capita_preco_corrente  5570 non-null   int64
#  13  perc_20_59_anos                5570 non-null   int64
#  14  pop_total                      5570 non-null   int64
#  15  total_sim_tecnologia           5570 non-null   int64
#  16  Mecanismos_incentivo_Sim       5570 non-null   int64
#  17  Reducao_IPTU_Sim               5570 non-null   int64
#  18  Isencao_IPTU_Sim               5570 non-null   int64
#  19  Reducao_ISSQN_Sim              5570 non-null   int64
#  20  Isencao_ISSQN_Sim              5570 non-null   int64
#  21  Isencao_Tx_Sim                 5570 non-null   int64
#  22  Cessao_terrenos_Sim            5570 non-null   int64
#  23  Doacao_terrenos_Sim            5570 non-null   int64
#  24  Outros_mecanismos_Sim          5570 non-null   int64
#  25  ISH_Baixa                      5570 non-null   int64
#  26  ISH_Máxima                     5570 non-null   int64
#  27  ISH_Média                      5570 non-null   int64
#  28  ISH_Mínima                     5570 non-null   int64
# dtypes: int64(29)
# memory usage: 1.3 MB

# %%
valores_k =[]
inercias =[]

for i in range(1,15):
    cluster_empr = KMeans(n_clusters=i, random_state=42).fit(df_c_22)
    valores_k.append(i)
    inercias.append(cluster_empr.inertia_)

# %%
fig, ax = plt.subplots()

ax.plot(valores_k,inercias)

plt.show()

# %%
cluster_empr_22 = KMeans(n_clusters=5, random_state=42).fit(df_c_22)

# %%
cluster_empr_22.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 3])

# %%
fig, ax = plt.subplots(figsize= (15,10))

ax.scatter(df_c_22.iloc[:,1], df_c_22.iloc[:,0], c = cluster_empr_22.labels_)

plt.show()

# %%
df_c_22['cluster'] = cluster_empr_22.labels_

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster
# cod_municipio_ibge
# 110001                       0          0           0        0
# 110002                       0          1           0        0
# 110003                       0          0           0        0
# 110004                       0          0           0        0
# 110005                       0          0           0        0
#
# [5 rows x 30 columns]

# %%
col_empr = df['qtd_abertas_Empresario_Individual']
display(col_empr)
  
df_c_22 = df_c_22.join(col_empr )
# Out:
# cod_municipio_ibge
# 110001      194
# 110002     1275
# 110003       49
# 110004     1258
# 110005      257
#           ...
# 522200      222
# 522205       66
# 522220       23
# 522230       47
# 530010    54325
# Name: qtd_abertas_Empresario_Individual, Length: 5570, dtype: int64

# %%
df_c_22
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
# ...                            ...         ...                    ...
# 522200                           1         528                      6
# 522205                           0         394                      8
# 522220                           0         403                      1
# 522230                           0         344                      7
# 530010                         480      122197                     25
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
# ...                                       ...                     ...
# 522200                                    106                       4
# 522205                                    104                       0
# 522220                                     66                       0
# 522230                                     39                       0
# 530010                                    109                    2210
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
# ...                                         ...             ...
# 522200                                       12             449
# 522205                                        0             450
# 522220                                        0             431
# 522230                                        0             432
# 530010                                    13097             505
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
# ...                            ...               ...               ...  ...
# 522200                         479               473               516  ...
# 522205                         464               457               504  ...
# 522220                         443               426               445  ...
# 522230                         417               428               460  ...
# 530010                         534               522               552  ...
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
# ...                                 ...                  ...
# 522200                                0                    0
# 522205                                0                    1
# 522220                                1                    1
# 522230                                1                    0
# 530010                                1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
# ...                                   ...        ...         ...        ...
# 522200                                  0          0           1          0
# 522205                                  0          0           0          1
# 522220                                  0          0           0          0
# 522230                                  0          0           0          0
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  cluster  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110001                       0        0                                194
# 110002                       0        0                               1275
# 110003                       0        0                                 49
# 110004                       0        0                               1258
# 110005                       0        0                                257
# ...                        ...      ...                                ...
# 522200                       0        0                                222
# 522205                       0        0                                 66
# 522220                       0        0                                 23
# 522230                       0        0                                 47
# 530010                       0        3                              54325
#
#                     novos_clusters
# cod_municipio_ibge
# 110001                           0
# 110002                           0
# 110003                           0
# 110004                           0
# 110005                           0
# ...                            ...
# 522200                           0
# 522205                           0
# 522220                           0
# 522230                           0
# 530010                           1
#
# [5570 rows x 32 columns]

# %%
df_c_22['cluster'].value_counts()
# Out:
# 0    5432
# 4     125
# 3      11
# 2       1
# 1       1
# Name: cluster, dtype: int64

# %%
df_c_22.loc[df_c_22['cluster'] == 0,'novos_clusters'] = 0

# %%
df_c_22.loc[df_c_22['cluster'] == 1,'novos_clusters'] = 1

# %%
df_c_22.loc[df_c_22['cluster'] == 2,'novos_clusters'] = 1

# %%
df_c_22.loc[df_c_22['cluster'] == 3,'novos_clusters'] = 1

# %%
df_c_22.loc[df_c_22['cluster'] == 4,'novos_clusters'] = 2

# %%
df_c_22 = df_c_22.astype('int64')

# %%
#df_c_22.to_excel('df_c_22.xlsx')

# %% [markdown]
# ### Kmeans - 2019

# %%
df_c_19 = df_2

# %%
df_c_19 = df_c_19.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %%
df_c_19.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382994
# 110005                         2.0       591.0               7.847822
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342994                     6.0
# 110002                              86.588543                    42.0
# 110003                              79.838102                     0.0
# 110004                              89.462154                   202.0
# 110005                              89.952827                     0.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664286
# 110002                                    299.0      481.314239
# 110003                                      0.0      442.604167
# 110004                                    469.0      484.990720
# 110005                                     38.0      466.433803
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  543.020270        495.929730        502.991429  ...
# 110002                  549.247267        513.304727        512.975890  ...
# 110003                  506.685185        466.007407        484.925000  ...
# 110004                  549.739357        513.924809        524.946720  ...
# 110005                  551.494737        498.394737        493.949296  ...
#
#                     Reducao_ISSQN_Sim  Isencao_ISSQN_Sim  Isencao_Tx_Sim  \
# cod_municipio_ibge
# 110001                              0                  0               0
# 110002                              0                  0               1
# 110003                              0                  1               0
# 110004                              1                  0               1
# 110005                              0                  0               0
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima
# cod_municipio_ibge
# 110001                       0
# 110002                       0
# 110003                       0
# 110004                       0
# 110005                       0
#
# [5 rows x 30 columns]

# %%
df_c_19 = df_c_19.astype('int64')

# %%
df_c_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   taxa_homicidio                 5570 non-null   int64
#  1   RH_adm_dir                     5570 non-null   int64
#  2   densidade_banda_larga          5570 non-null   int64
#  3   densidade_telefonia_movel      5570 non-null   int64
#  4   qtd_cursos_engenharias         5570 non-null   int64
#  5   qtd_cursos_negocios_direito    5570 non-null   int64
#  6   media_notas_CN                 5570 non-null   int64
#  7   media_notas_CH                 5570 non-null   int64
#  8   media_NU_NOTA_LC               5570 non-null   int64
#  9   media_NU_NOTA_MT               5570 non-null   int64
#  10  media_NU_NOTA_REDACAO          5570 non-null   int64
#  11  valor_medio_recebido_familia   5570 non-null   int64
#  12  pib_per_capita_preco_corrente  5570 non-null   int64
#  13  perc_20_59_anos                5570 non-null   int64
#  14  pop_total                      5570 non-null   int64
#  15  total_sim_tecnologia           5570 non-null   int64
#  16  porte_municipio                5570 non-null   int64
#  17  Mecanismos_incentivo_Sim       5570 non-null   int64
#  18  Reducao_IPTU_Sim               5570 non-null   int64
#  19  Isencao_IPTU_Sim               5570 non-null   int64
#  20  Reducao_ISSQN_Sim              5570 non-null   int64
#  21  Isencao_ISSQN_Sim              5570 non-null   int64
#  22  Isencao_Tx_Sim                 5570 non-null   int64
#  23  Cessao_terrenos_Sim            5570 non-null   int64
#  24  Doacao_terrenos_Sim            5570 non-null   int64
#  25  Outros_mecanismos_Sim          5570 non-null   int64
#  26  ISH_Baixa                      5570 non-null   int64
#  27  ISH_Máxima                     5570 non-null   int64
#  28  ISH_Média                      5570 non-null   int64
#  29  ISH_Mínima                     5570 non-null   int64
# dtypes: int64(30)
# memory usage: 1.4 MB

# %%
valores_k =[]
inercias =[]

for i in range(1,15):
    cluster_empr = KMeans(n_clusters=i, random_state=42).fit(df_c_19)
    valores_k.append(i)
    inercias.append(cluster_empr.inertia_)

# %%
fig, ax = plt.subplots()

ax.plot(valores_k,inercias)

plt.show()

# %%
cluster_empr_19 = KMeans(n_clusters=3, random_state=42).fit(df_c_19)

# %%
cluster_empr_19.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
#verificar se eu dividi as posições de x e y corretamente

fig, ax = plt.subplots(figsize= (15,10))

ax.scatter(df_c_19.iloc[:,1], df_c_19.iloc[:,0], c = cluster_empr_19.labels_)

plt.show()

# %%
df_c_19['cluster'] = cluster_empr_19.labels_

# %%
df_c_19.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           7         926                      5
# 110002                          41        2563                     11
# 110003                           0         344                      3
# 110004                          17        1971                     12
# 110005                           2         591                      7
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     34                       6
# 110002                                     86                      42
# 110003                                     79                       0
# 110004                                     89                     202
# 110005                                     89                       0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       23             480
# 110002                                      299             481
# 110003                                        0             442
# 110004                                      469             484
# 110005                                       38             466
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         543               495               502  ...
# 110002                         549               513               512  ...
# 110003                         506               466               484  ...
# 110004                         549               513               524  ...
# 110005                         551               498               493  ...
#
#                     Isencao_ISSQN_Sim  Isencao_Tx_Sim  Cessao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                              0               0                    0
# 110002                              0               1                    0
# 110003                              1               0                    0
# 110004                              0               1                    1
# 110005                              0               0                    0
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster
# cod_municipio_ibge
# 110001                       0          0           0        0
# 110002                       0          1           0        0
# 110003                       0          0           0        0
# 110004                       0          0           0        0
# 110005                       0          0           0        0
#
# [5 rows x 31 columns]

# %%
df_c_19= df_c_19.drop('porte_municipio', axis = 1)

# %%
col_empr = df_2['qtd_abertas_Empresario_Individual']
display(col_empr)
  
df_c_19 = df_c_19.join(col_empr)
# Out:
# cod_municipio_ibge
# 110001      167
# 110002     1058
# 110003       50
# 110004      987
# 110005      181
#           ...
# 522200      150
# 522205       47
# 522220       22
# 522230       25
# 530010    47504
# Name: qtd_abertas_Empresario_Individual, Length: 5570, dtype: int64

# %%
col_clu = df_c_22['novos_clusters']
display(col_clu)
  
df_c_19 = df_c_19.join(col_clu)
# Out:
# cod_municipio_ibge
# 110001    0
# 110002    0
# 110003    0
# 110004    0
# 110005    0
#          ..
# 522200    0
# 522205    0
# 522220    0
# 522230    0
# 530010    1
# Name: novos_clusters, Length: 5570, dtype: int64

# %%
df_c_19
# Out:
#                     qtd_abertas_Empresario_Individual  taxa_homicidio  \
# cod_municipio_ibge
# 110001                                            167             7.0
# 110002                                           1058            41.0
# 110003                                             50             0.0
# 110004                                            987            17.0
# 110005                                            181             2.0
# ...                                               ...             ...
# 522200                                            150             2.0
# 522205                                             47             4.0
# 522220                                             22             3.0
# 522230                                             25             2.0
# 530010                                          47504           530.0
#
#                     RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                   926.0               5.391153
# 110002                  2563.0              11.445074
# 110003                   344.0               3.990964
# 110004                  1971.0              12.382994
# 110005                   591.0               7.847822
# ...                        ...                    ...
# 522200                   528.0               7.191806
# 522205                   394.0               8.601167
# 522220                   403.0               5.055907
# 522230                   344.0               2.817385
# 530010                122197.0              23.930012
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342994                     6.0
# 110002                              86.588543                    42.0
# 110003                              79.838102                     0.0
# 110004                              89.462154                   202.0
# 110005                              89.952827                     0.0
# ...                                       ...                     ...
# 522200                              33.744500                     0.0
# 522205                              78.874528                     0.0
# 522220                               5.833738                     0.0
# 522230                              26.473115                     0.0
# 530010                             117.493171                  3082.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664286
# 110002                                    299.0      481.314239
# 110003                                      0.0      442.604167
# 110004                                    469.0      484.990720
# 110005                                     38.0      466.433803
# ...                                         ...             ...
# 522200                                      0.0      474.571765
# 522205                                      0.0      439.651613
# 522220                                      0.0      440.164286
# 522230                                      0.0      451.296667
# 530010                                  15811.0      510.176935
#
#                     media_notas_CH  media_NU_NOTA_LC  ...  Isencao_ISSQN_Sim  \
# cod_municipio_ibge                                    ...
# 110001                  543.020270        495.929730  ...                  0
# 110002                  549.247267        513.304727  ...                  0
# 110003                  506.685185        466.007407  ...                  1
# 110004                  549.739357        513.924809  ...                  0
# 110005                  551.494737        498.394737  ...                  0
# ...                            ...               ...  ...                ...
# 522200                  522.414607        493.386517  ...                  0
# 522205                  498.125641        463.625641  ...                  0
# 522220                  513.100000        450.394444  ...                  0
# 522230                  498.101587        463.396825  ...                  0
# 530010                  580.567979        546.609685  ...                  0
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                           0                    0                    0
# 110002                           1                    0                    1
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110005                           0                    0                    0
# ...                            ...                  ...                  ...
# 522200                           0                    0                    0
# 522205                           1                    0                    1
# 522220                           0                    1                    1
# 522230                           0                    1                    0
# 530010                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
# ...                                   ...        ...         ...        ...
# 522200                                  0          0           1          0
# 522205                                  0          0           0          1
# 522220                                  0          0           0          0
# 522230                                  0          0           0          0
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  novos_clusters
# cod_municipio_ibge
# 110001                       0               0
# 110002                       0               0
# 110003                       0               0
# 110004                       0               0
# 110005                       0               0
# ...                        ...             ...
# 522200                       0               0
# 522205                       0               0
# 522220                       0               0
# 522230                       0               0
# 530010                       0               1
#
# [5570 rows x 32 columns]

# %% [markdown]
# ## Treinando o modelo com Cluster

# %% [markdown]
# ### 2022

# %%
df_c_22.head()
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           8         926                      8
# 110002                          38        2563                     21
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110005                           3         591                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     70                       2
# 110002                                     93                      99
# 110003                                     78                       0
# 110004                                    105                     184
# 110005                                    108                       4
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       30             497
# 110002                                      342             474
# 110003                                        0             477
# 110004                                      422             489
# 110005                                       35             479
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         504               491               543  ...
# 110002                         495               484               518  ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110005                         477               454               480  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                           0                    0                    0
# 110002                           1                    0                    1
# 110003                           0                    0                    0
# 110004                           1                    1                    1
# 110005                           0                    0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110001                       0                                194
# 110002                       0                               1275
# 110003                       0                                 49
# 110004                       0                               1258
# 110005                       0                                257
#
#                     novos_clusters
# cod_municipio_ibge
# 110001                           0
# 110002                           0
# 110003                           0
# 110004                           0
# 110005                           0
#
# [5 rows x 31 columns]

# %%
#df_c_22= df_c_22.drop('cluster', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df_c_22= df_c_22.drop('cluster', axis = 1)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['cluster'] not found in axis"

# %%
#df_c_22 = pd.get_dummies(df_c_22, columns = ['cluster']) #drop_first=True

# %%
h = FeatureHasher(n_features=4)
f = h.transform(df_c_22['cluster'])
f.toarray()

# %%
df_c_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 110001 to 530010
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     5570 non-null   int64
#  1   RH_adm_dir                         5570 non-null   int64
#  2   densidade_banda_larga              5570 non-null   int64
#  3   densidade_telefonia_movel          5570 non-null   int64
#  4   qtd_cursos_engenharias             5570 non-null   int64
#  5   qtd_cursos_negocios_direito        5570 non-null   int64
#  6   media_notas_CN                     5570 non-null   int64
#  7   media_notas_CH                     5570 non-null   int64
#  8   media_NU_NOTA_LC                   5570 non-null   int64
#  9   media_NU_NOTA_MT                   5570 non-null   int64
#  10  media_NU_NOTA_REDACAO              5570 non-null   int64
#  11  valor_medio_recebido_familia       5570 non-null   int64
#  12  pib_per_capita_preco_corrente      5570 non-null   int64
#  13  perc_20_59_anos                    5570 non-null   int64
#  14  pop_total                          5570 non-null   int64
#  15  total_sim_tecnologia               5570 non-null   int64
#  16  Mecanismos_incentivo_Sim           5570 non-null   int64
#  17  Reducao_IPTU_Sim                   5570 non-null   int64
#  18  Isencao_IPTU_Sim                   5570 non-null   int64
#  19  Reducao_ISSQN_Sim                  5570 non-null   int64
#  20  Isencao_ISSQN_Sim                  5570 non-null   int64
#  21  Isencao_Tx_Sim                     5570 non-null   int64
#  22  Cessao_terrenos_Sim                5570 non-null   int64
#  23  Doacao_terrenos_Sim                5570 non-null   int64
#  24  Outros_mecanismos_Sim              5570 non-null   int64
#  25  ISH_Baixa                          5570 non-null   int64
#  26  ISH_Máxima                         5570 non-null   int64
#  27  ISH_Média                          5570 non-null   int64
#  28  ISH_Mínima                         5570 non-null   int64
#  29  qtd_abertas_Empresario_Individual  5570 non-null   int64
#  30  novos_clusters                     5570 non-null   int64
# dtypes: int64(31)
# memory usage: 1.5 MB

# %%
treino_clus = df_c_22.groupby('qtd_cursos_negocios_direito', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste_clus = df_c_22.drop(treino_clus.index)

print(treino_clus.shape, teste_clus.shape)
# Out:
# (4276, 31) (1294, 31)

# %%
#treino_clus = pd.get_dummies(treino_clus, columns = ['cluster'], drop_first=True)
#teste_clus = pd.get_dummies(teste_clus, columns = ['cluster'], drop_first=True)

# %%
treino_clus = treino_clus.drop('qtd_cursos_negocios_direito', axis = 1)
teste_clus = teste_clus.drop('qtd_cursos_negocios_direito', axis = 1)

# %%
teste_clus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1294 entries, 110007 to 522205
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     1294 non-null   int64
#  1   RH_adm_dir                         1294 non-null   int64
#  2   densidade_banda_larga              1294 non-null   int64
#  3   densidade_telefonia_movel          1294 non-null   int64
#  4   qtd_cursos_engenharias             1294 non-null   int64
#  5   media_notas_CN                     1294 non-null   int64
#  6   media_notas_CH                     1294 non-null   int64
#  7   media_NU_NOTA_LC                   1294 non-null   int64
#  8   media_NU_NOTA_MT                   1294 non-null   int64
#  9   media_NU_NOTA_REDACAO              1294 non-null   int64
#  10  valor_medio_recebido_familia       1294 non-null   int64
#  11  pib_per_capita_preco_corrente      1294 non-null   int64
#  12  perc_20_59_anos                    1294 non-null   int64
#  13  pop_total                          1294 non-null   int64
#  14  total_sim_tecnologia               1294 non-null   int64
#  15  Mecanismos_incentivo_Sim           1294 non-null   int64
#  16  Reducao_IPTU_Sim                   1294 non-null   int64
#  17  Isencao_IPTU_Sim                   1294 non-null   int64
#  18  Reducao_ISSQN_Sim                  1294 non-null   int64
#  19  Isencao_ISSQN_Sim                  1294 non-null   int64
#  20  Isencao_Tx_Sim                     1294 non-null   int64
#  21  Cessao_terrenos_Sim                1294 non-null   int64
#  22  Doacao_terrenos_Sim                1294 non-null   int64
#  23  Outros_mecanismos_Sim              1294 non-null   int64
#  24  ISH_Baixa                          1294 non-null   int64
#  25  ISH_Máxima                         1294 non-null   int64
#  26  ISH_Média                          1294 non-null   int64
#  27  ISH_Mínima                         1294 non-null   int64
#  28  qtd_abertas_Empresario_Individual  1294 non-null   int64
#  29  novos_clusters                     1294 non-null   int64
# dtypes: int64(30)
# memory usage: 313.4 KB

# %%
treino_clus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4276 entries, 290755 to 355030
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   taxa_homicidio                     4276 non-null   int64
#  1   RH_adm_dir                         4276 non-null   int64
#  2   densidade_banda_larga              4276 non-null   int64
#  3   densidade_telefonia_movel          4276 non-null   int64
#  4   qtd_cursos_engenharias             4276 non-null   int64
#  5   media_notas_CN                     4276 non-null   int64
#  6   media_notas_CH                     4276 non-null   int64
#  7   media_NU_NOTA_LC                   4276 non-null   int64
#  8   media_NU_NOTA_MT                   4276 non-null   int64
#  9   media_NU_NOTA_REDACAO              4276 non-null   int64
#  10  valor_medio_recebido_familia       4276 non-null   int64
#  11  pib_per_capita_preco_corrente      4276 non-null   int64
#  12  perc_20_59_anos                    4276 non-null   int64
#  13  pop_total                          4276 non-null   int64
#  14  total_sim_tecnologia               4276 non-null   int64
#  15  Mecanismos_incentivo_Sim           4276 non-null   int64
#  16  Reducao_IPTU_Sim                   4276 non-null   int64
#  17  Isencao_IPTU_Sim                   4276 non-null   int64
#  18  Reducao_ISSQN_Sim                  4276 non-null   int64
#  19  Isencao_ISSQN_Sim                  4276 non-null   int64
#  20  Isencao_Tx_Sim                     4276 non-null   int64
#  21  Cessao_terrenos_Sim                4276 non-null   int64
#  22  Doacao_terrenos_Sim                4276 non-null   int64
#  23  Outros_mecanismos_Sim              4276 non-null   int64
#  24  ISH_Baixa                          4276 non-null   int64
#  25  ISH_Máxima                         4276 non-null   int64
#  26  ISH_Média                          4276 non-null   int64
#  27  ISH_Mínima                         4276 non-null   int64
#  28  qtd_abertas_Empresario_Individual  4276 non-null   int64
#  29  novos_clusters                     4276 non-null   int64
# dtypes: int64(30)
# memory usage: 1.0 MB

# %% [markdown]
# ### Pycaret

# %% [markdown]
# #### RMSE

# %%
regression_setup_rmse = setup(data = treino_clus, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_659d2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_659d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_659d2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_659d2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_659d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_659d2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_659d2_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_659d2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_659d2_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_659d2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_659d2_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_659d2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_659d2_row3_col1" class="data row3 col1" >(4276, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_659d2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_659d2_row4_col1" class="data row4 col1" >(4276, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_659d2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_659d2_row5_col1" class="data row5 col1" >(2993, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_659d2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_659d2_row6_col1" class="data row6 col1" >(1283, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_659d2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_659d2_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_659d2_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_659d2_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_659d2_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_659d2_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_659d2_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_659d2_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_659d2_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_659d2_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_659d2_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_659d2_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_659d2_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_659d2_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_659d2_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_659d2_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_659d2_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_659d2_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_659d2_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_659d2_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_659d2_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_659d2_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_659d2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_659d2_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_659d2_row18_col1" class="data row18 col1" >65a0</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_clus = compare_models(sort = 'RMSE', fold=5)
# Out:
# <style type="text/css">
# #T_9c176 th {
#   text-align: left;
# }
# #T_9c176_row0_col0, #T_9c176_row0_col1, #T_9c176_row0_col2, #T_9c176_row0_col5, #T_9c176_row0_col6, #T_9c176_row1_col0, #T_9c176_row1_col1, #T_9c176_row1_col2, #T_9c176_row1_col3, #T_9c176_row1_col4, #T_9c176_row1_col5, #T_9c176_row1_col6, #T_9c176_row2_col0, #T_9c176_row2_col1, #T_9c176_row2_col2, #T_9c176_row2_col3, #T_9c176_row2_col4, #T_9c176_row2_col5, #T_9c176_row2_col6, #T_9c176_row3_col0, #T_9c176_row3_col1, #T_9c176_row3_col2, #T_9c176_row3_col3, #T_9c176_row3_col4, #T_9c176_row3_col5, #T_9c176_row3_col6, #T_9c176_row4_col0, #T_9c176_row4_col1, #T_9c176_row4_col2, #T_9c176_row4_col3, #T_9c176_row4_col4, #T_9c176_row4_col5, #T_9c176_row4_col6, #T_9c176_row5_col0, #T_9c176_row5_col1, #T_9c176_row5_col2, #T_9c176_row5_col3, #T_9c176_row5_col4, #T_9c176_row5_col5, #T_9c176_row5_col6, #T_9c176_row6_col0, #T_9c176_row6_col1, #T_9c176_row6_col2, #T_9c176_row6_col3, #T_9c176_row6_col4, #T_9c176_row6_col5, #T_9c176_row6_col6, #T_9c176_row7_col0, #T_9c176_row7_col1, #T_9c176_row7_col3, #T_9c176_row7_col4, #T_9c176_row7_col5, #T_9c176_row7_col6, #T_9c176_row8_col0, #T_9c176_row8_col1, #T_9c176_row8_
row0_col4" class="data row0 col4" >0.7033</td>
#       <td id="T_50842_row0_col5" class="data row0 col5" >0.8955</td>
#     </tr>
#     <tr>
#       <th id="T_50842_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50842_row1_col0" class="data row1 col0" >160.8343</td>
#       <td id="T_50842_row1_col1" class="data row1 col1" >269436.6142</td>
#       <td id="T_50842_row1_col2" class="data row1 col2" >519.0728</td>
#       <td id="T_50842_row1_col3" class="data row1 col3" >0.9550</td>
#       <td id="T_50842_row1_col4" class="data row1 col4" >0.7507</td>
#       <td id="T_50842_row1_col5" class="data row1 col5" >1.0109</td>
#     </tr>
#     <tr>
#       <th id="T_50842_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50842_row2_col0" class="data row2 col0" >133.2942</td>
#       <td id="T_50842_row2_col1" class="data row2 col1" >147907.4012</td>
#       <td id="T_50842_row2_col2" class="data row2 col2" >384.5873</td>
#       <td id="T_50842_row2_col3" class="data row2 col3" >0.9590</td>
#       <td id="T_50842_row2_col4" class="data row2 col4" >0.7476</td>
#       <td id="T_50842_row2_col5" class="data row2 col5" >1.0560</td>
#     </tr>
#     <tr>
#       <th id="T_50842_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50842_row3_col0" class="data row3 col0" >94.6137</td>
#       <td id="T_50842_row3_col1" class="data row3 col1" >39445.9339</td>
#       <td id="T_50842_row3_col2" class="data row3 col2" >198.6100</td>
#       <td id="T_50842_row3_col3" class="data row3 col3" >0.9676</td>
#       <td id="T_50842_row3_col4" class="data row3 col4" >0.7437</td>
#       <td id="T_50842_row3_col5" class="data row3 col5" >0.9838</td>
#     </tr>
#     <tr>
#       <th id="T_50842_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50842_row4_col0" class="data row4 col0" >190.3882</td>
#       <td id="T_50842_row4_col1" class="data row4 col1" >1080453.6837</td>
#       <td id="T_50842_row4_col2" class="data row4 col2" >1039.4487</td>
#       <td id="T_50842_row4_col3" class="data row4 col3" >0.8915</td>
#       <td id="T_50842_row4_col4" class="data row4 col4" >0.7461</td>
#       <td id="T_50842_row4_col5" class="data row4 col5" >0.9800</td>
#     </tr>
#     <tr>
#       <th id="T_50842_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_50842_row5_col0" class="data row5 col0" >156.3024</td>
#       <td id="T_50842_row5_col1" class="data row5 col1" >683607.0619</td>
#       <td id="T_50842_row5_col2" class="data row5 col2" >702.6277</td>
#       <td id="T_50842_row5_col3" class="data row5 col3" >0.9286</td>
#       <td id="T_50842_row5_col4" class="data row5 col4" >0.7383</td>
#       <td id="T_50842_row5_col5" class="data row5 col5" >0.9852</td>
#     </tr>
#     <tr>
#       <th id="T_50842_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_50842_row6_col0" class="data row6 col0" >39.0911</td>
#       <td id="T_50842_row6_col1" class="data row6 col1" >702024.6559</td>
#       <td id="T_50842_row6_col2" class="data row6 col2" >435.7997</td>
#       <td id="T_50842_row6_col3" class="data row6 col3" >0.0399</td>
#       <td id="T_50842_row6_col4" class="data row6 col4" >0.0176</td>
#       <td id="T_50842_row6_col5" class="data row6 col5" >0.0524</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(tuned_clus)
# Out:
# OrthogonalMatchingPursuit()

# %%
#plot_model(tuned_clus, plot='feature')

# %%
final_model_baseline_rmse_clus = finalize_model(best_model_clus)

# %% [markdown]
# ### Previsão - RMSE 2022

# %%
pred_teste_clus = predict_model(final_model_baseline_rmse_clus, data = teste_clus)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0ab15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ab15_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0ab15_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0ab15_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0ab15_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0ab15_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0ab15_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0ab15_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ab15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ab15_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_0ab15_row0_col1" class="data row0 col1" >42.3680</td>
#       <td id="T_0ab15_row0_col2" class="data row0 col2" >9534.9134</td>
#       <td id="T_0ab15_row0_col3" class="data row0 col3" >97.6469</td>
#       <td id="T_0ab15_row0_col4" class="data row0 col4" >0.9041</td>
#       <td id="T_0ab15_row0_col5" class="data row0 col5" >0.4140</td>
#       <td id="T_0ab15_row0_col6" class="data row0 col6" >0.3884</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_teste_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110007                           1         382                      3
# 110008                           3         573                      4
# 110029                           2         411                      4
# 110070                           3         580                     12
# 110092                           2         596                      1
# ...                            ...         ...                    ...
# 522108                           0         267                      5
# 522140                          57        2888                      5
# 522157                           0         209                      3
# 522160                          15        1180                     12
# 522205                           0         394                      8
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110007                                     51                       0
# 110008                                     35                       5
# 110029                                     88                       0
# 110070                                     29                       0
# 110092                                     61                       0
# ...                                       ...                     ...
# 522108                                     47                       0
# 522140                                    101                       2
# 522157                                     81                       0
# 522160                                    112                      50
# 522205                                    104                       0
#
#                     media_notas_CN  media_notas_CH  media_NU_NOTA_LC  \
# cod_municipio_ibge
# 110007                         439             466               432
# 110008                         438             465               451
# 110029                         478             509               475
# 110070                         409             423               418
# 110092                         449             423               414
# ...                            ...             ...               ...
# 522108                         409             428               420
# 522140                         473             494               479
# 522157                         430             435               486
# 522160                         477             502               493
# 522205                         450             464               457
#
#                     media_NU_NOTA_MT  media_NU_NOTA_REDACAO  ...  \
# cod_municipio_ibge                                           ...
# 110007                           445                    577  ...
# 110008                           478                    492  ...
# 110029                           487                    597  ...
# 110070                           462                    548  ...
# 110092                           434                    517  ...
# ...                              ...                    ...  ...
# 522108                           446                    333  ...
# 522140                           514                    568  ...
# 522157                           514                    446  ...
# 522160                           523                    589  ...
# 522205                           504                    552  ...
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110007                                1                    0
# 110008                                1                    0
# 110029                                1                    1
# 110070                                1                    1
# 110092                                0                    0
# ...                                 ...                  ...
# 522108                                0                    0
# 522140                                1                    1
# 522157                                1                    0
# 522160                                0                    0
# 522205                                0                    1
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110007                                  1          0           0          0
# 110008                                  0          1           0          0
# 110029                                  0          0           0          0
# 110070                                  1          0           0          1
# 110092                                  0          0           0          1
# ...                                   ...        ...         ...        ...
# 522108                                  0          1           0          0
# 522140                                  0          0           0          1
# 522157                                  0          0           0          1
# 522160                                  0          0           0          0
# 522205                                  0          0           0          1
#
#                     ISH_Mínima  novos_clusters  \
# cod_municipio_ibge
# 110007                       0               0
# 110008                       0               0
# 110029                       0               0
# 110070                       0               0
# 110092                       0               0
# ...                        ...             ...
# 522108                       0               0
# 522140                       0               0
# 522157                       0               0
# 522160                       0               0
# 522205                       0               0
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110007                                             86             42.13
# 110008                                            106            139.03
# 110029                                             33             77.30
# 110070                                             38            115.29
# 110092                                            104            112.59
# ...                                               ...               ...
# 522108                                             34             19.50
# 522140                                           2842           1309.17
# 522157                                             14             30.02
# 522160                                            587            612.08
# 522205                                             66            123.26
#
# [1294 rows x 31 columns]

# %%
plt.scatter(pred_teste_clus['qtd_abertas_Empresario_Individual'],pred_teste_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ### Previsão - RMSE 2019

# %%
df_c_19 = pd.get_dummies(df_c_19, columns = ['cluster'], drop_first=True)

# %%
pred_2018_2019_clus = predict_model(final_model_baseline_rmse_clus, data = df_c_19)
# Out:
# <style type="text/css">
# </style>
# <table id="T_47565">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47565_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_47565_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_47565_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_47565_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_47565_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_47565_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_47565_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47565_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47565_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_47565_row0_col1" class="data row0 col1" >118.6216</td>
#       <td id="T_47565_row0_col2" class="data row0 col2" >871795.3168</td>
#       <td id="T_47565_row0_col3" class="data row0 col3" >933.6998</td>
#       <td id="T_47565_row0_col4" class="data row0 col4" >0.9477</td>
#       <td id="T_47565_row0_col5" class="data row0 col5" >0.4637</td>
#       <td id="T_47565_row0_col6" class="data row0 col6" >0.4822</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_2018_2019_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                         7.0       926.0               5.391153
# 110002                        41.0      2563.0              11.445074
# 110003                         0.0       344.0               3.990964
# 110004                        17.0      1971.0              12.382995
# 110005                         2.0       591.0               7.847822
# ...                            ...         ...                    ...
# 522200                         2.0       528.0               7.191805
# 522205                         4.0       394.0               8.601167
# 522220                         3.0       403.0               5.055907
# 522230                         2.0       344.0               2.817385
# 530010                       530.0    122197.0              23.930012
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                              34.342995                     6.0
# 110002                              86.588539                    42.0
# 110003                              79.838104                     0.0
# 110004                              89.462151                   202.0
# 110005                              89.952827                     0.0
# ...                                       ...                     ...
# 522200                              33.744499                     0.0
# 522205                              78.874527                     0.0
# 522220                               5.833738                     0.0
# 522230                              26.473114                     0.0
# 530010                             117.493172                  3082.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                     23.0      480.664276
# 110002                                    299.0      481.314240
# 110003                                      0.0      442.604156
# 110004                                    469.0      484.990723
# 110005                                     38.0      466.433807
# ...                                         ...             ...
# 522200                                      0.0      474.571777
# 522205                                      0.0      439.651611
# 522220                                      0.0      440.164276
# 522230                                      0.0      451.296661
# 530010                                  15811.0      510.176941
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                  543.020264        495.929718        502.991425  ...
# 110002                  549.247253        513.304749        512.975891  ...
# 110003                  506.685181        466.007416        484.924988  ...
# 110004                  549.739380        513.924805        524.946716  ...
# 110005                  551.494751        498.394745        493.949310  ...
# ...                            ...               ...               ...  ...
# 522200                  522.414612        493.386505        503.091766  ...
# 522205                  498.125641        463.625641        479.803223  ...
# 522220                  513.099976        450.394440        504.899994  ...
# 522230                  498.101593        463.396820        471.051666  ...
# 530010                  580.567993        546.609680        552.578613  ...
#
#                     Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110001                                0                    0
# 110002                                0                    1
# 110003                                0                    0
# 110004                                1                    1
# 110005                                0                    0
# ...                                 ...                  ...
# 522200                                0                    0
# 522205                                0                    1
# 522220                                1                    1
# 522230                                1                    0
# 530010                                1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110001                                  0          0           0          0
# 110002                                  1          0           0          1
# 110003                                  1          0           0          0
# 110004                                  0          0           0          0
# 110005                                  0          1           0          0
# ...                                   ...        ...         ...        ...
# 522200                                  0          0           1          0
# 522205                                  0          0           0          1
# 522220                                  0          0           0          0
# 522230                                  0          0           0          0
# 530010                                  1          0           0          0
#
#                     ISH_Mínima  novos_clusters  \
# cod_municipio_ibge
# 110001                       0               0
# 110002                       0               0
# 110003                       0               0
# 110004                       0               0
# 110005                       0               0
# ...                        ...             ...
# 522200                       0               0
# 522205                       0               0
# 522220                       0               0
# 522230                       0               0
# 530010                       0               1
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110001                                            167            239.66
# 110002                                           1058           1462.69
# 110003                                             50             49.08
# 110004                                            987           1287.47
# 110005                                            181            226.02
# ...                                               ...               ...
# 522200                                            150            102.78
# 522205                                             47             83.57
# 522220                                             22             45.98
# 522230                                             25             45.06
# 530010                                          47504          68863.08
#
# [5570 rows x 33 columns]

# %%
plt.scatter(pred_2018_2019_clus['qtd_abertas_Empresario_Individual'],pred_2018_2019_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %%
pred_2018_2019_clus.to_excel('teste_cluster_2019.xlsx')

# %% [markdown]
# ### MAPE

# %%
regression_setup = setup(data = treino_clus, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_fa203_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fa203">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa203_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fa203_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa203_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fa203_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fa203_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fa203_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fa203_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fa203_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fa203_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fa203_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fa203_row3_col1" class="data row3 col1" >(4178, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fa203_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fa203_row4_col1" class="data row4 col1" >(4178, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fa203_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fa203_row5_col1" class="data row5 col1" >(2924, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fa203_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fa203_row6_col1" class="data row6 col1" >(1254, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fa203_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fa203_row7_col1" class="data row7 col1" >31</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fa203_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_fa203_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fa203_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_fa203_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fa203_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_fa203_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fa203_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_fa203_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fa203_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_fa203_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fa203_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_fa203_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fa203_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_fa203_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fa203_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_fa203_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fa203_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_fa203_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fa203_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_fa203_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fa203_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fa203_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_fa203_row18_col1" class="data row18 col1" >3c31</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model_clus = compare_models(sort = 'MAPE', fold=5)
# Out:
# <style type="text/css">
# #T_1dea8 th {
#   text-align: left;
# }
# #T_1dea8_row0_col0, #T_1dea8_row0_col1, #T_1dea8_row0_col2, #T_1dea8_row0_col3, #T_1dea8_row0_col4, #T_1dea8_row1_col0, #T_1dea8_row1_col1, #T_1dea8_row1_col2, #T_1dea8_row1_col3, #T_1dea8_row1_col4, #T_1dea8_row1_col5, #T_1dea8_row1_col6, #T_1dea8_row2_col0, #T_1dea8_row2_col1, #T_1dea8_row2_col2, #T_1dea8_row2_col3, #T_1dea8_row2_col4, #T_1dea8_row2_col5, #T_1dea8_row2_col6, #T_1dea8_row3_col0, #T_1dea8_row3_col1, #T_1dea8_row3_col2, #T_1dea8_row3_col3, #T_1dea8_row3_col4, #T_1dea8_row3_col5, #T_1dea8_row3_col6, #T_1dea8_row4_col0, #T_1dea8_row4_col1, #T_1dea8_row4_col2, #T_1dea8_row4_col3, #T_1dea8_row4_col4, #T_1dea8_row4_col5, #T_1dea8_row4_col6, #T_1dea8_row5_col0, #T_1dea8_row5_col1, #T_1dea8_row5_col2, #T_1dea8_row5_col3, #T_1dea8_row5_col4, #T_1dea8_row5_col5, #T_1dea8_row5_col6, #T_1dea8_row6_col0, #T_1dea8_row6_col4, #T_1dea8_row6_col5, #T_1dea8_row6_col6, #T_1dea8_row7_col0, #T_1dea8_row7_col1, #T_1dea8_row7_col2, #T_1dea8_row7_col3, #T_1dea8_row7_col4, #T_1dea8_row7_col5, #T_1dea8_row7_col6, #T_1dea8_row8_col0, #T_1dea8_row8_col1, #T_1dea8_row8_col2, #T_1dea8_row8_col3, #T_1dea8_row8_col4, #T_1dea8_row8_col5, #T_1dea8_row8_col6, #T_1dea8_row9_col0, #T_1dea8_row9_col1, #T_1dea8_row9_col2, #T_1dea8_row9_col3, #T_1dea8_row9_col4, #T_1dea8_row9_col5, #T_1dea8_row9_col6, #T_1dea8_row10_col0, #T_1dea8_row10_col1, #T_1dea8_row10_col2, #T_1dea8_row10_col3, #T_1dea8_row10_col4, #T_1dea8_row10_col5, #T_1dea8_row10_col6, #T_1dea8_row11_col0, #T_1dea8_row11_col1, #T_1dea8_row11_col2, #T_1dea8_row11_col3, #T_1dea8_row11_col4, #T_1dea8_row11_col5, #T_1dea8_row11_col6, #T_1dea8_row12_col0, #T_1dea8_row12_col1, #T_1dea8_row12_col2, #T_1dea8_row12_col3, #T_1dea8_row12_col5, #T_1dea8_row12_col6, #T_1dea8_row13_col0, #T_1dea8_row13_col1, #T_1dea8_row13_col2, #T_1dea8_row13_col3, #T_1dea8_row13_col4, #T_1dea8_row13_col5, #T_1dea8_row13_col6, #T_1dea8_row14_col0, #T_1dea8_row14_col1, #T_1dea8_row14_col2, #T_1dea8_row14_col3, #T_1dea8_row14_col4, #T_1dea8_row14_col5, #T_1dea8_row14_col6, #T_1dea8_row15_col0, #T_1dea8_row15_col1, #T_1dea8_row15_col2, #T_1dea8_row15_col3, #T_1dea8_row15_col4, #T_1dea8_row15_col5, #T_1dea8_row15_col6, #T_1dea8_row16_col0, #T_1dea8_row16_col1, #T_1dea8_row16_col2, #T_1dea8_row16_col3, #T_1dea8_row16_col4, #T_1dea8_row16_col5, #T_1dea8_row16_col6, #T_1dea8_row17_col0, #T_1dea8_row17_col1, #T_1dea8_row17_col2, #T_1dea8_row17_col3, #T_1dea8_row17_col4, #T_1dea8_row17_col5, #T_1dea8_row17_col6, #T_1dea8_row18_col0, #T_1dea8_row18_col1, #T_1dea8_row18_col2, #T_1dea8_row18_col3, #T_1dea8_row18_col4, #T_1dea8_row18_col5, #T_1dea8_row18_col6 {
#   text-align: left;
# }
# #T_1dea8_row0_col5, #T_1dea8_row0_col6, #T_1dea8_row6_col1, #T_1dea8_row6_col2, #T_1dea8_row6_col3, #T_1dea8_row12_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1dea8_row0_col7, #T_1dea8_row1_col7, #T_1dea8_row3_col7, #T_1dea8_row4_col7, #T_1dea8_row5_col7, #T_1dea8_row6_col7, #T_1dea8_row7_col7, #T_1dea8_row8_col7, #T_1dea8_row9_col7, #T_1dea8_row10_col7, #T_1dea8_row11_col7, #T_1dea8_row12_col7, #T_1dea8_row13_col7, #T_1dea8_row14_col7, #T_1dea8_row15_col7, #T_1dea8_row16_col7, #T_1dea8_row17_col7, #T_1dea8_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1dea8_row2_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1dea8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dea8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1dea8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1dea8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1dea8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1dea8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1dea8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1dea8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1dea8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dea8_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_1dea8_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_1dea8_row0_col1" class="data row0 col1" >179.0280</td>
#       <td id="T_1dea8_row0_col2" class="data row0 col2" >16004772.6030</td>
#       <td id="T_1dea8_row0_col3" class="data row0 col3" >2322.2651</td>
#       <td id="T_1dea8_row0_col4" class="data row0 col4" >0.7731</td>
#       <td id="T_1dea8_row0_col5" class="data row0 col5" >0.4216</td>
#       <td id="T_1dea8_row0_col6" class="data row0 col6" >0.4050</td>
#       <td id="T_1dea8_row0_col7" class="data row0 col7" >0.3900</td>
#     </tr>
#     <tr>
#       <th id="T_1dea8_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_1dea8_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_1dea8_row1_col1" class="data row1 col1" >179.5765</td>
#       <td id="T_1dea8_row1_col2" class="data row1 col2" >20276159.1733</td>
#       <td id="T_1dea8_row1_col3" class="data row1 col3" >2419.4517</td>
#       <td id="T_1dea8_row1_col4" class="data row1 col4" >0.7753</td>
#       <td id="T_1dea8_row1_col5" class="data row1 col5" >0.4379</td>
#       <td id="T_1dea8_row1_col6" class="data row1 col6" >0.4319</td>
#       <td id="T_1dea8_row1_col7" class="data row1 col7" >0.4000</td>
#     </tr>
#     <tr>
#       <th id="T_1dea8_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_1dea8_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_1dea8_row2_col1" class="data row2 col1" >249.5722</td>
#       <td id="T_1dea8_row2_col2" class="data row2 col2" >31089943.0552</td>
#       <td id="T_1dea8_row2_col3" class="data row2 col3" >3928.3623</td>
#       <td id="T_1dea8_row2_col4" class="data row2 col4" >-3.2682</td>
#       <td id="T_1dea8_row2_col5" class="data row2 col5" >0.4969</td>
#       <td id="T_1dea8_row2_col6" class="data row2 col6" >0.4421</td>
#       <td id="T_1dea8_row2_col7" class="data row2 col7" >0.3480</td>
#     </tr>
#     <tr>
#       <th id="T
td>
#     </tr>
#     <tr>
#       <th id="T_89877_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89877_row3_col0" class="data row3 col0" >130.3227</td>
#       <td id="T_89877_row3_col1" class="data row3 col1" >385638.3118</td>
#       <td id="T_89877_row3_col2" class="data row3 col2" >620.9978</td>
#       <td id="T_89877_row3_col3" class="data row3 col3" >0.9208</td>
#       <td id="T_89877_row3_col4" class="data row3 col4" >0.7895</td>
#       <td id="T_89877_row3_col5" class="data row3 col5" >1.1914</td>
#     </tr>
#     <tr>
#       <th id="T_89877_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_89877_row4_col0" class="data row4 col0" >195.8724</td>
#       <td id="T_89877_row4_col1" class="data row4 col1" >720789.1372</td>
#       <td id="T_89877_row4_col2" class="data row4 col2" >848.9930</td>
#       <td id="T_89877_row4_col3" class="data row4 col3" >0.9087</td>
#       <td id="T_89877_row4_col4" class="data row4 col4" >0.7257</td>
#       <td id="T_89877_row4_col5" class="data row4 col5" >0.9969</td>
#     </tr>
#     <tr>
#       <th id="T_89877_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_89877_row5_col0" class="data row5 col0" >240.3993</td>
#       <td id="T_89877_row5_col1" class="data row5 col1" >18379706.3014</td>
#       <td id="T_89877_row5_col2" class="data row5 col2" >2451.3914</td>
#       <td id="T_89877_row5_col3" class="data row5 col3" >0.7536</td>
#       <td id="T_89877_row5_col4" class="data row5 col4" >0.7963</td>
#       <td id="T_89877_row5_col5" class="data row5 col5" >1.2401</td>
#     </tr>
#     <tr>
#       <th id="T_89877_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_89877_row6_col0" class="data row6 col0" >151.0337</td>
#       <td id="T_89877_row6_col1" class="data row6 col1" >35697742.1904</td>
#       <td id="T_89877_row6_col2" class="data row6 col2" >3517.1560</td>
#       <td id="T_89877_row6_col3" class="data row6 col3" >0.2857</td>
#       <td id="T_89877_row6_col4" class="data row6 col4" >0.0501</td>
#       <td id="T_89877_row6_col5" class="data row6 col5" >0.2017</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
print(tuned_clus)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
plot_model(best_model_clus, plot='feature')

# %%
final_model_baseline_mape_clus = finalize_model(best_model_clus)

# %% [markdown]
# ### Previsão - Mape 2022

# %%
pred_teste_clus = predict_model(final_model_baseline_mape_clus, data = teste_clus)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5fe0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5fe0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e5fe0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e5fe0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e5fe0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e5fe0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e5fe0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e5fe0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5fe0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5fe0_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_e5fe0_row0_col1" class="data row0 col1" >93.8469</td>
#       <td id="T_e5fe0_row0_col2" class="data row0 col2" >119848.8287</td>
#       <td id="T_e5fe0_row0_col3" class="data row0 col3" >346.1919</td>
#       <td id="T_e5fe0_row0_col4" class="data row0 col4" >0.9615</td>
#       <td id="T_e5fe0_row0_col5" class="data row0 col5" >0.4130</td>
#       <td id="T_e5fe0_row0_col6" class="data row0 col6" >0.3824</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_teste_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110003                           0         344                      5
# 110004                          21        1971                     19
# 110009                           7         893                     10
# 110015                           6        1425                     12
# 110020                         145       12963                     23
# ...                            ...         ...                    ...
# 522040                           3        1064                     17
# 522150                           3         296                      1
# 522157                           0         209                      3
# 522160                          15        1180                     12
# 522220                           0         403                      1
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110003                                     78                       0
# 110004                                    105                     184
# 110009                                     60                       0
# 110015                                    111                      18
# 110020                                    106                     424
# ...                                       ...                     ...
# 522040                                     84                       0
# 522150                                     87                       0
# 522157                                     81                       0
# 522160                                    112                      50
# 522220                                     66                       0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110003                                        0             477
# 110004                                      422             489
# 110009                                       22             461
# 110015                                       60             458
# 110020                                     1595             473
# ...                                         ...             ...
# 522040                                       13             454
# 522150                                        0             418
# 522157                                        0             430
# 522160                                      146             477
# 522220                                        0             431
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110003                         486               447               522  ...
# 110004                         505               490               533  ...
# 110009                         469               466               502  ...
# 110015                         476               470               507  ...
# 110020                         496               482               511  ...
# ...                            ...               ...               ...  ...
# 522040                         472               466               498  ...
# 522150                         419               414               436  ...
# 522157                         435               486               514  ...
# 522160                         502               493               523  ...
# 522220                         443               426               445  ...
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110009                                0                      0          0
# 110015                                0                      0          0
# 110020                                0                      0          1
# ...                                 ...                    ...        ...
# 522040                                1                      0          0
# 522150                                1                      0          0
# 522157                                0                      0          0
# 522160                                0                      0          0
# 522220                                1                      0          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster_1  cluster_2  \
# cod_municipio_ibge
# 110003                       0          0           0          0          0
# 110004                       0          0           0          0          0
# 110009                       0          1           0          0          0
# 110015                       0          0           0          0          0
# 110020                       0          0           0          0          0
# ...                        ...        ...         ...        ...        ...
# 522040                       0          0           0          0          0
# 522150                       0          0           0          0          0
# 522157                       0          1           0          0          0
# 522160                       0          0           0          0          0
# 522220                       0          0           0          0          0
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110003                                             49             52.54
# 110004                                           1258           1375.89
# 110009                                            319            233.55
# 110015                                            461            578.26
# 110020                                           7893           9242.11
# ...                                               ...               ...
# 522040                                            231            248.67
# 522150                                             25             46.96
# 522157                                             14             23.10
# 522160                                            587            787.79
# 522220                                             23             44.72
#
# [1392 rows x 33 columns]

# %%
plt.scatter(pred_teste_clus['qtd_abertas_Empresario_Individual'],pred_teste_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2022.png')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# ### Previsão - Mape 2019

# %%
pred_2018_2019_clus = predict_model(final_model_baseline_mape_clus, data = df_c_19)
# Out:
# <style type="text/css">
# </style>
# <table id="T_17622">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17622_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17622_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_17622_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_17622_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_17622_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_17622_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_17622_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17622_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17622_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_17622_row0_col1" class="data row0 col1" >116.1945</td>
#       <td id="T_17622_row0_col2" class="data row0 col2" >786575.1478</td>
#       <td id="T_17622_row0_col3" class="data row0 col3" >886.8907</td>
#       <td id="T_17622_row0_col4" class="data row0 col4" >0.9529</td>
#       <td id="T_17622_row0_col5" class="data row0 col5" >0.4530</td>
#       <td id="T_17622_row0_col6" class="data row0 col6" >0.4667</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_2018_2019_clus
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110001                           7         926                      5
# 110002                          41        2563                     11
# 110003                           0         344                      3
# 110004                          17        1971                     12
# 110005                           2         591                      7
# ...                            ...         ...                    ...
# 522200                           2         528                      7
# 522205                           4         394                      8
# 522220                           3         403                      5
# 522230                           2         344                      2
# 530010                         530      122197                     23
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110001                                     34                       6
# 110002                                     86                      42
# 110003                                     79                       0
# 110004                                     89                     202
# 110005                                     89                       0
# ...                                       ...                     ...
# 522200                                     33                       0
# 522205                                     78                       0
# 522220                                      5                       0
# 522230                                     26                       0
# 530010                                    117                    3082
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110001                                       23             480
# 110002                                      299             481
# 110003                                        0             442
# 110004                                      469             484
# 110005                                       38             466
# ...                                         ...             ...
# 522200                                        0             474
# 522205                                        0             439
# 522220                                        0             440
# 522230                                        0             451
# 530010                                    15811             510
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110001                         543               495               502  ...
# 110002                         549               513               512  ...
# 110003                         506               466               484  ...
# 110004                         549               513               524  ...
# 110005                         551               498               493  ...
# ...                            ...               ...               ...  ...
# 522200                         522               493               503  ...
# 522205                         498               463               479  ...
# 522220                         513               450               504  ...
# 522230                         498               463               471  ...
# 530010                         580               546               552  ...
#
#                     Doacao_terrenos_Sim  Outros_mecanismos_Sim  ISH_Baixa  \
# cod_municipio_ibge
# 110001                                0                      0          0
# 110002                                1                      1          0
# 110003                                0                      1          0
# 110004                                1                      0          0
# 110005                                0                      0          1
# ...                                 ...                    ...        ...
# 522200                                0                      0          0
# 522205                                1                      0          0
# 522220                                1                      0          0
# 522230                                0                      0          0
# 530010                                0                      1          0
#
#                     ISH_Máxima  ISH_Média  ISH_Mínima  cluster_1  cluster_2  \
# cod_municipio_ibge
# 110001                       0          0           0          0          0
# 110002                       0          1           0          0          0
# 110003                       0          0           0          0          0
# 110004                       0          0           0          0          0
# 110005                       0          0           0          0          0
# ...                        ...        ...         ...        ...        ...
# 522200                       1          0           0          0          0
# 522205                       0          1           0          0          0
# 522220                       0          0           0          0          0
# 522230                       0          0           0          0          0
# 530010                       0          0           0          0          1
#
#                     qtd_abertas_Empresario_Individual  prediction_label
# cod_municipio_ibge
# 110001                                            167            205.29
# 110002                                           1058           1264.52
# 110003                                             50             50.18
# 110004                                            987           1240.49
# 110005                                            181            215.65
# ...                                               ...               ...
# 522200                                            150            105.64
# 522205                                             47             88.38
# 522220                                             22             45.58
# 522230                                             25             44.75
# 530010                                          47504          61857.92
#
# [5570 rows x 33 columns]

# %%
plt.scatter(pred_2018_2019_clus['qtd_abertas_Empresario_Individual'],pred_2018_2019_clus['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
#plt.savefig('previsao_2019.png')
# Out:
# Text(0, 0.5, 'Valores preditos')
