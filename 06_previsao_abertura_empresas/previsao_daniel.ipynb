# %% [markdown]
# # Instalando o Pycaret

# %%
#!pip install pycaret

# %%
#!pip install scipy

# %%
# Importando bibliotecas necessárias
import pandas as pd
import sweetviz as sv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import shap
from pycaret.regression import *
from scipy.stats import randint as sp_randint
from scipy.stats import uniform as sp_uniform

# %% [markdown]
# # Tratando a base

# %%
df= pd.read_excel("Base_novo_teste.xlsx")

# %%
df = df[['cod_municipio_ibge','qtd_abertas_Empresario_Individual','Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','taxa_homicidio','RH_adm_dir','ISH','densidade_banda_larga','densidade_telefonia_movel','qtd_cursos_engenharias',
    'qtd_cursos_negocios_direito','media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO','valor_medio_recebido_familia','pib_per_capita_preco_corrente','perc_20_59_anos','pop_total','total_sim_tecnologia','porte_municipio']]

# %%
df.head()
# Out:
#    cod_municipio_ibge  qtd_abertas_Empresario_Individual Mecanismos_incentivo  \
# 0              110001                                194                  Não
# 1              110002                               1275                  Sim
# 2              110003                                 49                  Sim
# 3              110004                               1258                  Sim
# 4              110005                                257                  Sim
#
#   Reducao_IPTU Isencao_IPTU Reducao_ISSQN Isencao_ISSQN Isencao_Tx  \
# 0          NaN          NaN           NaN           NaN        NaN
# 1          Sim          Sim           Não           Não        Sim
# 2          Não          Não           Não           Sim        Não
# 3          Não          Sim           Sim           Não        Sim
# 4          Não          Sim           Não           Não        Não
#
#   Cessao_terrenos Doacao_terrenos  ... media_notas_CH  media_NU_NOTA_LC  \
# 0             NaN             NaN  ...     504.034091        491.079545
# 1             Não             Sim  ...     495.727950        484.710248
# 2             Não             Não  ...     486.071429        447.628571
# 3             Sim             Sim  ...     505.006061        490.991919
# 4             Não             Não  ...     477.045714        454.722857
#
#    media_NU_NOTA_MT media_NU_NOTA_REDACAO  valor_medio_recebido_familia  \
# 0        543.558537            621.363636                         18495
# 1        518.811149            584.534161                         17615
# 2        522.883333            471.428571                         18956
# 3        533.458933            611.717172                         19376
# 4        480.696875            576.571429                         17752
#
#    pib_per_capita_preco_corrente  perc_20_59_anos  pop_total  \
# 0                       25091.18         0.587227      22516
# 1                       25730.20         0.591797     111148
# 2                       32226.25         0.584567       5067
# 3                       29331.29         0.595584      86416
# 4                       37069.25         0.598272      16088
#
#    total_sim_tecnologia  porte_municipio
# 0                  18.0                2
# 1                  12.0                4
# 2                   8.0                1
# 3                  17.0                3
# 4                   8.0                2
#
# [5 rows x 29 columns]

# %%
df['qtd_cursos_engenharias'] = df['qtd_cursos_engenharias'].fillna(0)

df['qtd_cursos_negocios_direito'] = df['qtd_cursos_negocios_direito'].fillna(0)

df['total_sim_tecnologia'] = df['total_sim_tecnologia'].fillna(0)

df['taxa_homicidio'] = df['taxa_homicidio'].fillna(0)

df['RH_adm_dir'] = df['RH_adm_dir'].fillna(0)

# %%
df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']] = df[['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos']].fillna('Não')

# %%
df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']] = df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].fillna(df[['media_notas_CN','media_notas_CH','media_NU_NOTA_LC','media_NU_NOTA_MT',
    'media_NU_NOTA_REDACAO']].median())

# %%
df = pd.get_dummies(df, columns = ['Mecanismos_incentivo','Reducao_IPTU', 'Isencao_IPTU', 'Reducao_ISSQN','Isencao_ISSQN','Isencao_Tx','Cessao_terrenos',
    'Doacao_terrenos','Outros_mecanismos','ISH'], drop_first=True)

# %%
df = df[np.isfinite(df).all(1)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 0 to 5569
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   cod_municipio_ibge                 5570 non-null   int64
#  1   qtd_abertas_Empresario_Individual  5570 non-null   int64
#  2   taxa_homicidio                     5570 non-null   float64
#  3   RH_adm_dir                         5570 non-null   float64
#  4   densidade_banda_larga              5570 non-null   float64
#  5   densidade_telefonia_movel          5570 non-null   float64
#  6   qtd_cursos_engenharias             5570 non-null   float64
#  7   qtd_cursos_negocios_direito        5570 non-null   float64
#  8   media_notas_CN                     5570 non-null   float64
#  9   media_notas_CH                     5570 non-null   float64
#  10  media_NU_NOTA_LC                   5570 non-null   float64
#  11  media_NU_NOTA_MT                   5570 non-null   float64
#  12  media_NU_NOTA_REDACAO              5570 non-null   float64
#  13  valor_medio_recebido_familia       5570 non-null   int64
#  14  pib_per_capita_preco_corrente      5570 non-null   float64
#  15  perc_20_59_anos                    5570 non-null   float64
#  16  pop_total                          5570 non-null   int64
#  17  total_sim_tecnologia               5570 non-null   float64
#  18  porte_municipio                    5570 non-null   int64
#  19  Mecanismos_incentivo_Sim           5570 non-null   uint8
#  20  Reducao_IPTU_Sim                   5570 non-null   uint8
#  21  Isencao_IPTU_Sim                   5570 non-null   uint8
#  22  Reducao_ISSQN_Sim                  5570 non-null   uint8
#  23  Isencao_ISSQN_Sim                  5570 non-null   uint8
#  24  Isencao_Tx_Sim                     5570 non-null   uint8
#  25  Cessao_terrenos_Sim                5570 non-null   uint8
#  26  Doacao_terrenos_Sim                5570 non-null   uint8
#  27  Outros_mecanismos_Sim              5570 non-null   uint8
#  28  ISH_Baixa                          5570 non-null   uint8
#  29  ISH_Máxima                         5570 non-null   uint8
#  30  ISH_Média                          5570 non-null   uint8
#  31  ISH_Mínima                         5570 non-null   uint8
# dtypes: float64(14), int64(5), uint8(13)
# memory usage: 941.0 KB

# %%
df = df.set_index('cod_municipio_ibge')

# %% [markdown]
# # Dividindo em treino e test

# %% [markdown]
# Adaleny, fiz a divisão de treino e teste baseado na estratificação

# %%
treino = df.groupby('porte_municipio', group_keys=False).apply(lambda x: x.sample(frac=0.75, random_state = 123))

teste = df.drop(treino.index)

print(treino.shape, teste.shape)
# Out:
# (4178, 31) (1392, 31)

# %%
# vamos separar duas bases, uma para treino e outra para teste
#treino = df.sample(frac=.8, random_state=123)
#treino.reset_index(inplace=True, drop=True)


#teste = df.drop(treino.index)
#teste.reset_index(inplace=True, drop=True)

#print(treino.shape, teste.shape)

#peguei esse do colab que compartilhou comigo, depois queria entender a formatação dele
# Out:
# (4456, 31) (1114, 31)

# %%
treino = treino.drop('porte_municipio', axis = 1)
teste= teste.drop('porte_municipio', axis = 1)

# %%
#teste= teste.drop('qtd_abertas_Empresario_Individual', axis = 1)

# %%
teste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1392 entries, 110005 to 522230
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   qtd_abertas_Empresario_Individual  1392 non-null   int64
#  1   taxa_homicidio                     1392 non-null   float64
#  2   RH_adm_dir                         1392 non-null   float64
#  3   densidade_banda_larga              1392 non-null   float64
#  4   densidade_telefonia_movel          1392 non-null   float64
#  5   qtd_cursos_engenharias             1392 non-null   float64
#  6   qtd_cursos_negocios_direito        1392 non-null   float64
#  7   media_notas_CN                     1392 non-null   float64
#  8   media_notas_CH                     1392 non-null   float64
#  9   media_NU_NOTA_LC                   1392 non-null   float64
#  10  media_NU_NOTA_MT                   1392 non-null   float64
#  11  media_NU_NOTA_REDACAO              1392 non-null   float64
#  12  valor_medio_recebido_familia       1392 non-null   int64
#  13  pib_per_capita_preco_corrente      1392 non-null   float64
#  14  perc_20_59_anos                    1392 non-null   float64
#  15  pop_total                          1392 non-null   int64
#  16  total_sim_tecnologia               1392 non-null   float64
#  17  Mecanismos_incentivo_Sim           1392 non-null   uint8
#  18  Reducao_IPTU_Sim                   1392 non-null   uint8
#  19  Isencao_IPTU_Sim                   1392 non-null   uint8
#  20  Reducao_ISSQN_Sim                  1392 non-null   uint8
#  21  Isencao_ISSQN_Sim                  1392 non-null   uint8
#  22  Isencao_Tx_Sim                     1392 non-null   uint8
#  23  Cessao_terrenos_Sim                1392 non-null   uint8
#  24  Doacao_terrenos_Sim                1392 non-null   uint8
#  25  Outros_mecanismos_Sim              1392 non-null   uint8
#  26  ISH_Baixa                          1392 non-null   uint8
#  27  ISH_Máxima                         1392 non-null   uint8
#  28  ISH_Média                          1392 non-null   uint8
#  29  ISH_Mínima                         1392 non-null   uint8
# dtypes: float64(14), int64(3), uint8(13)
# memory usage: 213.4 KB

# %% [markdown]
# # Pycaret

# %% [markdown]
# ## Setup

# %%
regression_setup = setup(data = treino, target = 'qtd_abertas_Empresario_Individual', session_id = 42)
# Out:
# <style type="text/css">
# #T_c7d2d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c7d2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7d2d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c7d2d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7d2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7d2d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c7d2d_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7d2d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c7d2d_row1_col1" class="data row1 col1" >qtd_abertas_Empresario_Individual</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7d2d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c7d2d_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7d2d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c7d2d_row3_col1" class="data row3 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7d2d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c7d2d_row4_col1" class="data row4 col1" >(4178, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7d2d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c7d2d_row5_col1" class="data row5 col1" >(2924, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7d2d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c7d2d_row6_col1" class="data row6 col1" >(1254, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7d2d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c7d2d_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7d2d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_c7d2d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7d2d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_c7d2d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7d2d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_c7d2d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7d2d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_c7d2d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7d2d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_c7d2d_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c7d2d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_c7d2d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c7d2d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_c7d2d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c7d2d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_c7d2d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c7d2d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_c7d2d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c7d2d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_c7d2d_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c7d2d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c7d2d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_c7d2d_row18_col1" class="data row18 col1" >90e5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Comparando Modelos

# %% [markdown]
# ### Usando MAPE

# %%
best_model = compare_models(sort = 'RMSE', fold=5)
# Out:
# <style type="text/css">
# #T_60ce9 th {
#   text-align: left;
# }
# #T_60ce9_row0_col0, #T_60ce9_row0_col5, #T_60ce9_row0_col6, #T_60ce9_row1_col0, #T_60ce9_row1_col1, #T_60ce9_row1_col2, #T_60ce9_row1_col3, #T_60ce9_row1_col4, #T_60ce9_row1_col5, #T_60ce9_row1_col6, #T_60ce9_row2_col0, #T_60ce9_row2_col1, #T_60ce9_row2_col2, #T_60ce9_row2_col3, #T_60ce9_row2_col4, #T_60ce9_row2_col5, #T_60ce9_row2_col6, #T_60ce9_row3_col0, #T_60ce9_row3_col1, #T_60ce9_row3_col2, #T_60ce9_row3_col3, #T_60ce9_row3_col4, #T_60ce9_row3_col5, #T_60ce9_row3_col6, #T_60ce9_row4_col0, #T_60ce9_row4_col1, #T_60ce9_row4_col2, #T_60ce9_row4_col3, #T_60ce9_row4_col4, #T_60ce9_row4_col5, #T_60ce9_row4_col6, #T_60ce9_row5_col0, #T_60ce9_row5_col1, #T_60ce9_row5_col2, #T_60ce9_row5_col3, #T_60ce9_row5_col4, #T_60ce9_row5_col5, #T_60ce9_row5_col6, #T_60ce9_row6_col0, #T_60ce9_row6_col1, #T_60ce9_row6_col2, #T_60ce9_row6_col3, #T_60ce9_row6_col4, #T_60ce9_row6_col5, #T_60ce9_row6_col6, #T_60ce9_row7_col0, #T_60ce9_row7_col1, #T_60ce9_row7_col2, #T_60ce9_row7_col3, #T_60ce9_row7_col4, #T_60ce9_row7_col5, #T_60ce9_row7_col6, #T_60ce9_row8_col0, #T_60ce9_row8_col1, #T_60ce9_row8_col2, #T_60ce9_row8_col3, #T_60ce9_row8_col4, #T_60ce9_row8_col5, #T_60ce9_row8_col6, #T_60ce9_row9_col0, #T_60ce9_row9_col1, #T_60ce9_row9_col2, #T_60ce9_row9_col3, #T_60ce9_row9_col4, #T_60ce9_row9_col5, #T_60ce9_row9_col6, #T_60ce9_row10_col0, #T_60ce9_row10_col1, #T_60ce9_row10_col2, #T_60ce9_row10_col3, #T_60ce9_row10_col4, #T_60ce9_row10_col5, #T_60ce9_row10_col6, #T_60ce9_row11_col0, #T_60ce9_row11_col1, #T_60ce9_row11_col2, #T_60ce9_row11_col3, #T_60ce9_row11_col4, #T_60ce9_row11_col5, #T_60ce9_row11_col6, #T_60ce9_row12_col0, #T_60ce9_row12_col1, #T_60ce9_row12_col2, #T_60ce9_row12_col3, #T_60ce9_row12_col4, #T_60ce9_row13_col0, #T_60ce9_row13_col1, #T_60ce9_row13_col2, #T_60ce9_row13_col3, #T_60ce9_row13_col4, #T_60ce9_row13_col5, #T_60ce9_row13_col6, #T_60ce9_row14_col0, #T_60ce9_row14_col1, #T_60ce9_row14_col2, #T_60ce9_row14_col3, #T_60ce9_row14_col4, #T_60ce9_row14_col5, #T_60ce9_row14_col6, #T_60ce9_row15_col0, #T_60ce9_row15_col1, #T_60ce9_row15_col2, #T_60ce9_row15_col3, #T_60ce9_row15_col4, #T_60ce9_row15_col5, #T_60ce9_row15_col6, #T_60ce9_row16_col0, #T_60ce9_row16_col1, #T_60ce9_row16_col2, #T_60ce9_row16_col3, #T_60ce9_row16_col4, #T_60ce9_row16_col5, #T_60ce9_row16_col6, #T_60ce9_row17_col0, #T_60ce9_row17_col1, #T_60ce9_row17_col2, #T_60ce9_row17_col3, #T_60ce9_row17_col4, #T_60ce9_row17_col5, #T_60ce9_row17_col6, #T_60ce9_row18_col0, #T_60ce9_row18_col1, #T_60ce9_row18_col2, #T_60ce9_row18_col3, #T_60ce9_row18_col4, #T_60ce9_row18_col5, #T_60ce9_row18_col6, #T_60ce9_row19_col0, #T_60ce9_row19_col1, #T_60ce9_row19_col2, #T_60ce9_row19_col3, #T_60ce9_row19_col4, #T_60ce9_row19_col5, #T_60ce9_row19_col6 {
#   text-align: left;
# }
# #T_60ce9_row0_col1, #T_60ce9_row0_col2, #T_60ce9_row0_col3, #T_60ce9_row0_col4, #T_60ce9_row12_col5, #T_60ce9_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_60ce9_row0_col7, #T_60ce9_row1_col7, #T_60ce9_row2_col7, #T_60ce9_row3_col7, #T_60ce9_row4_col7, #T_60ce9_row5_col7, #T_60ce9_row6_col7, #T_60ce9_row7_col7, #T_60ce9_row9_col7, #T_60ce9_row10_col7, #T_60ce9_row11_col7, #T_60ce9_row12_col7, #T_60ce9_row13_col7, #T_60ce9_row14_col7, #T_60ce9_row15_col7, #T_60ce9_row16_col7, #T_60ce9_row17_col7, #T_60ce9_row18_col7, #T_60ce9_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_60ce9_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_60ce9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60ce9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_60ce9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_60ce9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_60ce9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_60ce9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_60ce9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_60ce9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_60ce9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60ce9_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_60ce9_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_60ce9_row0_col1" class="data row0 col1" >138.3505</td>
#       <td id="T_60ce9_row0_col2" class="data row0 col2" >366711.5141</td>
#       <td id="T_60ce9_row0_col3" class="data row0 col3" >578.1140</td>
#       <td id="T_60ce9_row0_col4" class="data row0 col4" >0.9485</td>
#       <td id="T_60ce9_row0_col5" class="data row0 col5" >0.6986</td>
#       <td id="T_60ce9_row0_col6" class="data row0 col6" >0.7208</td>
#       <td id="T_60ce9_row0_col7" class="data row0 col7" >0.2320</td>
#     </tr>
#     <tr>
#       <th id="T_60ce9_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_60ce9_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_60ce9_row1_col1" class="data row1 col1" >222.3184</td>
#       <td id="T_60ce9_row1_col2" class="data row1 col2" >1304406.5691</td>
#       <td id="T_60ce9_row1_col3" class="data row1 col3" >947.6668</td>
#       <td id="T_60ce9_row1_col4" class="data row1 col4" >0.9245</td>
#       <td id="T_60ce9_row1_col5" class="data row1 col5" >1.1778</td>
#       <td id="T_60ce9_row1_col6" class="data row1 col6" >2.6551</td>
#       <td id="T_60ce9_row1_col7" class="data row1 col7" >0.1760</td>
#     </tr>
#     <tr>
#       <th id="T_60ce9_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_60ce9_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_60ce9_row2_col1" class="data row2 col1" >181.8900</td>
#       <td id="T_60ce9_row2_col2" class="data row2 col2" >1662429.6217</td>
#       <td id="T_60ce9_row2_col3" class="data row2 col3" >1095.5381</td>
#       <td id="T_60ce9_row2_col4" class="data row2 col4" >0.9077</td>
#       <td id="T_60ce9_row2_col5" class="data row2 col5" >0.9878</td>
#       <td id="T_60ce9_row2_col6" class="data row2 col6" >1.7161</td>
#       <td id="T_60ce9_row2_col7" class="data row2 col7" >0.1920</td>
#     </tr>
#     <tr>
#       <th id="T_60ce9_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_60ce9_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_60ce9_row3_col1" class="data row3 col1" >184.2287</td>
#       <td id="T_60ce9_row3_col2" class="data row3 col2" >1682806.6179</td>
#       <td id="T_60ce9_row3_col3" class="data row3 col3" >1101.8769</td>
#       <td id="T_60ce9_row3_col4" class="data row3 col4" >0.9066</td>
#       <td id="T_60ce9_row3_col5" class="data row3 col5" >0.9739</td>
#       <td id="T_60ce9_row3_col6" class="data row3 col6" >1.7860</td>
#       <td id="T_60ce9_row3_col7" class="data row3 col7" >0.1800</td>
#     </tr>
#     <tr>
#       <th id="T_60ce9_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_60ce9_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_60ce9_row4_col1" class="data row4 col1" >188.2600</td>
#       <td id="T_60ce9_row4_col2" class="data row4 col2" >1694558.2085</td>
#       <td id="T_60ce9_row4_col3" class="data row4 col3" >1105.2548</td>
#       <td id="T_60ce9_row4_col4" class="data row4 col4" >0.9062</td>
#       <td id="T_60ce9_row4_col5" class="data row4 col5" >1.0163</td>
#       <td id="T_60ce9_row4_col6" class="data row4 col6" >1.8654</td>
#       <td id="T_60ce9_row4_col7" class="data row4 col7" >0.1920</td>
#     </tr>
#     <tr>
#       <th id="T_60ce9_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_60ce9_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_60ce9_row5_col1" class="data row5 col1" >190.6498</td>
#       <td id="T_60ce9_row5_col2" class="data row5 col2" >1698940.5667</td>
#       <td id="T_60ce9_row5_col3" class="da
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]

# %%
# verificando os hiperparâmetros do modelo 

print(best_model)
# Out:
# HuberRegressor()

# %%
best_model = create_model('huber', fold = 5)
# Out:
# <style type="text/css">
# #T_7cc3d_row5_col0, #T_7cc3d_row5_col1, #T_7cc3d_row5_col2, #T_7cc3d_row5_col3, #T_7cc3d_row5_col4, #T_7cc3d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7cc3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cc3d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7cc3d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7cc3d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7cc3d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7cc3d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7cc3d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cc3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cc3d_row0_col0" class="data row0 col0" >141.8830</td>
#       <td id="T_7cc3d_row0_col1" class="data row0 col1" >353570.7113</td>
#       <td id="T_7cc3d_row0_col2" class="data row0 col2" >594.6181</td>
#       <td id="T_7cc3d_row0_col3" class="data row0 col3" >0.9850</td>
#       <td id="T_7cc3d_row0_col4" class="data row0 col4" >0.7202</td>
#       <td id="T_7cc3d_row0_col5" class="data row0 col5" >0.6571</td>
#     </tr>
#     <tr>
#       <th id="T_7cc3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cc3d_row1_col0" class="data row1 col0" >152.2660</td>
#       <td id="T_7cc3d_row1_col1" class="data row1 col1" >373452.7730</td>
#       <td id="T_7cc3d_row1_col2" class="data row1 col2" >611.1078</td>
#       <td id="T_7cc3d_row1_col3" class="data row1 col3" >0.8825</td>
#       <td id="T_7cc3d_row1_col4" class="data row1 col4" >0.6260</td>
#       <td id="T_7cc3d_row1_col5" class="data row1 col5" >0.5953</td>
#     </tr>
#     <tr>
#       <th id="T_7cc3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cc3d_row2_col0" class="data row2 col0" >150.8734</td>
#       <td id="T_7cc3d_row2_col1" class="data row2 col1" >512538.5771</td>
#       <td id="T_7cc3d_row2_col2" class="data row2 col2" >715.9180</td>
#       <td id="T_7cc3d_row2_col3" class="data row2 col3" >0.9430</td>
#       <td id="T_7cc3d_row2_col4" class="data row2 col4" >0.7083</td>
#       <td id="T_7cc3d_row2_col5" class="data row2 col5" >0.7101</td>
#     </tr>
#     <tr>
#       <th id="T_7cc3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cc3d_row3_col0" class="data row3 col0" >89.4697</td>
#       <td id="T_7cc3d_row3_col1" class="data row3 col1" >55167.1622</td>
#       <td id="T_7cc3d_row3_col2" class="data row3 col2" >234.8769</td>
#       <td id="T_7cc3d_row3_col3" class="data row3 col3" >0.9366</td>
#       <td id="T_7cc3d_row3_col4" class="data row3 col4" >0.6656</td>
#       <td id="T_7cc3d_row3_col5" class="data row3 col5" >0.6878</td>
#     </tr>
#     <tr>
#       <th id="T_7cc3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cc3d_row4_col0" class="data row4 col0" >157.2604</td>
#       <td id="T_7cc3d_row4_col1" class="data row4 col1" >538828.3469</td>
#       <td id="T_7cc3d_row4_col2" class="data row4 col2" >734.0493</td>
#       <td id="T_7cc3d_row4_col3" class="data row4 col3" >0.9955</td>
#       <td id="T_7cc3d_row4_col4" class="data row4 col4" >0.7731</td>
#       <td id="T_7cc3d_row4_col5" class="data row4 col5" >0.9538</td>
#     </tr>
#     <tr>
#       <th id="T_7cc3d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_7cc3d_row5_col0" class="data row5 col0" >138.3505</td>
#       <td id="T_7cc3d_row5_col1" class="data row5 col1" >366711.5141</td>
#       <td id="T_7cc3d_row5_col2" class="data row5 col2" >578.1140</td>
#       <td id="T_7cc3d_row5_col3" class="data row5 col3" >0.9485</td>
#       <td id="T_7cc3d_row5_col4" class="data row5 col4" >0.6986</td>
#       <td id="T_7cc3d_row5_col5" class="data row5 col5" >0.7208</td>
#     </tr>
#     <tr>
#       <th id="T_7cc3d_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_7cc3d_row6_col0" class="data row6 col0" >24.9394</td>
#       <td id="T_7cc3d_row6_col1" class="data row6 col1" >172143.9775</td>
#       <td id="T_7cc3d_row6_col2" class="data row6 col2" >180.2656</td>
#       <td id="T_7cc3d_row6_col3" class="data row6 col3" >0.0402</td>
#       <td id="T_7cc3d_row6_col4" class="data row6 col4" >0.0499</td>
#       <td id="T_7cc3d_row6_col5" class="data row6 col5" >0.1227</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### Plotando alguns graficos

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best_model, plot = 'learning')

# %%
plot_model(best_model, plot='vc')

# %%
plot_model(best_model, plot='error')

# %%
plot_model(best_model, plot='feature')

# %%
plot_model(best_model, plot='residuals',  scale = 3)

# %% [markdown]
# ### Tunando o modelo

# %%
# em alguns tutoriais vi que não fizeram nenhuma modificação manual dos parametros, e eles já modificavam. 
#Esse parece que não conteceu do mesmo jeito. 

tuned = tune_model(best_model, fold = 5)
# Out:
# <style type="text/css">
# #T_55d8c_row5_col0, #T_55d8c_row5_col1, #T_55d8c_row5_col2, #T_55d8c_row5_col3, #T_55d8c_row5_col4, #T_55d8c_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_55d8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55d8c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_55d8c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_55d8c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_55d8c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_55d8c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_55d8c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55d8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55d8c_row0_col0" class="data row0 col0" >141.0645</td>
#       <td id="T_55d8c_row0_col1" class="data row0 col1" >329320.7964</td>
#       <td id="T_55d8c_row0_col2" class="data row0 col2" >573.8648</td>
#       <td id="T_55d8c_row0_col3" class="data row0 col3" >0.9861</td>
#       <td id="T_55d8c_row0_col4" class="data row0 col4" >0.7124</td>
#       <td id="T_55d8c_row0_col5" class="data row0 col5" >0.6766</td>
#     </tr>
#     <tr>
#       <th id="T_55d8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55d8c_row1_col0" class="data row1 col0" >153.0118</td>
#       <td id="T_55d8c_row1_col1" class="data row1 col1" >375921.3360</td>
#       <td id="T_55d8c_row1_col2" class="data row1 col2" >613.1242</td>
#       <td id="T_55d8c_row1_col3" class="data row1 col3" >0.8817</td>
#       <td id="T_55d8c_row1_col4" class="data row1 col4" >0.6539</td>
#       <td id="T_55d8c_row1_col5" class="data row1 col5" >0.6034</td>
#     </tr>
#     <tr>
#       <th id="T_55d8c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55d8c_row2_col0" class="data row2 col0" >150.4280</td>
#       <td id="T_55d8c_row2_col1" class="data row2 col1" >497575.6228</td>
#       <td id="T_55d8c_row2_col2" class="data row2 col2" >705.3904</td>
#       <td id="T_55d8c_row2_col3" class="data row2 col3" >0.9446</td>
#       <td id="T_55d8c_row2_col4" class="data row2 col4" >0.6997</td>
#       <td id="T_55d8c_row2_col5" class="data row2 col5" >0.7065</td>
#     </tr>
#     <tr>
#       <th id="T_55d8c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55d8c_row3_col0" class="data row3 col0" >89.7567</td>
#       <td id="T_55d8c_row3_col1" class="data row3 col1" >55087.6462</td>
#       <td id="T_55d8c_row3_col2" class="data row3 col2" >234.7076</td>
#       <td id="T_55d8c_row3_col3" class="data row3 col3" >0.9367</td>
#       <td id="T_55d8c_row3_col4" class="data row3 col4" >0.6430</td>
#       <td id="T_55d8c_row3_col5" class="data row3 col5" >0.6916</td>
#     </tr>
#     <tr>
#       <th id="T_55d8c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55d8c_row4_col0" class="data row4 col0" >155.8591</td>
#       <td id="T_55d8c_row4_col1" class="data row4 col1" >543075.1470</td>
#       <td id="T_55d8c_row4_col2" class="data row4 col2" >736.9363</td>
#       <td id="T_55d8c_row4_col3" class="data row4 col3" >0.9954</td>
#       <td id="T_55d8c_row4_col4" class="data row4 col4" >0.7712</td>
#       <td id="T_55d8c_row4_col5" class="data row4 col5" >0.8733</td>
#     </tr>
#     <tr>
#       <th id="T_55d8c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_55d8c_row5_col0" class="data row5 col0" >138.0240</td>
#       <td id="T_55d8c_row5_col1" class="data row5 col1" >360196.1097</td>
#       <td id="T_55d8c_row5_col2" class="data row5 col2" >572.8047</td>
#       <td id="T_55d8c_row5_col3" class="data row5 col3" >0.9489</td>
#       <td id="T_55d8c_row5_col4" class="data row5 col4" >0.6960</td>
#       <td id="T_55d8c_row5_col5" class="data row5 col5" >0.7103</td>
#     </tr>
#     <tr>
#       <th id="T_55d8c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_55d8c_row6_col0" class="data row6 col0" >24.6397</td>
#       <td id="T_55d8c_row6_col1" class="data row6 col1" >171236.4535</td>
#       <td id="T_55d8c_row6_col2" class="data row6 col2" >179.1394</td>
#       <td id="T_55d8c_row6_col3" class="data row6 col3" >0.0406</td>
#       <td id="T_55d8c_row6_col4" class="data row6 col4" >0.0459</td>
#       <td id="T_55d8c_row6_col5" class="data row6 col5" >0.0889</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
#estranho, era para monstrar o que foi testado de diferente com o tuned, parece que esta igual.
#Sem falar que os resultados parecem piores depois de tunar 

print(tuned)
# Out:
# HuberRegressor(alpha=0.5, epsilon=1.7)

# %%
plot_model(tuned, plot = 'learning')  #use_train_data = True

# %%
# Validation Curve
plot_model(tuned, plot='vc')

# %%
plot_model(tuned, plot='error')

# O R² esta bem baixo

# %%
plot_model(tuned, plot='feature')

# %%
plot_model(tuned, plot='residuals',  scale = 3)

#os resultados parecem muito distantes uns dos outros

# %%
final_model_baseline = finalize_model(tuned)

# %% [markdown]
# ### Previsão

# %%
pred_treino = predict_model(final_model_baseline, data = treino)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a01e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a01e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6a01e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6a01e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6a01e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6a01e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6a01e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6a01e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a01e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a01e_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_6a01e_row0_col1" class="data row0 col1" >131.7326</td>
#       <td id="T_6a01e_row0_col2" class="data row0 col2" >258644.3471</td>
#       <td id="T_6a01e_row0_col3" class="data row0 col3" >508.5709</td>
#       <td id="T_6a01e_row0_col4" class="data row0 col4" >0.9890</td>
#       <td id="T_6a01e_row0_col5" class="data row0 col5" >0.7048</td>
#       <td id="T_6a01e_row0_col6" class="data row0 col6" >0.7478</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_treino
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 270660                         6.0         0.0               0.463208
# 316730                         0.0       186.0              12.130569
# 251278                         0.0       260.0               8.554277
# 430870                         0.0       226.0              30.952818
# 314920                         0.0       369.0               5.450562
# ...                            ...         ...                    ...
# 355030                       454.0    127721.0              32.097408
# 291080                       264.0      5937.0              11.146967
# 430510                        86.0      7345.0              34.121548
# 330330                       165.0      3689.0              36.960739
# 355220                        63.0     11747.0              37.041367
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 270660                              33.152462                     0.0
# 316730                              67.534187                     0.0
# 251278                              66.133064                     0.0
# 430870                              88.121902                     0.0
# 314920                              94.467270                     0.0
# ...                                       ...                     ...
# 355030                             125.004189                 12809.0
# 291080                             125.226761                   494.0
# 430510                             101.562866                   484.0
# 330330                             125.476761                  1362.0
# 355220                             119.078194                  1831.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 270660                                      0.0      395.628571
# 316730                                      0.0      490.662506
# 251278                                      0.0      444.866669
# 430870                                      0.0      488.318176
# 314920                                      0.0      469.000000
# ...                                         ...             ...
# 355030                                  52259.0      515.010742
# 291080                                   1546.0      497.371368
# 430510                                   1699.0      520.229065
# 330330                                   2503.0      522.259460
# 355220                                   2692.0      514.474243
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 270660                  422.762512        445.825012        436.742859  ...
# 316730                  527.674988        496.262512        539.212524  ...
# 251278                  473.833344        443.799988        451.933319  ...
# 430870                  497.261536        469.307678        565.990906  ...
# 314920                  452.000000        449.950012        554.099976  ...
# ...                            ...               ...               ...  ...
# 355030                  548.616333        534.100159        581.029175  ...
# 291080                  523.909973        509.181915        543.344971  ...
# 430510                  556.289062        535.819946        581.916504  ...
# 330330                  556.662903        536.360840        592.505432  ...
# 355220                  546.214417        531.277527        577.488953  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 270660                           0                    0                    0
# 316730                           0                    0                    0
# 251278                           0                    1                    1
# 430870                           0                    0                    0
# 314920                           0                    0                    0
# ...                            ...                  ...                  ...
# 355030                           0                    0                    0
# 291080                           0                    0                    0
# 430510                           0                    0                    0
# 330330                           1                    0                    0
# 355220                           1                    0                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 270660                                  0          1           0          0
# 316730                                  0          0           1          0
# 251278                                  0          1           0          0
# 430870                                  0          0           0          0
# 314920                                  0          0           0          0
# ...                                   ...        ...         ...        ...
# 355030                                  1          0           0          1
# 291080                                  0          0           0          0
# 430510                                  0          0           0          1
# 330330                                  0          1           0          0
# 355220                                  0          0           0          1
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 270660                       0                                 33
# 316730                       0                                 26
# 251278                       0                                 15
# 430870                       0                                 74
# 314920                       0                                 37
# ...                        ...                                ...
# 355030                       0                             253408
# 291080                       0                               9589
# 430510                       0                               9898
# 330330                       0                               9251
# 355220                       0                              17213
#
#                     prediction_label
# cod_municipio_ibge
# 270660                     50.239255
# 316730                     12.849264
# 251278                     -3.476766
# 430870                    102.689113
# 314920                     51.653274
# ...                              ...
# 355030                 253407.766344
# 291080                  10386.017573
# 430510                   9435.673314
# 330330                  12101.806259
# 355220                  14244.951267
#
# [4178 rows x 31 columns]

# %%
plt.scatter(pred_treino['qtd_abertas_Empresario_Individual'],pred_treino['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
# Out:
# Text(0, 0.5, 'Valores preditos')

# %% [markdown]
# Previsão de dados não vistos

# %%
pred_unseen = predict_model(final_model_baseline, data = teste)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8e09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8e09_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8e09_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a8e09_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a8e09_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a8e09_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a8e09_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a8e09_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8e09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8e09_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_a8e09_row0_col1" class="data row0 col1" >122.8559</td>
#       <td id="T_a8e09_row0_col2" class="data row0 col2" >134040.6877</td>
#       <td id="T_a8e09_row0_col3" class="data row0 col3" >366.1157</td>
#       <td id="T_a8e09_row0_col4" class="data row0 col4" >0.9622</td>
#       <td id="T_a8e09_row0_col5" class="data row0 col5" >0.6865</td>
#       <td id="T_a8e09_row0_col6" class="data row0 col6" >0.7617</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_unseen
# Out:
#                     taxa_homicidio  RH_adm_dir  densidade_banda_larga  \
# cod_municipio_ibge
# 110005                         3.0       591.0               8.540527
# 110007                         1.0       382.0               3.261486
# 110008                         3.0       573.0               4.388471
# 110011                        10.0      1484.0              20.346228
# 110013                         6.0      1214.0               7.779695
# ...                            ...         ...                    ...
# 522100                         5.0       195.0               2.852253
# 522119                         4.0       271.0              10.329089
# 522190                         0.0       184.0               9.433472
# 522200                         1.0       528.0               6.423907
# 522230                         0.0       344.0               7.187342
#
#                     densidade_telefonia_movel  qtd_cursos_engenharias  \
# cod_municipio_ibge
# 110005                             108.074341                     4.0
# 110007                              51.545662                     0.0
# 110008                              35.367435                     5.0
# 110011                             101.132721                     8.0
# 110013                              56.914486                     3.0
# ...                                       ...                     ...
# 522100                             103.565315                     0.0
# 522119                             116.298340                     0.0
# 522190                              78.092514                     0.0
# 522200                             106.821411                     4.0
# 522230                              39.892273                     0.0
#
#                     qtd_cursos_negocios_direito  media_notas_CN  \
# cod_municipio_ibge
# 110005                                     35.0      479.268738
# 110007                                      0.0      439.184601
# 110008                                     12.0      438.418182
# 110011                                    114.0      472.343292
# 110013                                     26.0      460.839630
# ...                                         ...             ...
# 522100                                      0.0      464.779999
# 522119                                      0.0      435.885712
# 522190                                      0.0      426.950012
# 522200                                     12.0      449.954041
# 522230                                      0.0      432.055542
#
#                     media_notas_CH  media_NU_NOTA_LC  media_NU_NOTA_MT  ...  \
# cod_municipio_ibge                                                      ...
# 110005                  477.045715        454.722870        480.696869  ...
# 110007                  466.414276        432.535706        445.276917  ...
# 110008                  465.692108        451.828949        478.290924  ...
# 110011                  501.169189        481.437683        507.111206  ...
# 110013                  482.138611        470.749115        485.543396  ...
# ...                            ...               ...               ...  ...
# 522100                  487.066681        474.000000        520.359985  ...
# 522119                  480.299988        450.257141        503.938110  ...
# 522190                  483.766663        451.266663        422.950012  ...
# 522200                  479.917084        473.014648        516.186462  ...
# 522230                  417.394745        428.821045        460.816681  ...
#
#                     Isencao_Tx_Sim  Cessao_terrenos_Sim  Doacao_terrenos_Sim  \
# cod_municipio_ibge
# 110005                           0                    0                    0
# 110007                           0                    1                    0
# 110008                           1                    1                    0
# 110011                           0                    0                    0
# 110013                           0                    0                    0
# ...                            ...                  ...                  ...
# 522100                           0                    0                    0
# 522119                           0                    1                    0
# 522190                           0                    0                    0
# 522200                           0                    0                    0
# 522230                           0                    1                    0
#
#                     Outros_mecanismos_Sim  ISH_Baixa  ISH_Máxima  ISH_Média  \
# cod_municipio_ibge
# 110005                                  0          1           0          0
# 110007                                  1          0           0          0
# 110008                                  0          1           0          0
# 110011                                  0          0           0          1
# 110013                                  1          1           0          0
# ...                                   ...        ...         ...        ...
# 522100                                  0          0           0          0
# 522119                                  0          0           1          0
# 522190                                  0          0           1          0
# 522200                                  0          0           1          0
# 522230                                  0          0           0          0
#
#                     ISH_Mínima  qtd_abertas_Empresario_Individual  \
# cod_municipio_ibge
# 110005                       0                                257
# 110007                       0                                 86
# 110008                       0                                106
# 110011                       0                                617
# 110013                       0                                279
# ...                        ...                                ...
# 522100                       0                                 41
# 522119                       0                                108
# 522190                       0                                 30
# 522200                       0                                222
# 522230                       0                                 47
#
#                     prediction_label
# cod_municipio_ibge
# 110005                    244.431312
# 110007                     38.251022
# 110008                    184.035830
# 110011                    749.728184
# 110013                    445.707551
# ...                              ...
# 522100                     52.918899
# 522119                    112.937606
# 522190                    114.281526
# 522200                    185.673619
# 522230                     54.298978
#
# [1392 rows x 31 columns]

# %%
plt.scatter(pred_unseen['qtd_abertas_Empresario_Individual'],pred_unseen['prediction_label'])
plt.xlabel('Valores reais')
plt.ylabel('Valores preditos')
# Out:
# Text(0, 0.5, 'Valores preditos')
